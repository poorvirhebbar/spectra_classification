# %%
from pathlib import Path
import numpy as np
import pandas as pd
from astropy.io import fits
import matplotlib.pyplot as plt
import copy
import seaborn as sns
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Subset, ConcatDataset

#import umap
#import hdbscan
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold, train_test_split, KFold
from sklearn.metrics import adjusted_rand_score
from tqdm import tqdm

# %%
def read_unequal_table(txt_file, num_columns=383, filler=''):
    """Read table from file."""
    table = []
    with open(txt_file) as file:
        for row in file:
            values = row.split()
            if len(values) > num_columns:
                raise ValueError('Number of values more than num_columns')
            elif len(values) < num_columns:
                diff = num_columns - len(values)
                padding = [filler]*diff
                values = values + padding
            else:
                pass
            table.append(values)
    return np.array(table)

# %%
def read_norm_spectra(txt_file):
    """Read the saved set of normalized spectra"""
    alldata = read_unequal_table(txt_file)
    srcids = alldata[:, 0].astype(str)
    normed_spectra = alldata[:, 1:-2].astype(float)
    netcounts = alldata[:, -2].astype(float)
    src_class = alldata[:, -1].astype(str)
    return srcids, normed_spectra, netcounts, src_class

# %%
def refine_labels(label_array):
    """Refine labels to 4 classes."""
    refined_labels = np.full(len(label_array), '', dtype='<U16')
    for i, label in enumerate(label_array):
        if label == '':
            continue
        if label == 'AGN' or label == 'CV':
            refined_labels[i] = label
        elif label == 'LM-STAR' or label == 'HM-STAR' or label == 'YSO':
            refined_labels[i] = 'STAR'
        else:
            refined_labels[i] = 'NS/BH'
    return refined_labels

# %%
pn_srcids, pn_normspec, pn_counts, pn_class = read_norm_spectra('../Data/Brightpn_id_normspec_counts_label.txt')

# %%
pn_class_refined = refine_labels(pn_class)

# %%
def check_spectra(normspec, refinedclass):
    """Check the normalized spectra of different classes."""
    en_bins = np.linspace(0.5, 10, len(normspec[0]))
    classes_unique = np.unique(refinedclass)
    plt.figure(figsize=(20, 12))
    plt.xlabel('Energy [keV]')
    plt.ylabel('Normalized counts [/bin]')
    plt.xscale('log')
    plt.xlim(0.5, 10.0)
    for classes in classes_unique:
        if classes != '':
            plt.plot(en_bins,
                     np.mean(normspec[refinedclass == classes], axis=0), label=classes)
    plt.legend()
    plt.show()

# %%
check_spectra(pn_normspec, pn_class_refined)

# %%
labelled_args = np.where(pn_class_refined != '')[0]
unlabelled_args = np.where(pn_class_refined == '')[0]
pn_normspec_labelled = pn_normspec[labelled_args]
pn_spec_labels = np.zeros(len(labelled_args), dtype=int)
pn_counts_labelled = pn_counts[labelled_args]
pn_spec_labels[pn_class_refined[labelled_args] == 'STAR'] = 1
pn_spec_labels[pn_class_refined[labelled_args] == 'NS/BH'] = 2
pn_spec_labels[pn_class_refined[labelled_args] == 'CV'] = 3

# %%
check_spectra(pn_normspec_labelled, pn_spec_labels)

# %%
pn_labelled_trainids = np.loadtxt('Train_PN_indices_forall_labelled.txt')
pn_labelled_testids = np.loadtxt('Test_PN_indices_forall_labelled.txt')

# %%
# =========================================================
# Simple Semi-supervised Autoencoder + Classifier
# =========================================================
class SemiSupervisedAE(nn.Module):
    def __init__(self, num_classes=4, latent_dim=32, drop=0.0, l_noise=0.05):
        super().__init__()

        # ---------- Encoder ----------
        self.encoder = nn.Sequential(
            nn.Conv1d(1, 8, kernel_size=7, padding=3),
            nn.BatchNorm1d(8),
            nn.ReLU(),
            nn.Dropout(drop),
            nn.MaxPool1d(2),

            nn.Conv1d(8, 16, kernel_size=5, padding=2),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Dropout(drop),
            nn.MaxPool1d(2),
        )

        # compute encoded feature size
        self._enc_out_dim = 16 * (380 // 4)  # assuming input length 380
        self.fc_enc = nn.Linear(self._enc_out_dim, latent_dim)
        self.latent_noise_std = l_noise

        # ---------- Decoder ----------
        self.fc_dec = nn.Linear(latent_dim, self._enc_out_dim)
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(16, 8, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.ConvTranspose1d(8, 1, kernel_size=7, padding=3),
            nn.Softplus()  # ensures positive reconstructed counts
        )

        # ---------- Classifier ----------
        self.classifier = nn.Sequential(
            # nn.Linear(latent_dim, 64),
            # nn.ReLU(),
            nn.Linear(latent_dim, num_classes)
        )

    def forward(self, x):
        # x: (B, 1, 380)
        z = self.encoder(x)
        z = z.view(x.size(0), -1)
        z = self.fc_enc(z)
        if self.training and self.latent_noise_std > 0:
            dim_std = z.std(dim=0, unbiased=False,
                            keepdim=True).clamp(min=1e-3)
            z_decode = z + torch.randn_like(z)*self.latent_noise_std*dim_std
            z_class = z + torch.randn_like(z)*(self.latent_noise_std*4*dim_std)
            # print(torch.randn_like(z)*self.latent_noise_std*5*dim_std)
        else:
            z_decode = z
            z_class = z

        # Decode
        dec = self.fc_dec(z_decode)
        dec = dec.view(x.size(0), 16, 380 // 4)
        x_hat = self.decoder(dec)

        # Upsample back to 380 bins
        x_hat = nn.functional.interpolate(x_hat, size=380, mode="linear")

        # Classify
        # z = self.dropout_latent(z)
        logits = self.classifier(z_class)
        return x_hat, logits, z


def l1_penalty(model):
    l1_norm = sum(p.abs().sum() for p in model.parameters())
    return l1_norm


def poisson_recon_loss(x, x_hat, total_counts=1.0, eps=1e-6):
    """
    x: original *normalized* input spectrum  (values sum to 1)
    x_hat: reconstructed normalized spectrum (values sum to ~1)
    total_counts: original total counts before normalization (scalar or tensor)
    """
    # ensure torch tensor
    if not torch.is_tensor(total_counts):
        total_counts = torch.tensor(total_counts, dtype=x.dtype,
                                    device=x.device)
    # reshape for broadcasting (B, 1, 1)
    if total_counts.ndim == 1:
        total_counts = total_counts.view(-1, 1, 1)

    # rescale both spectra back to original count scale
    # total_counts = total_counts.view(-1, 1, 1)
    x_rescaled = torch.clamp(x * total_counts, min=eps)
    x_hat_rescaled = torch.clamp(x_hat * total_counts, min=eps)

    # standard Poisson negative log-likelihood loss (ignoring constants)
    loss = ((x_hat_rescaled - x_rescaled +
             x_rescaled * torch.log(x_rescaled + eps) -
             x_rescaled * torch.log(x_hat_rescaled + eps)).sum(dim=2) /
            total_counts.view(-1, 1)).mean(dim=0)
    # print(loss.shape)
    return loss

def smoothness_loss(x_hat):
    # Penalize large gradients between neighboring bins
    return torch.mean(torch.abs(x_hat[:, :, 1:] - x_hat[:, :, :-1]).sum(dim=2))


def train_semisupervised(model, optimizer, labeled_loader, unlabeled_loader,
                         lambda_cls=2.0, device=None, epochs=20, l1_lam=0.0,
                         l_smooth=10, l_latent=1.0e-3,
                         scheduler=None, val_loader=None,
                         temp_filename='best_model', weights=None):
    """Train a supervised Autoencoder with classification loss."""
    if device is None:
        device='cuda' if torch.cuda.is_available() else 'cpu'
   
    model.to(device)
    if weights is None:
        ce_loss = nn.CrossEntropyLoss()
    else:
        ce_loss = nn.CrossEntropyLoss(weight=torch.tensor(weights).to(device))
    print(lambda_cls, l1_lam, l_smooth)
    
    #best_val_loss = float("inf")
    #best_epoch = -1
    #epochs_no_improve = 0
    #no_improve_patience = 12

    for epoch in range(epochs):
        print(f'Epoch {epoch}')
        model.train()
        total_loss = total_cls = total_recon = total_smooth = tot_latent = 0.0
        total_rloss_l = total_rloss_u = 0.0

        # main iterator: unlabeled batches
        labeled_iter = iter(labeled_loader)

        #for xbu in tqdm(unlabeled_loader, desc=f"Epoch {epoch+1}/{epochs}"):
        for xbu in unlabeled_loader:
            xbu = xbu[0].to(device)

            # fetch or resample labeled batch
            try:
                xb, yb = next(labeled_iter)
            except StopIteration:
                labeled_list = list(labeled_loader)
                xb, yb = random.choice(labeled_list)
            xb, yb = xb.to(device), yb.to(device)
            
            # Seperate counts and normalized spectra
            xbu_counts = xbu[:, :, -1].view(-1, 1, 1)
            xbu = xbu[:, :, :-1]
            xb_counts = xb[:, :, -1].view(-1, 1, 1)
            xb = xb[:, :, :-1]

            # forward passes
            x_hat_l, logits, z_l = model(xb)
            x_hat_u, _, z_u = model(xbu)

            # losses
            recon_loss_l = poisson_recon_loss(xb, x_hat_l, xb_counts)
            recon_loss_u = poisson_recon_loss(xbu, x_hat_u, xbu_counts)
            loss_recon = ((recon_loss_l*len(xb) + recon_loss_u*len(xbu)) /
                          (len(xb) + len(xbu)))
            loss_cls = ce_loss(logits, yb)
            loss = loss_recon + lambda_cls * loss_cls

            if l_latent > 0.0:
                loss_latent = ((torch.mean(z_l.pow(2))*len(xb) +
                                torch.mean(z_u.pow(2))*len(xbu)) /
                               (len(xb) + len(xbu)))
                loss += l_latent*loss_latent
            
            if l1_lam > 0.0:
                loss_l1 = l1_penalty(model)
                loss += l1_lam*loss_l1
            
            if l_smooth > 0.0:
                loss_smooth = (
                    smoothness_loss(x_hat_l)*len(xb) +
                    smoothness_loss(x_hat_u)*len(xbu)) / (len(xb) + len(xbu))
                loss += l_smooth*loss_smooth

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            total_cls += loss_cls.item()
            total_smooth += loss_smooth.item()
            total_recon += loss_recon.item()
            total_rloss_l += recon_loss_l.item()
            total_rloss_u += recon_loss_u.item()
            tot_latent += loss_latent.item()

        print(f"Epoch {epoch+1}:total={total_loss/len(unlabeled_loader):.4f}, "
              f"cls={total_cls/len(unlabeled_loader):.4f}, "
              f"recon={total_recon/len(unlabeled_loader):.4f} "
              f"({total_rloss_l/len(unlabeled_loader):.4f}, "
              f"{total_rloss_u/len(unlabeled_loader):.4f}), ",
              f"smooth={total_smooth/len(unlabeled_loader):.4f}, "
              f"latent={tot_latent/len(unlabeled_loader):.4f}")
        if val_loader is not None:
            # Get validation loss
            model.eval()
            val_loss, val_items, corr = 0.0, 0, 0
            val_loss_r, val_loss_c, val_loss_s, val_loss_l = 0.0, 0.0, 0.0, 0.0
            val_nscv_items, val_nscv_corr = 0, 0
            with torch.no_grad():
                for xb, yb in val_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    xb_counts = xb[:, :, -1].view(-1, 1, 1)
                    xb = xb[:, :, :-1]
                    x_hat, logits_val, z_val = model(xb)
                    val_loss_rb = poisson_recon_loss(
                        xb, x_hat, xb_counts).item()
                    val_loss_cb = ce_loss(logits_val, yb).item()
                    val_loss_sb = smoothness_loss(x_hat).item()
                    val_loss_lb = torch.mean(z_val.pow(2))
                    val_loss_b = (val_loss_rb + lambda_cls*val_loss_cb +
                                  l_smooth*val_loss_sb + l_latent*val_loss_lb +
                                  l1_lam*l1_penalty(model).item())
                    preds = torch.argmax(logits_val, dim=1)
                    val_loss += val_loss_b
                    val_loss_r += val_loss_rb
                    val_loss_c += val_loss_cb
                    val_loss_s += val_loss_sb
                    val_loss_l += val_loss_lb
                    corr += (preds == yb).sum().item()
                    val_items += xb.size(0)
                    val_nscv_items += torch.logical_or(yb==2, yb==3).sum()
                    val_nscv_corr += torch.logical_or(
                        torch.logical_and(preds==2, yb==2),
                        torch.logical_and(preds==3, yb==3)).sum()
            val_loss = val_loss/len(val_loader)
            val_loss_r = val_loss_r/len(val_loader)
            val_loss_c = val_loss_c/len(val_loader)
            val_loss_s = val_loss_s/len(val_loader)
            val_loss_l = val_loss_l/len(val_loader)
            val_acc = corr/max(val_items, 1)
            val_acc_nscv = val_nscv_corr/max(val_nscv_items, 1)
            print(f"Validation loss: {val_loss:.4f} | Val acc: {val_acc:.4f} |"
                  f"Val acc (NS/BH/CV): {val_acc_nscv:.4f} |"
                  f"val_class:{val_loss_c:.4f} val_recon:{val_loss_r:.4f} "
                  f"val_smooth: {val_loss_s:.4f} val_latent:{val_loss_l:.4f}")
            if scheduler is not None:
                old_lr = optimizer.param_groups[0]['lr']
                scheduler.step(val_loss)
                new_lr = optimizer.param_groups[0]['lr']
                if new_lr < old_lr:
                    print(f'Learning rate changed to {new_lr:.6f}')
            
            # if val_loss < best_val_loss:
            #    best_val_loss = val_loss
            #    epochs_no_improve = 0
            #    torch.save(model.state_dict(), temp_filename)
            # else:
            #    epochs_no_improve += 1

            # if epochs_no_improve >= no_improve_patience:
            #    print(f"Early stopping at epoch {epoch}")
            #    model.load_state_dict(torch.load(temp_filename))
            #    break

    return model


def semisupervised_kfold_test(models_class, labelled_data, labels,
                              unlabelled_data, num_classes=4, lambda_cls=2.0,
                              k_folds=10, lr=1e-3, epochs=20,
                              batch_size=32, ul_batch_size=512,
                              test_size=0.2, device=None,
                              l1_lambda=0.0, l2_lambda=0.0, op_alg='Adam',
                              train_ids=None, test_ids=None, weights=None):
    """
    k-fold CV on labeled data with all unlabeled data in training.
    Returns all fold models, validation & test accuracies, and best model.
    """
    if device is None:
        device='cuda' if torch.cuda.is_available() else 'cpu'

    # --- Hold-out test split ---
    if train_ids is None and test_ids is None:
        train_ids, test_ids = train_test_split(np.arange(len(labels)),
                                               test_size=test_size,
                                               stratify=labels,
                                               random_state=32)

    X_trainval = labelled_data[train_ids]
    X_test = labelled_data[test_ids]
    y_trainval = labels[train_ids]
    y_test = labels[test_ids]
    test_ds = TensorDataset(
        torch.tensor(X_test, dtype=torch.float32).unsqueeze(1),
        torch.tensor(y_test, dtype=torch.long))
    train_spec = torch.tensor(X_trainval, dtype=torch.float32).unsqueeze(1)
    spec_label = torch.tensor(y_trainval, dtype=torch.long)
    train_data = TensorDataset(train_spec, spec_label)

    test_loader = DataLoader(test_ds, batch_size=batch_size)

    # Unlabeled loader
    unl_ds = TensorDataset(
        torch.tensor(unlabelled_data, dtype=torch.float32).unsqueeze(1))
    unl_loader = DataLoader(unl_ds, batch_size=ul_batch_size, shuffle=True)

    # --- K-fold CV ---
    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)
    results = []

    for fold, (train_idx, val_idx) in enumerate(skf.split(train_spec,
                                                          spec_label), 1):
        print(f"\n=== Fold {fold}/{k_folds} ===")

        #X_train, y_train = X_trainval[train_idx], y_trainval[train_idx]
        #X_val, y_val = X_trainval[val_idx], y_trainval[val_idx]
        train_ds = torch.utils.data.Subset(train_data, train_idx)
        val_ds = torch.utils.data.Subset(train_data, val_idx) 

        #train_ds = TensorDataset(
        #    torch.tensor(X_train, dtype=torch.float32).unsqueeze(1),
        #    torch.tensor(y_train, dtype=torch.long))
        #val_ds = TensorDataset(
        #    torch.tensor(X_val, dtype=torch.float32).unsqueeze(1),
        #    torch.tensor(y_val, dtype=torch.long))

        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_ds, batch_size=batch_size)

        # Model + optimizer
        model = models_class(num_classes=num_classes).to(device)
        if op_alg == 'Adam':
            optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        else:
            optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9,
                                        weight_decay=l2_lambda, nesterov=True)

        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='min', factor=0.25, patience=5, min_lr=1e-6)


        # Train
        model = train_semisupervised(
            model, optimizer, train_loader, unl_loader, lambda_cls=lambda_cls,
            device=device, epochs=epochs, l1_lam=l1_lambda,
            scheduler=scheduler, val_loader=val_loader,
            temp_filename=f"best_model_temp_{fold}.pt", weights=weights)
        train_acc, train_acc_nscv = evaluate(model, train_loader, device)

        # --- Validation accuracy ---
        val_acc, val_acc_nscv = evaluate(model, val_loader, device)

        # --- Test accuracy ---
        test_acc, test_acc_nscv = evaluate(model, test_loader, device)
        print(f"Train accuracy: {train_acc:.5f} ({train_acc_nscv:.5f})| "
              f"Val accuracy: {val_acc:.5f} ({val_acc_nscv:.5f}) | "
              f"Test accuracy: {test_acc:.5f} ({test_acc_nscv:.5f})")

        results.append({'model': model,
                        'val_acc': val_acc,
                        'test_acc': test_acc,
                        'val_acc_nscv': val_acc_nscv,
                        'test_acc_nscv': test_acc_nscv})

    return results, train_ds, test_ds


def evaluate(model, data_loader, device):
    """Evaluate model and return accuracy"""
    correct, total = 0, 0
    corr_nscv, total_nscv = 0, 0
    model.eval()
    with torch.no_grad():
        for xb, yb in data_loader:
            xb, yb = xb.to(device), yb.to(device)
            _, logits, _ = model(xb[:, :, :-1])  # Remove total counts column
            preds = torch.argmax(logits, dim=1)
            correct += (preds == yb).sum().item()
            total += yb.size(0)
            total_nscv += torch.logical_or(yb==2, yb==3).sum()
            corr_nscv += torch.logical_or(
                torch.logical_and(preds==2, yb==2),
                torch.logical_and(preds==3, yb==3)).sum()
        acc_val = correct / total
        acc_nscv_val = corr_nscv/total_nscv
    return acc_val, acc_nscv_val

# %%
class_counts = np.array([1339, 1193, 99, 99])
class_weights = 1/class_counts
class_weights = class_weights/np.sum(class_weights)
print(class_weights**0.5)
# Out:
# [0.18514428 0.19614641 0.68089947 0.68089947]

# %%
all_results, train_data, test_data = semisupervised_kfold_test(
    SemiSupervisedAE,
    np.column_stack([pn_normspec_labelled, pn_counts_labelled]),
    pn_spec_labels,
    np.column_stack([pn_normspec[unlabelled_args], pn_counts[unlabelled_args]]),
    epochs=20, lambda_cls=10, l2_lambda=1.0e-3, l1_lambda=1.0e-4, lr=1.0e-3,
    train_ids=pn_labelled_trainids.astype(int),
    test_ids=pn_labelled_testids.astype(int),
    weights=(class_weights**0.5).tolist())
# Out:
# === Fold 1/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=34.6702, cls=1.1102, recon=16.6618 (16.4093, 16.6798),  smooth=0.6352, latent=26.7582
# Validation loss: 11.2017 | Val acc: 0.7991 |Val acc (NS/BH/CV): 0.0588 |val_class:0.8713 val_recon:1.2434 val_smooth: 0.0694 val_latent:22.7333
# Epoch 1
# Epoch 2:total=9.9300, cls=0.7641, recon=1.3117 (1.1618, 1.3216),  smooth=0.0425, latent=23.2789
# Validation loss: 10.1720 | Val acc: 0.7306 |Val acc (NS/BH/CV): 0.4118 |val_class:0.7938 val_recon:1.4785 val_smooth: 0.0195 val_latent:30.4970
# Epoch 2
# Epoch 3:total=8.5037, cls=0.6416, recon=1.1819 (1.1322, 1.1876),  smooth=0.0352, latent=22.4777
# Validation loss: 19.4331 | Val acc: 0.6347 |Val acc (NS/BH/CV): 0.0588 |val_class:0.9820 val_recon:6.1899 val_smooth: 0.2882 val_latent:9.1671
# Epoch 3
# Epoch 4:total=7.2527, cls=0.5249, recon=1.1418 (1.1254, 1.1428),  smooth=0.0307, latent=22.0210
# Validation loss: 10.1299 | Val acc: 0.8174 |Val acc (NS/BH/CV): 0.0588 |val_class:0.6783 val_recon:1.9281 val_smooth: 0.0870 val_latent:14.2519
# Epoch 4
# Epoch 5:total=6.4244, cls=0.4464, recon=1.1189 (1.1125, 1.1201),  smooth=0.0283, latent=21.8522
# Validation loss: 8.8534 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.2941 |val_class:0.6113 val_recon:1.5360 val_smooth: 0.0651 val_latent:15.3488
# Epoch 5
# Epoch 6:total=5.9837, cls=0.4056, recon=1.0914 (1.0589, 1.0937),  smooth=0.0276, latent=21.3486
# Validation loss: 8.4048 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.2353 |val_class:0.6656 val_recon:0.8654 val_smooth: 0.0322 val_latent:20.3698
# Epoch 6
# Epoch 7:total=5.2488, cls=0.3349, recon=1.0809 (1.0477, 1.0837),  smooth=0.0256, latent=20.5458
# Validation loss: 18.2321 | Val acc: 0.6347 |Val acc (NS/BH/CV): 0.1176 |val_class:1.2556 val_recon:3.7486 val_smooth: 0.1373 val_latent:11.0255
# Epoch 7
# Epoch 8:total=4.5901, cls=0.2705, recon=1.0694 (1.0349, 1.0723),  smooth=0.0251, latent=20.1042
# Validation loss: 9.5271 | Val acc: 0.8265 |Val acc (NS/BH/CV): 0.1765 |val_class:0.7731 val_recon:0.9076 val_smooth: 0.0324 val_latent:18.1526
# Epoch 8
# Epoch 9:total=4.0388, cls=0.2169, recon=1.0626 (1.0032, 1.0691),  smooth=0.0241, latent=19.6415
# Validation loss: 10.2820 | Val acc: 0.7626 |Val acc (NS/BH/CV): 0.4118 |val_class:0.7811 val_recon:1.3672 val_smooth: 0.0542 val_latent:14.7351
# Epoch 9
# Epoch 10:total=3.7159, cls=0.1855, recon=1.0540 (0.9941, 1.0556),  smooth=0.0240, latent=19.2347
# Validation loss: 10.1471 | Val acc: 0.8082 |Val acc (NS/BH/CV): 0.3529 |val_class:0.8302 val_recon:0.9036 val_smooth: 0.0376 val_latent:16.7471
# Epoch 10
# Epoch 11:total=3.8284, cls=0.1981, recon=1.0529 (0.9826, 1.0565),  smooth=0.0226, latent=18.6249
# Validation loss: 9.5488 | Val acc: 0.8219 |Val acc (NS/BH/CV): 0.2941 |val_class:0.7898 val_recon:0.8313 val_smooth: 0.0252 val_latent:17.6272
# Epoch 11
# Epoch 12:total=3.3966, cls=0.1557, recon=1.0478 (0.9882, 1.0452),  smooth=0.0223, latent=17.8442
# Validation loss: 12.6996 | Val acc: 0.7763 |Val acc (NS/BH/CV): 0.2941 |val_class:0.9693 val_recon:1.8055 val_smooth: 0.0638 val_latent:12.4606
# Learning rate changed to 0.000250
# Epoch 12
# Epoch 13:total=2.8541, cls=0.1042, recon=1.0351 (0.9736, 1.0390),  smooth=0.0209, latent=17.6430
# Validation loss: 9.2606 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.2941 |val_class:0.7604 val_recon:0.8444 val_smooth: 0.0245 val_latent:17.1984
# Epoch 13
# Epoch 14:total=2.7263, cls=0.0920, recon=1.0323 (0.9464, 1.0384),  smooth=0.0206, latent=17.6716
# Validation loss: 9.1258 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.2941 |val_class:0.7492 val_recon:0.8256 val_smooth: 0.0241 val_latent:17.3345
# Epoch 14
# Epoch 15:total=2.7936, cls=0.0989, recon=1.0323 (0.9728, 1.0358),  smooth=0.0205, latent=17.6748
# Validation loss: 9.5538 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.2353 |val_class:0.7876 val_recon:0.8538 val_smooth: 0.0258 val_latent:16.5870
# Epoch 15
# Epoch 16:total=2.7143, cls=0.0914, recon=1.0309 (0.9411, 1.0385),  smooth=0.0203, latent=17.7496
# Validation loss: 9.5773 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.4118 |val_class:0.7894 val_recon:0.8447 val_smooth: 0.0273 val_latent:16.6475
# Epoch 16
# Epoch 17:total=2.5714, cls=0.0777, recon=1.0264 (0.9399, 1.0325),  smooth=0.0202, latent=17.6893
# Validation loss: 10.4102 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.2941 |val_class:0.8765 val_recon:0.8315 val_smooth: 0.0248 val_latent:17.2232
# Epoch 17
# Epoch 18:total=2.5766, cls=0.0783, recon=1.0281 (0.9721, 1.0328),  smooth=0.0200, latent=17.7173
# Validation loss: 10.9063 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.1765 |val_class:0.9215 val_recon:0.8640 val_smooth: 0.0264 val_latent:16.3895
# Learning rate changed to 0.000063
# Early stopping at epoch 17
# Train accuracy: 0.92206 | Val accuracy: 0.85845 | Test accuracy: 0.85219
#
# === Fold 2/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=72.6445, cls=1.0993, recon=47.1920 (47.7974, 47.1593),  smooth=1.3918, latent=17.9390
# Validation loss: 15.2348 | Val acc: 0.7078 |Val acc (NS/BH/CV): 0.0588 |val_class:0.9321 val_recon:3.2515 val_smooth: 0.2128 val_latent:10.3473
# Epoch 1
# Epoch 2:total=10.4246, cls=0.8160, recon=1.3370 (1.2635, 1.3419),  smooth=0.0385, latent=18.9761
# Validation loss: 13.1528 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.2353 |val_class:0.7677 val_recon:3.3810 val_smooth: 0.1560 val_latent:10.0744
# Epoch 2
# Epoch 3:total=8.8669, cls=0.6777, recon=1.2220 (1.2317, 1.2206),  smooth=0.0323, latent=18.8061
# Validation loss: 12.2433 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.2353 |val_class:0.6957 val_recon:3.2790 val_smooth: 0.1470 val_latent:10.1635
# Epoch 3
# Epoch 4:total=7.9304, cls=0.5893, recon=1.1886 (1.2397, 1.1863),  smooth=0.0303, latent=18.8079
# Validation loss: 19.9949 | Val acc: 0.5799 |Val acc (NS/BH/CV): 0.4706 |val_class:1.6826 val_recon:2.5418 val_smooth: 0.0065 val_latent:33.3048
# Epoch 4
# Epoch 5:total=7.0016, cls=0.4992, recon=1.1705 (1.2635, 1.1659),  smooth=0.0292, latent=18.8733
# Validation loss: 11.9090 | Val acc: 0.8493 |Val acc (NS/BH/CV): 0.1176 |val_class:0.7487 val_recon:2.7669 val_smooth: 0.1114 val_latent:11.0355
# Epoch 5
# Epoch 6:total=6.4254, cls=0.4456, recon=1.1461 (1.1677, 1.1448),  smooth=0.0274, latent=18.9954
# Validation loss: 10.2058 | Val acc: 0.8813 |Val acc (NS/BH/CV): 0.4118 |val_class:0.7113 val_recon:1.8047 val_smooth: 0.0744 val_latent:13.0741
# Epoch 6
# Epoch 7:total=5.8656, cls=0.3915, recon=1.1322 (1.1469, 1.1300),  smooth=0.0267, latent=18.9540
# Validation loss: 9.1276 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.5294 |val_class:0.7052 val_recon:1.1049 val_smooth: 0.0421 val_latent:16.2298
# Epoch 7
# Epoch 8:total=5.0044, cls=0.3079, recon=1.1169 (1.1339, 1.1138),  smooth=0.0257, latent=18.6835
# Validation loss: 14.8843 | Val acc: 0.6530 |Val acc (NS/BH/CV): 0.2353 |val_class:1.3098 val_recon:1.0055 val_smooth: 0.0226 val_latent:21.7018
# Epoch 8
# Epoch 9:total=4.7818, cls=0.2882, recon=1.0980 (1.0817, 1.0998),  smooth=0.0249, latent=18.5961
# Validation loss: 14.8318 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.2941 |val_class:0.9065 val_recon:3.9401 val_smooth: 0.1281 val_latent:10.0873
# Epoch 9
# Epoch 10:total=4.3819, cls=0.2496, recon=1.0923 (1.1000, 1.0937),  smooth=0.0239, latent=18.2489
# Validation loss: 12.2267 | Val acc: 0.8630 |Val acc (NS/BH/CV): 0.2941 |val_class:0.8163 val_recon:2.7004 val_smooth: 0.0816 val_latent:10.9321
# Epoch 10
# Epoch 11:total=3.9331, cls=0.2071, recon=1.0745 (1.0421, 1.0764),  smooth=0.0232, latent=17.8856
# Validation loss: 15.7915 | Val acc: 0.7489 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2991 val_recon:1.6280 val_smooth: 0.0622 val_latent:13.0603
# Epoch 11
# Epoch 12:total=4.0435, cls=0.2192, recon=1.0672 (1.0514, 1.0671),  smooth=0.0229, latent=17.3285
# Validation loss: 17.7489 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.2353 |val_class:1.0086 val_recon:5.6457 val_smooth: 0.1470 val_latent:8.1103
# Epoch 12
# Epoch 13:total=3.4137, cls=0.1577, recon=1.0601 (1.0527, 1.0618),  smooth=0.0221, latent=16.4497
# Validation loss: 12.7311 | Val acc: 0.8630 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0206 val_recon:1.4770 val_smooth: 0.0496 val_latent:12.2588
# Learning rate changed to 0.000250
# Epoch 13
# Epoch 14:total=2.9645, cls=0.1144, recon=1.0519 (1.0090, 1.0545),  smooth=0.0213, latent=16.3147
# Validation loss: 11.5726 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9747 val_recon:0.9535 val_smooth: 0.0318 val_latent:15.1091
# Epoch 14
# Epoch 15:total=2.8733, cls=0.1058, recon=1.0477 (1.0109, 1.0500),  smooth=0.0212, latent=16.4271
# Validation loss: 11.1600 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9310 val_recon:0.9721 val_smooth: 0.0324 val_latent:14.8313
# Epoch 15
# Epoch 16:total=2.7788, cls=0.0966, recon=1.0470 (1.0267, 1.0493),  smooth=0.0210, latent=16.4429
# Validation loss: 11.6704 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9946 val_recon:0.9091 val_smooth: 0.0260 val_latent:16.0698
# Epoch 16
# Epoch 17:total=2.7366, cls=0.0928, recon=1.0443 (1.0007, 1.0471),  smooth=0.0209, latent=16.4797
# Validation loss: 12.1928 | Val acc: 0.8493 |Val acc (NS/BH/CV): 0.4706 |val_class:1.0332 val_recon:0.9768 val_smooth: 0.0330 val_latent:15.1835
# Epoch 17
# Epoch 18:total=2.6089, cls=0.0803, recon=1.0425 (1.0174, 1.0442),  smooth=0.0209, latent=16.4427
# Validation loss: 11.2274 | Val acc: 0.8721 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9469 val_recon:0.9250 val_smooth: 0.0279 val_latent:15.4001
# Epoch 18
# Epoch 19:total=2.6243, cls=0.0824, recon=1.0410 (0.9959, 1.0431),  smooth=0.0205, latent=16.4400
# Validation loss: 11.5031 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9768 val_recon:0.9159 val_smooth: 0.0266 val_latent:15.9480
# Learning rate changed to 0.000063
# Early stopping at epoch 18
# Train accuracy: 0.92002 | Val accuracy: 0.85388 | Test accuracy: 0.84672
#
# === Fold 3/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=117.0490, cls=1.2395, recon=84.8539 (85.3703, 84.8255),  smooth=1.9268, latent=12.5769
# Validation loss: 13.7932 | Val acc: 0.7615 |Val acc (NS/BH/CV): 0.0625 |val_class:1.0234 val_recon:2.0018 val_smooth: 0.1026 val_latent:11.8945
# Epoch 1
# Epoch 2:total=11.8922, cls=0.9789, recon=1.2663 (1.1833, 1.2710),  smooth=0.0298, latent=18.2519
# Validation loss: 11.6313 | Val acc: 0.7477 |Val acc (NS/BH/CV): 0.1875 |val_class:0.9040 val_recon:1.4541 val_smooth: 0.0604 val_latent:12.7071
# Epoch 2
# Epoch 3:total=10.2998, cls=0.8302, recon=1.1839 (1.1923, 1.1831),  smooth=0.0277, latent=17.4788
# Validation loss: 11.4534 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.1875 |val_class:0.8425 val_recon:1.7949 val_smooth: 0.0702 val_latent:11.2150
# Epoch 3
# Epoch 4:total=9.2909, cls=0.7333, recon=1.1569 (1.1350, 1.1575),  smooth=0.0263, latent=17.1989
# Validation loss: 13.1637 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.2500 |val_class:0.7629 val_recon:3.7949 val_smooth: 0.1211 val_latent:8.3147
# Epoch 4
# Epoch 5:total=8.4688, cls=0.6524, recon=1.1534 (1.1990, 1.1516),  smooth=0.0254, latent=16.9162
# Validation loss: 9.5581 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.2500 |val_class:0.6403 val_recon:1.9260 val_smooth: 0.0697 val_latent:10.7455
# Epoch 5
# Epoch 6:total=7.6617, cls=0.5726, recon=1.1482 (1.1759, 1.1473),  smooth=0.0250, latent=16.7537
# Validation loss: 9.2986 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7267 val_recon:1.1197 val_smooth: 0.0376 val_latent:14.0810
# Epoch 6
# Epoch 7:total=7.1777, cls=0.5257, recon=1.1348 (1.1393, 1.1346),  smooth=0.0247, latent=16.6769
# Validation loss: 10.8388 | Val acc: 0.7523 |Val acc (NS/BH/CV): 0.1875 |val_class:0.8493 val_recon:1.3180 val_smooth: 0.0493 val_latent:12.6323
# Epoch 7
# Epoch 8:total=6.7259, cls=0.4817, recon=1.1232 (1.1367, 1.1227),  smooth=0.0246, latent=16.4250
# Validation loss: 8.8759 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.1875 |val_class:0.6630 val_recon:1.2013 val_smooth: 0.0509 val_latent:12.8352
# Epoch 8
# Epoch 9:total=6.0567, cls=0.4170, recon=1.1076 (1.0857, 1.1084),  smooth=0.0241, latent=15.4410
# Validation loss: 8.4221 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.2500 |val_class:0.6678 val_recon:0.9366 val_smooth: 0.0269 val_latent:14.6005
# Epoch 9
# Epoch 10:total=5.4103, cls=0.3556, recon=1.0849 (1.0370, 1.0876),  smooth=0.0231, latent=15.1992
# Validation loss: 11.9571 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.1875 |val_class:0.7793 val_recon:2.8235 val_smooth: 0.0808 val_latent:8.4425
# Epoch 10
# Epoch 11:total=5.0677, cls=0.3221, recon=1.0742 (1.0508, 1.0765),  smooth=0.0233, latent=14.8688
# Validation loss: 11.3351 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.2500 |val_class:0.6703 val_recon:3.1503 val_smooth: 0.0950 val_latent:7.9165
# Epoch 11
# Epoch 12:total=4.5280, cls=0.2704, recon=1.0622 (1.0085, 1.0659),  smooth=0.0223, latent=14.3563
# Validation loss: 10.4668 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.1875 |val_class:0.8793 val_recon:0.8637 val_smooth: 0.0270 val_latent:14.5296
# Epoch 12
# Epoch 13:total=4.1870, cls=0.2377, recon=1.0514 (0.9806, 1.0574),  smooth=0.0220, latent=14.1260
# Validation loss: 9.7864 | Val acc: 0.7385 |Val acc (NS/BH/CV): 0.5625 |val_class:0.8086 val_recon:0.9744 val_smooth: 0.0185 val_latent:16.5709
# Epoch 13
# Epoch 14:total=4.3534, cls=0.2553, recon=1.0461 (0.9693, 1.0518),  smooth=0.0216, latent=13.7899
# Validation loss: 14.6196 | Val acc: 0.7110 |Val acc (NS/BH/CV): 0.2500 |val_class:1.2853 val_recon:1.0604 val_smooth: 0.0164 val_latent:17.3056
# Epoch 14
# Epoch 15:total=3.9703, cls=0.2180, recon=1.0384 (0.9514, 1.0444),  smooth=0.0214, latent=13.3404
# Validation loss: 10.9164 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7854 val_recon:1.9654 val_smooth: 0.0564 val_latent:8.3937
# Learning rate changed to 0.000250
# Epoch 15
# Epoch 16:total=3.2621, cls=0.1491, recon=1.0303 (0.9428, 1.0360),  smooth=0.0203, latent=13.1464
# Validation loss: 9.7004 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.5000 |val_class:0.8072 val_recon:0.8972 val_smooth: 0.0194 val_latent:13.5094
# Epoch 16
# Epoch 17:total=3.2812, cls=0.1511, recon=1.0331 (0.9420, 1.0397),  smooth=0.0199, latent=13.2005
# Validation loss: 9.7937 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8169 val_recon:0.8686 val_smooth: 0.0219 val_latent:13.1314
# Epoch 17
# Epoch 18:total=3.1470, cls=0.1380, recon=1.0307 (0.9604, 1.0370),  smooth=0.0199, latent=13.2045
# Validation loss: 9.3568 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7744 val_recon:0.8758 val_smooth: 0.0199 val_latent:13.7165
# Epoch 18
# Epoch 19:total=3.1185, cls=0.1355, recon=1.0280 (0.9385, 1.0331),  smooth=0.0199, latent=13.2014
# Validation loss: 9.8698 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8240 val_recon:0.8658 val_smooth: 0.0227 val_latent:12.9802
# Epoch 19
# Epoch 20:total=3.0117, cls=0.1251, recon=1.0281 (0.9402, 1.0345),  smooth=0.0196, latent=13.2154
# Validation loss: 9.2946 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7667 val_recon:0.9207 val_smooth: 0.0169 val_latent:14.7806
# Train accuracy: 0.98574 | Val accuracy: 0.85780 | Test accuracy: 0.85949
#
# === Fold 4/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=27.4604, cls=1.0045, recon=11.9373 (11.1637, 11.9894),  smooth=0.4920, latent=28.7997
# Validation loss: 11.3212 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.1875 |val_class:0.8230 val_recon:1.4077 val_smooth: 0.1135 val_latent:19.2251
# Epoch 1
# Epoch 2:total=10.1664, cls=0.7635, recon=1.4199 (1.1180, 1.4410),  smooth=0.0562, latent=20.3089
# Validation loss: 10.0745 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.3125 |val_class:0.7252 val_recon:1.3330 val_smooth: 0.0945 val_latent:14.3019
# Epoch 2
# Epoch 3:total=8.2141, cls=0.6078, recon=1.1990 (1.1087, 1.2053),  smooth=0.0387, latent=18.5444
# Validation loss: 9.4002 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7280 val_recon:1.2797 val_smooth: 0.0286 val_latent:20.6961
# Epoch 3
# Epoch 4:total=7.3371, cls=0.5299, recon=1.1419 (1.0666, 1.1489),  smooth=0.0343, latent=18.1450
# Validation loss: 8.9750 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7044 val_recon:1.0582 val_smooth: 0.0317 val_latent:17.9904
# Epoch 4
# Epoch 5:total=6.6667, cls=0.4715, recon=1.0933 (1.0184, 1.0995),  smooth=0.0301, latent=17.2644
# Validation loss: 9.0401 | Val acc: 0.8899 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7149 val_recon:1.0062 val_smooth: 0.0326 val_latent:16.4360
# Epoch 5
# Epoch 6:total=5.7917, cls=0.3893, recon=1.0656 (1.0028, 1.0696),  smooth=0.0273, latent=16.2824
# Validation loss: 10.0486 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8107 val_recon:1.2048 val_smooth: 0.0171 val_latent:19.8013
# Epoch 6
# Epoch 7:total=5.2854, cls=0.3404, recon=1.0578 (0.9852, 1.0613),  smooth=0.0261, latent=15.5643
# Validation loss: 10.3014 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.5000 |val_class:0.8393 val_recon:1.1562 val_smooth: 0.0183 val_latent:18.9313
# Epoch 7
# Epoch 8:total=4.7854, cls=0.2933, recon=1.0432 (0.9545, 1.0495),  smooth=0.0243, latent=14.7767
# Validation loss: 13.8250 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.0625 |val_class:1.1952 val_recon:1.0313 val_smooth: 0.0273 val_latent:16.0913
# Epoch 8
# Epoch 9:total=4.1956, cls=0.2362, recon=1.0348 (0.9516, 1.0402),  smooth=0.0230, latent=14.5326
# Validation loss: 10.5849 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8798 val_recon:0.9848 val_smooth: 0.0232 val_latent:15.1815
# Epoch 9
# Epoch 10:total=3.8881, cls=0.2065, recon=1.0303 (0.9686, 1.0351),  smooth=0.0223, latent=14.4965
# Validation loss: 9.4887 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7625 val_recon:1.1040 val_smooth: 0.0188 val_latent:14.4241
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=3.5263, cls=0.1717, recon=1.0257 (0.9522, 1.0317),  smooth=0.0212, latent=14.2861
# Validation loss: 9.9360 | Val acc: 0.8761 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8176 val_recon:0.9283 val_smooth: 0.0260 val_latent:14.1344
# Epoch 11
# Epoch 12:total=3.1918, cls=0.1388, recon=1.0218 (0.9512, 1.0259),  smooth=0.0211, latent=14.5160
# Validation loss: 10.0694 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8343 val_recon:0.9432 val_smooth: 0.0211 val_latent:15.2704
# Epoch 12
# Epoch 13:total=3.2481, cls=0.1449, recon=1.0194 (0.9430, 1.0259),  smooth=0.0209, latent=14.5863
# Validation loss: 10.0355 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8301 val_recon:0.9503 val_smooth: 0.0212 val_latent:15.1512
# Epoch 13
# Epoch 14:total=3.1800, cls=0.1386, recon=1.0166 (0.9245, 1.0226),  smooth=0.0206, latent=14.6907
# Validation loss: 10.0117 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8290 val_recon:0.9423 val_smooth: 0.0207 val_latent:15.5912
# Epoch 14
# Epoch 15:total=3.1764, cls=0.1385, recon=1.0171 (0.9328, 1.0243),  smooth=0.0204, latent=14.7237
# Validation loss: 10.3468 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.5000 |val_class:0.8620 val_recon:0.9313 val_smooth: 0.0224 val_latent:14.9670
# Epoch 15
# Epoch 16:total=2.9752, cls=0.1187, recon=1.0151 (0.9298, 1.0209),  smooth=0.0203, latent=14.6889
# Validation loss: 10.8486 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9139 val_recon:0.9276 val_smooth: 0.0211 val_latent:15.1561
# Learning rate changed to 0.000063
# Early stopping at epoch 15
# Train accuracy: 0.85794 | Val accuracy: 0.86239 | Test accuracy: 0.80839
#
# === Fold 5/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=33.7305, cls=1.0345, recon=14.3587 (14.1682, 14.3746),  smooth=0.8468, latent=30.4273
# Validation loss: 13.3222 | Val acc: 0.6789 |Val acc (NS/BH/CV): 0.3750 |val_class:1.0597 val_recon:1.6800 val_smooth: 0.0486 val_latent:30.1845
# Epoch 1
# Epoch 2:total=9.6230, cls=0.6990, recon=1.4594 (1.1562, 1.4758),  smooth=0.0620, latent=24.3581
# Validation loss: 13.6455 | Val acc: 0.6972 |Val acc (NS/BH/CV): 0.1875 |val_class:1.0897 val_recon:2.0023 val_smooth: 0.0181 val_latent:35.2482
# Epoch 2
# Epoch 3:total=8.2452, cls=0.5958, recon=1.2520 (1.0967, 1.2621),  smooth=0.0482, latent=22.6520
# Validation loss: 10.2944 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8329 val_recon:1.0045 val_smooth: 0.0406 val_latent:23.0030
# Epoch 3
# Epoch 4:total=7.4325, cls=0.5341, recon=1.1500 (1.0643, 1.1582),  smooth=0.0387, latent=21.7212
# Validation loss: 11.2484 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.1875 |val_class:0.9346 val_recon:0.9412 val_smooth: 0.0406 val_latent:21.9207
# Epoch 4
# Epoch 5:total=6.3094, cls=0.4281, recon=1.1303 (1.0670, 1.1341),  smooth=0.0342, latent=21.0379
# Validation loss: 17.2840 | Val acc: 0.6789 |Val acc (NS/BH/CV): 0.0000 |val_class:1.5266 val_recon:1.1757 val_smooth: 0.0282 val_latent:23.4483
# Epoch 5
# Epoch 6:total=5.8409, cls=0.3867, recon=1.1008 (1.0482, 1.1034),  smooth=0.0316, latent=20.0521
# Validation loss: 11.1016 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.1875 |val_class:0.9205 val_recon:0.9423 val_smooth: 0.0398 val_latent:17.0027
# Epoch 6
# Epoch 7:total=5.3423, cls=0.3418, recon=1.0802 (1.0097, 1.0853),  smooth=0.0284, latent=19.1704
# Validation loss: 13.1456 | Val acc: 0.6560 |Val acc (NS/BH/CV): 0.5000 |val_class:1.1356 val_recon:0.8662 val_smooth: 0.0364 val_latent:18.8013
# Epoch 7
# Epoch 8:total=4.6956, cls=0.2800, recon=1.0664 (1.0114, 1.0712),  smooth=0.0269, latent=18.6750
# Validation loss: 13.1321 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.1250 |val_class:1.1370 val_recon:0.9886 val_smooth: 0.0211 val_latent:19.6643
# Epoch 8
# Epoch 9:total=4.4391, cls=0.2557, recon=1.0592 (0.9893, 1.0652),  smooth=0.0260, latent=18.3174
# Validation loss: 13.0722 | Val acc: 0.7294 |Val acc (NS/BH/CV): 0.6875 |val_class:1.1317 val_recon:0.9975 val_smooth: 0.0190 val_latent:22.2128
# Learning rate changed to 0.000250
# Epoch 9
# Epoch 10:total=3.7141, cls=0.1856, recon=1.0496 (0.9832, 1.0543),  smooth=0.0245, latent=17.9745
# Validation loss: 9.7404 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8044 val_recon:0.8735 val_smooth: 0.0260 val_latent:17.7219
# Epoch 10
# Epoch 11:total=3.4848, cls=0.1630, recon=1.0470 (0.9778, 1.0515),  smooth=0.0244, latent=18.1132
# Validation loss: 10.9843 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9321 val_recon:0.8700 val_smooth: 0.0228 val_latent:19.4104
# Epoch 11
# Epoch 12:total=3.5017, cls=0.1650, recon=1.0465 (0.9837, 1.0505),  smooth=0.0241, latent=18.1507
# Validation loss: 9.8865 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8221 val_recon:0.9014 val_smooth: 0.0198 val_latent:20.2397
# Epoch 12
# Epoch 13:total=3.2951, cls=0.1443, recon=1.0489 (0.9836, 1.0499),  smooth=0.0240, latent=18.1586
# Validation loss: 10.0606 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8380 val_recon:0.8587 val_smooth: 0.0258 val_latent:17.6874
# Epoch 13
# Epoch 14:total=3.2481, cls=0.1405, recon=1.0441 (0.9706, 1.0493),  smooth=0.0236, latent=18.2585
# Validation loss: 11.0932 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9311 val_recon:0.8981 val_smooth: 0.0322 val_latent:16.7259
# Epoch 14
# Epoch 15:total=3.2567, cls=0.1422, recon=1.0389 (0.9625, 1.0442),  smooth=0.0232, latent=18.2244
# Validation loss: 10.5649 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.5000 |val_class:0.8894 val_recon:0.8587 val_smooth: 0.0249 val_latent:18.0326
# Epoch 15
# Epoch 16:total=3.1211, cls=0.1289, recon=1.0399 (0.9615, 1.0461),  smooth=0.0229, latent=18.1710
# Validation loss: 10.3742 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8717 val_recon:0.8494 val_smooth: 0.0244 val_latent:18.2316
# Learning rate changed to 0.000063
# Epoch 16
# Epoch 17:total=2.9869, cls=0.1159, recon=1.0350 (0.9589, 1.0397),  smooth=0.0230, latent=18.1458
# Validation loss: 10.8071 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.5000 |val_class:0.9149 val_recon:0.8536 val_smooth: 0.0240 val_latent:18.3308
# Epoch 17
# Epoch 18:total=2.9819, cls=0.1157, recon=1.0346 (0.9472, 1.0419),  smooth=0.0227, latent=18.2129
# Validation loss: 10.4099 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8765 val_recon:0.8538 val_smooth: 0.0227 val_latent:18.5403
# Epoch 18
# Epoch 19:total=2.9239, cls=0.1097, recon=1.0367 (0.9380, 1.0415),  smooth=0.0226, latent=18.1791
# Validation loss: 10.6881 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9019 val_recon:0.8500 val_smooth: 0.0255 val_latent:17.9874
# Epoch 19
# Epoch 20:total=2.8177, cls=0.0993, recon=1.0357 (0.9574, 1.0405),  smooth=0.0225, latent=18.2342
# Validation loss: 10.5714 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8911 val_recon:0.8516 val_smooth: 0.0246 val_latent:17.8903
# Train accuracy: 0.98727 | Val accuracy: 0.86239 | Test accuracy: 0.86861
#
# === Fold 6/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=94.3312, cls=1.1354, recon=66.7200 (67.2883, 66.6870),  smooth=1.5723, latent=16.3201
# Validation loss: 12.2829 | Val acc: 0.7477 |Val acc (NS/BH/CV): 0.0625 |val_class:0.9737 val_recon:1.5848 val_smooth: 0.0418 val_latent:24.4373
# Epoch 1
# Epoch 2:total=10.4153, cls=0.8202, recon=1.3091 (1.2018, 1.3164),  smooth=0.0364, latent=21.4366
# Validation loss: 10.0288 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.1875 |val_class:0.8067 val_recon:1.1500 val_smooth: 0.0270 val_latent:22.3290
# Epoch 2
# Epoch 3:total=9.0359, cls=0.7012, recon=1.1884 (1.1578, 1.1909),  smooth=0.0295, latent=20.8584
# Validation loss: 10.5937 | Val acc: 0.7615 |Val acc (NS/BH/CV): 0.0000 |val_class:0.8286 val_recon:1.2448 val_smooth: 0.0527 val_latent:16.3507
# Epoch 3
# Epoch 4:total=8.4177, cls=0.6437, recon=1.1569 (1.1210, 1.1602),  smooth=0.0283, latent=20.5996
# Validation loss: 9.3717 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.3125 |val_class:0.7476 val_recon:1.0629 val_smooth: 0.0291 val_latent:20.9902
# Epoch 4
# Epoch 5:total=7.5179, cls=0.5559, recon=1.1453 (1.1281, 1.1509),  smooth=0.0271, latent=20.2664
# Validation loss: 8.5404 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.4375 |val_class:0.6640 val_recon:1.0507 val_smooth: 0.0309 val_latent:18.7910
# Epoch 5
# Epoch 6:total=6.4997, cls=0.4554, recon=1.1373 (1.1181, 1.1379),  smooth=0.0265, latent=20.1968
# Validation loss: 11.7762 | Val acc: 0.6697 |Val acc (NS/BH/CV): 0.1250 |val_class:0.9839 val_recon:1.1682 val_smooth: 0.0223 val_latent:22.2756
# Epoch 6
# Epoch 7:total=6.0302, cls=0.4108, recon=1.1260 (1.0746, 1.1298),  smooth=0.0252, latent=19.9510
# Validation loss: 10.0860 | Val acc: 0.7752 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8170 val_recon:1.1928 val_smooth: 0.0174 val_latent:23.8800
# Epoch 7
# Epoch 8:total=5.6512, cls=0.3745, recon=1.1150 (1.0712, 1.1184),  smooth=0.0247, latent=19.1030
# Validation loss: 9.4317 | Val acc: 0.7569 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7543 val_recon:1.1773 val_smooth: 0.0163 val_latent:22.5835
# Epoch 8
# Epoch 9:total=5.0952, cls=0.3210, recon=1.1037 (1.0682, 1.1049),  smooth=0.0237, latent=18.1460
# Validation loss: 8.8451 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.5625 |val_class:0.6914 val_recon:1.0648 val_smooth: 0.0323 val_latent:16.0415
# Epoch 9
# Epoch 10:total=4.3208, cls=0.2459, recon=1.0872 (1.0209, 1.0910),  smooth=0.0229, latent=17.4036
# Validation loss: 9.2911 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.1875 |val_class:0.7038 val_recon:1.2812 val_smooth: 0.0430 val_latent:13.3279
# Epoch 10
# Epoch 11:total=4.1978, cls=0.2354, recon=1.0747 (1.0031, 1.0827),  smooth=0.0224, latent=16.8674
# Validation loss: 12.3566 | Val acc: 0.6972 |Val acc (NS/BH/CV): 0.4375 |val_class:1.0334 val_recon:1.3435 val_smooth: 0.0127 val_latent:22.0355
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=3.5616, cls=0.1733, recon=1.0677 (1.0019, 1.0722),  smooth=0.0215, latent=16.5521
# Validation loss: 9.0482 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7237 val_recon:1.0006 val_smooth: 0.0266 val_latent:15.3619
# Epoch 12
# Epoch 13:total=3.4249, cls=0.1602, recon=1.0618 (0.9735, 1.0673),  smooth=0.0215, latent=16.5025
# Validation loss: 9.0648 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7333 val_recon:0.9556 val_smooth: 0.0231 val_latent:16.5390
# Epoch 13
# Epoch 14:total=3.3370, cls=0.1519, recon=1.0594 (0.9772, 1.0647),  smooth=0.0213, latent=16.5008
# Validation loss: 9.0175 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7283 val_recon:1.0010 val_smooth: 0.0187 val_latent:17.5906
# Epoch 14
# Epoch 15:total=3.2433, cls=0.1432, recon=1.0533 (0.9653, 1.0600),  smooth=0.0213, latent=16.3761
# Validation loss: 9.5188 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7785 val_recon:0.9903 val_smooth: 0.0197 val_latent:17.5872
# Epoch 15
# Epoch 16:total=3.0787, cls=0.1268, recon=1.0548 (0.9718, 1.0611),  smooth=0.0210, latent=16.4133
# Validation loss: 10.0825 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.5625 |val_class:0.8048 val_recon:1.1514 val_smooth: 0.0340 val_latent:13.4426
# Epoch 16
# Epoch 17:total=3.0741, cls=0.1269, recon=1.0497 (0.9718, 1.0541),  smooth=0.0210, latent=16.2926
# Validation loss: 9.4949 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.3125 |val_class:0.7772 val_recon:0.9542 val_smooth: 0.0223 val_latent:16.0816
# Learning rate changed to 0.000063
# Early stopping at epoch 16
# Train accuracy: 0.86609 | Val accuracy: 0.81651 | Test accuracy: 0.82482
#
# === Fold 7/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=51.3314, cls=1.0766, recon=29.5579 (29.8630, 29.5394),  smooth=1.0463, latent=21.7668
# Validation loss: 11.4187 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.2500 |val_class:0.8864 val_recon:1.3367 val_smooth: 0.0674 val_latent:20.5171
# Epoch 1
# Epoch 2:total=9.5821, cls=0.7465, recon=1.2135 (1.1301, 1.2188),  smooth=0.0358, latent=22.7378
# Validation loss: 12.9206 | Val acc: 0.5917 |Val acc (NS/BH/CV): 0.1875 |val_class:1.0918 val_recon:1.0718 val_smooth: 0.0384 val_latent:24.1752
# Epoch 2
# Epoch 3:total=8.4630, cls=0.6427, recon=1.1538 (1.0760, 1.1583),  smooth=0.0336, latent=22.2613
# Validation loss: 9.5912 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7617 val_recon:1.2019 val_smooth: 0.0221 val_latent:26.5505
# Epoch 3
# Epoch 4:total=7.3025, cls=0.5305, recon=1.1340 (1.0553, 1.1423),  smooth=0.0316, latent=21.4475
# Validation loss: 8.8255 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.5000 |val_class:0.6948 val_recon:1.0987 val_smooth: 0.0227 val_latent:24.4313
# Epoch 4
# Epoch 5:total=6.2786, cls=0.4318, recon=1.1168 (1.0656, 1.1200),  smooth=0.0295, latent=20.8960
# Validation loss: 12.3807 | Val acc: 0.6284 |Val acc (NS/BH/CV): 0.6250 |val_class:1.0338 val_recon:1.3110 val_smooth: 0.0175 val_latent:27.9272
# Epoch 5
# Epoch 6:total=5.7512, cls=0.3823, recon=1.0960 (1.0083, 1.1020),  smooth=0.0281, latent=20.5171
# Validation loss: 10.8159 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.2500 |val_class:0.8889 val_recon:1.0101 val_smooth: 0.0368 val_latent:18.0334
# Epoch 6
# Epoch 7:total=5.4444, cls=0.3536, recon=1.0812 (0.9900, 1.0891),  smooth=0.0275, latent=19.7276
# Validation loss: 13.2673 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.1875 |val_class:1.1277 val_recon:1.0677 val_smooth: 0.0372 val_latent:16.5011
# Epoch 7
# Epoch 8:total=4.8237, cls=0.2935, recon=1.0698 (0.9878, 1.0757),  smooth=0.0266, latent=18.4916
# Validation loss: 11.0946 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.3125 |val_class:0.9288 val_recon:0.9694 val_smooth: 0.0284 val_latent:16.8972
# Epoch 8
# Epoch 9:total=4.1373, cls=0.2272, recon=1.0585 (0.9689, 1.0654),  smooth=0.0252, latent=17.8570
# Validation loss: 11.3355 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.1250 |val_class:0.9558 val_recon:0.9929 val_smooth: 0.0228 val_latent:19.6574
# Epoch 9
# Epoch 10:total=3.8278, cls=0.1970, recon=1.0564 (0.9810, 1.0625),  smooth=0.0246, latent=17.1750
# Validation loss: 11.0984 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9233 val_recon:1.0420 val_smooth: 0.0269 val_latent:15.1088
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=3.2513, cls=0.1419, recon=1.0441 (0.9546, 1.0502),  smooth=0.0233, latent=16.5218
# Validation loss: 10.3396 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8586 val_recon:0.9190 val_smooth: 0.0280 val_latent:16.0397
# Epoch 11
# Epoch 12:total=3.0966, cls=0.1268, recon=1.0434 (0.9565, 1.0478),  smooth=0.0230, latent=16.5791
# Validation loss: 11.6817 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.2500 |val_class:0.9782 val_recon:1.0258 val_smooth: 0.0320 val_latent:14.2804
# Epoch 12
# Epoch 13:total=3.1610, cls=0.1339, recon=1.0398 (0.9444, 1.0466),  smooth=0.0226, latent=16.6722
# Validation loss: 10.8498 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.2500 |val_class:0.9093 val_recon:0.9409 val_smooth: 0.0261 val_latent:15.7398
# Epoch 13
# Epoch 14:total=2.9972, cls=0.1179, recon=1.0390 (0.9486, 1.0447),  smooth=0.0224, latent=16.6819
# Validation loss: 11.0542 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9346 val_recon:0.9618 val_smooth: 0.0189 val_latent:17.8530
# Epoch 14
# Epoch 15:total=2.9103, cls=0.1098, recon=1.0358 (0.9483, 1.0405),  smooth=0.0220, latent=16.7323
# Validation loss: 11.0748 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9377 val_recon:0.9498 val_smooth: 0.0191 val_latent:18.4186
# Epoch 15
# Epoch 16:total=2.8739, cls=0.1067, recon=1.0321 (0.9406, 1.0381),  smooth=0.0219, latent=16.8020
# Validation loss: 12.4292 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.2500 |val_class:1.0693 val_recon:0.9591 val_smooth: 0.0222 val_latent:16.6332
# Learning rate changed to 0.000063
# Early stopping at epoch 15
# Train accuracy: 0.89002 | Val accuracy: 0.83945 | Test accuracy: 0.83212
#
# === Fold 8/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=45.5419, cls=1.0715, recon=23.4470 (23.4972, 23.4449),  smooth=1.0825, latent=28.4771
# Validation loss: 13.0905 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.1176 |val_class:1.0630 val_recon:1.2226 val_smooth: 0.0687 val_latent:24.3886
# Epoch 1
# Epoch 2:total=10.2429, cls=0.7804, recon=1.3843 (1.1744, 1.3963),  smooth=0.0503, latent=24.9169
# Validation loss: 11.3514 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.1176 |val_class:0.7714 val_recon:1.7560 val_smooth: 0.1339 val_latent:14.6578
# Epoch 2
# Epoch 3:total=8.6416, cls=0.6491, recon=1.2047 (1.1280, 1.2123),  smooth=0.0395, latent=22.8406
# Validation loss: 10.7658 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.1765 |val_class:0.7708 val_recon:1.5864 val_smooth: 0.0928 val_latent:15.2713
# Epoch 3
# Epoch 4:total=7.5775, cls=0.5482, recon=1.1764 (1.1264, 1.1803),  smooth=0.0366, latent=22.3449
# Validation loss: 8.6420 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.1765 |val_class:0.6541 val_recon:1.0055 val_smooth: 0.0545 val_latent:19.9111
# Epoch 4
# Epoch 5:total=6.7621, cls=0.4685, recon=1.1688 (1.1316, 1.1714),  smooth=0.0354, latent=22.0450
# Validation loss: 11.4843 | Val acc: 0.7523 |Val acc (NS/BH/CV): 0.1176 |val_class:0.9230 val_recon:1.0338 val_smooth: 0.0669 val_latent:18.5829
# Epoch 5
# Epoch 6:total=6.0046, cls=0.3978, recon=1.1467 (1.0918, 1.1499),  smooth=0.0324, latent=21.7244
# Validation loss: 11.1836 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.3529 |val_class:0.8690 val_recon:1.8258 val_smooth: 0.0099 val_latent:33.5501
# Epoch 6
# Epoch 7:total=5.2732, cls=0.3266, recon=1.1405 (1.0900, 1.1437),  smooth=0.0309, latent=21.2591
# Validation loss: 12.1126 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.1176 |val_class:0.9819 val_recon:1.6099 val_smooth: 0.0115 val_latent:30.4234
# Epoch 7
# Epoch 8:total=4.8402, cls=0.2869, recon=1.1220 (1.0733, 1.1242),  smooth=0.0289, latent=20.7865
# Validation loss: 8.8381 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4706 |val_class:0.7011 val_recon:0.9346 val_smooth: 0.0331 val_latent:20.6225
# Epoch 8
# Epoch 9:total=4.2887, cls=0.2339, recon=1.1095 (1.0401, 1.1155),  smooth=0.0278, latent=20.2220
# Validation loss: 14.5369 | Val acc: 0.6972 |Val acc (NS/BH/CV): 0.1765 |val_class:1.2478 val_recon:1.0306 val_smooth: 0.0468 val_latent:16.7907
# Epoch 9
# Epoch 10:total=4.0522, cls=0.2121, recon=1.0985 (1.0238, 1.1034),  smooth=0.0269, latent=19.6671
# Validation loss: 13.2067 | Val acc: 0.7156 |Val acc (NS/BH/CV): 0.3529 |val_class:1.1428 val_recon:1.0088 val_smooth: 0.0203 val_latent:21.5452
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=3.2987, cls=0.1391, recon=1.0859 (1.0311, 1.0896),  smooth=0.0257, latent=19.2217
# Validation loss: 9.6009 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.4118 |val_class:0.7686 val_recon:0.9897 val_smooth: 0.0363 val_latent:16.6416
# Epoch 11
# Epoch 12:total=3.2687, cls=0.1366, recon=1.0830 (0.9939, 1.0886),  smooth=0.0255, latent=19.1503
# Validation loss: 9.6026 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.4706 |val_class:0.7900 val_recon:0.9309 val_smooth: 0.0206 val_latent:20.5660
# Epoch 12
# Epoch 13:total=3.0879, cls=0.1192, recon=1.0807 (1.0032, 1.0875),  smooth=0.0251, latent=19.1842
# Validation loss: 9.5348 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.4706 |val_class:0.7843 val_recon:0.8962 val_smooth: 0.0230 val_latent:19.6856
# Epoch 13
# Epoch 14:total=3.1165, cls=0.1228, recon=1.0748 (0.9876, 1.0811),  smooth=0.0249, latent=19.0766
# Validation loss: 9.6765 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.5294 |val_class:0.7981 val_recon:0.8969 val_smooth: 0.0233 val_latent:19.4009
# Epoch 14
# Epoch 15:total=3.0005, cls=0.1117, recon=1.0726 (0.9993, 1.0772),  smooth=0.0246, latent=19.0475
# Validation loss: 10.4608 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.4118 |val_class:0.8748 val_recon:0.8895 val_smooth: 0.0259 val_latent:18.7689
# Epoch 15
# Epoch 16:total=2.9192, cls=0.1041, recon=1.0695 (0.9996, 1.0726),  smooth=0.0244, latent=19.0446
# Validation loss: 10.0329 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.4118 |val_class:0.8359 val_recon:0.8888 val_smooth: 0.0220 val_latent:19.7560
# Learning rate changed to 0.000063
# Early stopping at epoch 15
# Train accuracy: 0.87882 | Val accuracy: 0.86239 | Test accuracy: 0.84124
#
# === Fold 9/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=92.2955, cls=1.1288, recon=66.1188 (66.4650, 66.0963),  smooth=1.4353, latent=14.1617
# Validation loss: 15.5623 | Val acc: 0.4908 |Val acc (NS/BH/CV): 0.1176 |val_class:1.1222 val_recon:2.3228 val_smooth: 0.1485 val_latent:10.0852
# Epoch 1
# Epoch 2:total=10.0210, cls=0.7916, recon=1.2423 (1.1562, 1.2471),  smooth=0.0324, latent=15.9716
# Validation loss: 15.8009 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.0588 |val_class:0.9278 val_recon:4.4092 val_smooth: 0.1584 val_latent:7.7392
# Epoch 2
# Epoch 3:total=8.4036, cls=0.6390, recon=1.1819 (1.1676, 1.1820),  smooth=0.0293, latent=15.6398
# Validation loss: 12.4151 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.1176 |val_class:0.8478 val_recon:2.4677 val_smooth: 0.0936 val_latent:9.8070
# Epoch 3
# Epoch 4:total=7.4773, cls=0.5497, recon=1.1656 (1.1739, 1.1663),  smooth=0.0275, latent=15.4077
# Validation loss: 14.0022 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.0588 |val_class:1.0925 val_recon:1.9253 val_smooth: 0.0617 val_latent:10.6685
# Epoch 4
# Epoch 5:total=6.7973, cls=0.4851, recon=1.1508 (1.1312, 1.1515),  smooth=0.0255, latent=15.4967
# Validation loss: 13.9603 | Val acc: 0.7706 |Val acc (NS/BH/CV): 0.1176 |val_class:1.1279 val_recon:1.6827 val_smooth: 0.0461 val_latent:11.8944
# Epoch 5
# Epoch 6:total=6.1351, cls=0.4206, recon=1.1443 (1.1127, 1.1461),  smooth=0.0243, latent=15.3470
# Validation loss: 12.4974 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.2353 |val_class:1.0451 val_recon:1.2146 val_smooth: 0.0290 val_latent:14.0831
# Epoch 6
# Epoch 7:total=5.6099, cls=0.3709, recon=1.1235 (1.0752, 1.1275),  smooth=0.0234, latent=15.2757
# Validation loss: 26.1667 | Val acc: 0.5550 |Val acc (NS/BH/CV): 0.0588 |val_class:2.3228 val_recon:2.2937 val_smooth: 0.0091 val_latent:25.7324
# Epoch 7
# Epoch 8:total=5.4556, cls=0.3571, recon=1.1070 (1.0571, 1.1111),  smooth=0.0234, latent=14.5887
# Validation loss: 26.4380 | Val acc: 0.6147 |Val acc (NS/BH/CV): 0.0000 |val_class:2.2294 val_recon:2.6004 val_smooth: 0.1005 val_latent:8.7704
# Epoch 8
# Epoch 9:total=4.4027, cls=0.2542, recon=1.0900 (1.0233, 1.0933),  smooth=0.0227, latent=14.1349
# Validation loss: 14.2593 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.3529 |val_class:1.1975 val_recon:1.6425 val_smooth: 0.0090 val_latent:20.8667
# Learning rate changed to 0.000250
# Epoch 9
# Epoch 10:total=3.9856, cls=0.2141, recon=1.0781 (1.0033, 1.0831),  smooth=0.0222, latent=14.0482
# Validation loss: 13.5657 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.2353 |val_class:1.1700 val_recon:1.0580 val_smooth: 0.0264 val_latent:13.4262
# Epoch 10
# Epoch 11:total=3.8824, cls=0.2046, recon=1.0705 (0.9853, 1.0779),  smooth=0.0221, latent=14.0133
# Validation loss: 13.8503 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.2353 |val_class:1.1991 val_recon:1.0342 val_smooth: 0.0280 val_latent:13.4530
# Epoch 11
# Epoch 12:total=3.6098, cls=0.1778, recon=1.0654 (0.9809, 1.0698),  smooth=0.0221, latent=13.9916
# Validation loss: 14.7236 | Val acc: 0.8761 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2920 val_recon:1.0312 val_smooth: 0.0226 val_latent:14.7102
# Epoch 12
# Epoch 13:total=3.5664, cls=0.1738, recon=1.0639 (0.9693, 1.0724),  smooth=0.0220, latent=13.9726
# Validation loss: 13.7549 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.3529 |val_class:1.2000 val_recon:0.9883 val_smooth: 0.0221 val_latent:14.7009
# Epoch 13
# Epoch 14:total=3.5650, cls=0.1743, recon=1.0586 (0.9659, 1.0659),  smooth=0.0218, latent=13.9315
# Validation loss: 14.3487 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3529 |val_class:1.2566 val_recon:0.9933 val_smooth: 0.0244 val_latent:13.9194
# Epoch 14
# Epoch 15:total=3.5362, cls=0.1717, recon=1.0566 (0.9695, 1.0635),  smooth=0.0218, latent=13.9344
# Validation loss: 16.9117 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.1765 |val_class:1.5160 val_recon:0.9874 val_smooth: 0.0218 val_latent:15.5859
# Learning rate changed to 0.000063
# Early stopping at epoch 14
# Train accuracy: 0.85336 | Val accuracy: 0.82569 | Test accuracy: 0.84307
#
# === Fold 10/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=58.5350, cls=1.1274, recon=35.3575 (35.9264, 35.3246),  smooth=1.1355, latent=21.9357
# Validation loss: 14.0573 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9360 val_recon:2.2187 val_smooth: 0.1940 val_latent:12.3789
# Epoch 1
# Epoch 2:total=9.9203, cls=0.7698, recon=1.3041 (1.2180, 1.3098),  smooth=0.0371, latent=20.0602
# Validation loss: 10.1910 | Val acc: 0.8807 |Val acc (NS/BH/CV): 0.2353 |val_class:0.8192 val_recon:1.0632 val_smooth: 0.0390 val_latent:18.6789
# Epoch 2
# Epoch 3:total=8.8242, cls=0.6776, recon=1.1836 (1.2383, 1.1801),  smooth=0.0317, latent=19.5038
# Validation loss: 12.7092 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.0000 |val_class:0.8353 val_recon:2.5586 val_smooth: 0.1257 val_latent:11.8933
# Epoch 3
# Epoch 4:total=8.0958, cls=0.6085, recon=1.1547 (1.1833, 1.1560),  smooth=0.0307, latent=19.4362
# Validation loss: 10.9420 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9023 val_recon:1.0064 val_smooth: 0.0362 val_latent:19.2468
# Epoch 4
# Epoch 5:total=7.0229, cls=0.5024, recon=1.1439 (1.1610, 1.1429),  smooth=0.0303, latent=19.1921
# Validation loss: 11.9256 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9875 val_recon:1.3026 val_smooth: 0.0190 val_latent:23.5648
# Epoch 5
# Epoch 6:total=6.5154, cls=0.4526, recon=1.1297 (1.1210, 1.1327),  smooth=0.0305, latent=18.9081
# Validation loss: 11.6967 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9610 val_recon:1.1141 val_smooth: 0.0418 val_latent:16.2493
# Epoch 6
# Epoch 7:total=5.8638, cls=0.3903, recon=1.1206 (1.1365, 1.1196),  smooth=0.0283, latent=18.5344
# Validation loss: 9.5618 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.2941 |val_class:0.7499 val_recon:1.3506 val_smooth: 0.0148 val_latent:23.1787
# Epoch 7
# Epoch 8:total=5.1737, cls=0.3242, recon=1.1042 (1.0951, 1.1047),  smooth=0.0268, latent=18.1303
# Validation loss: 9.7431 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.2941 |val_class:0.7944 val_recon:1.0381 val_smooth: 0.0199 val_latent:19.7460
# Epoch 8
# Epoch 9:total=4.8654, cls=0.2953, recon=1.0908 (1.0718, 1.0911),  smooth=0.0259, latent=17.6371
# Validation loss: 11.4105 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.1176 |val_class:0.9597 val_recon:0.9851 val_smooth: 0.0265 val_latent:17.3551
# Epoch 9
# Epoch 10:total=4.2546, cls=0.2368, recon=1.0779 (1.0412, 1.0834),  smooth=0.0244, latent=17.2178
# Validation loss: 12.8666 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.1765 |val_class:1.1074 val_recon:1.0183 val_smooth: 0.0208 val_latent:18.2930
# Epoch 10
# Epoch 11:total=3.9720, cls=0.2095, recon=1.0758 (1.0857, 1.0753),  smooth=0.0236, latent=17.0712
# Validation loss: 11.9509 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.1765 |val_class:1.0206 val_recon:0.9741 val_smooth: 0.0204 val_latent:17.8375
# Epoch 11
# Epoch 12:total=3.8985, cls=0.2033, recon=1.0683 (1.0607, 1.0670),  smooth=0.0230, latent=16.7608
# Validation loss: 13.4249 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.2353 |val_class:1.1609 val_recon:1.0856 val_smooth: 0.0160 val_latent:18.9704
# Epoch 12
# Epoch 13:total=3.4945, cls=0.1643, recon=1.0600 (1.0395, 1.0618),  smooth=0.0223, latent=16.6620
# Validation loss: 12.5801 | Val acc: 0.7752 |Val acc (NS/BH/CV): 0.4706 |val_class:1.0815 val_recon:0.9765 val_smooth: 0.0220 val_latent:16.4944
# Learning rate changed to 0.000250
# Epoch 13
# Epoch 14:total=3.1130, cls=0.1277, recon=1.0509 (1.0176, 1.0539),  smooth=0.0216, latent=16.5996
# Validation loss: 12.0464 | Val acc: 0.8761 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0342 val_recon:0.9237 val_smooth: 0.0212 val_latent:16.7473
# Epoch 14
# Epoch 15:total=2.9123, cls=0.1084, recon=1.0472 (0.9961, 1.0505),  smooth=0.0212, latent=16.6291
# Validation loss: 12.5398 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0828 val_recon:0.9083 val_smooth: 0.0234 val_latent:16.5955
# Epoch 15
# Epoch 16:total=2.8849, cls=0.1058, recon=1.0446 (1.0013, 1.0461),  smooth=0.0213, latent=16.6101
# Validation loss: 12.4934 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0704 val_recon:0.9478 val_smooth: 0.0274 val_latent:15.2010
# Epoch 16
# Epoch 17:total=2.8656, cls=0.1042, recon=1.0446 (1.0006, 1.0488),  smooth=0.0210, latent=16.7088
# Validation loss: 11.9592 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0233 val_recon:0.9047 val_smooth: 0.0254 val_latent:15.9788
# Epoch 17
# Epoch 18:total=2.7576, cls=0.0935, recon=1.0453 (0.9932, 1.0479),  smooth=0.0208, latent=16.7161
# Validation loss: 13.4684 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.2941 |val_class:1.1770 val_recon:0.9096 val_smooth: 0.0220 val_latent:16.8537
# Epoch 18
# Epoch 19:total=2.7963, cls=0.0976, recon=1.0436 (1.0077, 1.0465),  smooth=0.0208, latent=16.7264
# Validation loss: 13.7703 | Val acc: 0.8761 |Val acc (NS/BH/CV): 0.2353 |val_class:1.2077 val_recon:0.9257 val_smooth: 0.0198 val_latent:17.5908
# Learning rate changed to 0.000063
# Early stopping at epoch 18
# Train accuracy: 0.92210 | Val accuracy: 0.86239 | Test accuracy: 0.87226

# %%
all_results2, train_data, test_data = semisupervised_kfold_test(
    SemiSupervisedAE,
    np.column_stack([pn_normspec_labelled, pn_counts_labelled]),
    pn_spec_labels,
    np.column_stack([pn_normspec[unlabelled_args], pn_counts[unlabelled_args]]),
    epochs=20, lambda_cls=10, l2_lambda=1.0e-3, l1_lambda=1.0e-4, lr=1.0e-3,
    train_ids=pn_labelled_trainids.astype(int),
    test_ids=pn_labelled_testids.astype(int),
    weights=(class_weights).tolist(), k_folds=5)
# Out:
# === Fold 1/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=36.4426, cls=1.2503, recon=14.9624 (15.1874, 14.9525),  smooth=0.8431, latent=22.3895
# Validation loss: 13.1305 | Val acc: 0.7397 |Val acc (NS/BH/CV): 0.2353 |val_class:1.0435 val_recon:1.1221 val_smooth: 0.1034 val_latent:14.8182
# Epoch 1
# Epoch 2:total=11.4713, cls=0.9194, recon=1.2596 (1.1347, 1.2670),  smooth=0.0474, latent=18.7579
# Validation loss: 12.2373 | Val acc: 0.7489 |Val acc (NS/BH/CV): 0.4118 |val_class:0.9936 val_recon:1.0795 val_smooth: 0.0681 val_latent:15.1028
# Epoch 2
# Epoch 3:total=9.6410, cls=0.7480, recon=1.2130 (1.0990, 1.2206),  smooth=0.0403, latent=17.6562
# Validation loss: 12.5691 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.1176 |val_class:1.0211 val_recon:1.1982 val_smooth: 0.0617 val_latent:14.3932
# Epoch 3
# Epoch 4:total=7.8696, cls=0.5805, recon=1.1644 (1.0847, 1.1710),  smooth=0.0353, latent=17.1681
# Validation loss: 12.2987 | Val acc: 0.8265 |Val acc (NS/BH/CV): 0.3529 |val_class:1.0348 val_recon:0.9844 val_smooth: 0.0419 val_latent:15.6237
# Epoch 4
# Epoch 5:total=6.9937, cls=0.4984, recon=1.1337 (1.0378, 1.1405),  smooth=0.0326, latent=16.4672
# Validation loss: 12.2710 | Val acc: 0.7854 |Val acc (NS/BH/CV): 0.4118 |val_class:1.0370 val_recon:1.1498 val_smooth: 0.0196 val_latent:19.7945
# Epoch 5
# Epoch 6:total=6.1148, cls=0.4146, recon=1.1118 (1.0432, 1.1160),  smooth=0.0305, latent=15.9205
# Validation loss: 16.4681 | Val acc: 0.8219 |Val acc (NS/BH/CV): 0.1176 |val_class:1.4489 val_recon:1.0740 val_smooth: 0.0353 val_latent:14.7993
# Epoch 6
# Epoch 7:total=5.2022, cls=0.3277, recon=1.0862 (0.9899, 1.0924),  smooth=0.0285, latent=15.2842
# Validation loss: 14.4716 | Val acc: 0.8493 |Val acc (NS/BH/CV): 0.1765 |val_class:1.2122 val_recon:1.2798 val_smooth: 0.0519 val_latent:11.6683
# Epoch 7
# Epoch 8:total=4.4520, cls=0.2559, recon=1.0668 (0.9802, 1.0726),  smooth=0.0270, latent=15.2569
# Validation loss: 33.5589 | Val acc: 0.8128 |Val acc (NS/BH/CV): 0.0000 |val_class:3.0101 val_recon:2.1032 val_smooth: 0.0801 val_latent:11.9590
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=3.9633, cls=0.2086, recon=1.0613 (0.9775, 1.0677),  smooth=0.0259, latent=15.3537
# Validation loss: 11.4118 | Val acc: 0.8174 |Val acc (NS/BH/CV): 0.4118 |val_class:0.9733 val_recon:0.8523 val_smooth: 0.0270 val_latent:14.9404
# Epoch 9
# Epoch 10:total=3.5676, cls=0.1700, recon=1.0546 (0.9581, 1.0615),  smooth=0.0256, latent=15.4108
# Validation loss: 12.5421 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0781 val_recon:0.8845 val_smooth: 0.0321 val_latent:13.8250
# Epoch 10
# Epoch 11:total=3.5893, cls=0.1727, recon=1.0544 (0.9587, 1.0605),  smooth=0.0251, latent=15.4940
# Validation loss: 12.1048 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.4706 |val_class:1.0202 val_recon:0.9603 val_smooth: 0.0388 val_latent:12.9601
# Epoch 11
# Epoch 12:total=3.5517, cls=0.1697, recon=1.0489 (0.9481, 1.0561),  smooth=0.0248, latent=15.6129
# Validation loss: 13.6221 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.2941 |val_class:1.1826 val_recon:0.9092 val_smooth: 0.0332 val_latent:13.9732
# Epoch 12
# Epoch 13:total=3.3879, cls=0.1539, recon=1.0471 (0.9550, 1.0546),  smooth=0.0244, latent=15.6740
# Validation loss: 12.9823 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.3529 |val_class:1.1337 val_recon:0.8860 val_smooth: 0.0201 val_latent:17.2318
# Epoch 13
# Epoch 14:total=3.2653, cls=0.1422, recon=1.0457 (0.9676, 1.0533),  smooth=0.0240, latent=15.8070
# Validation loss: 14.2834 | Val acc: 0.8356 |Val acc (NS/BH/CV): 0.2353 |val_class:1.2608 val_recon:0.8704 val_smooth: 0.0249 val_latent:15.0303
# Epoch 14
# Epoch 15:total=3.1418, cls=0.1305, recon=1.0423 (0.9473, 1.0479),  smooth=0.0237, latent=15.8425
# Validation loss: 14.1245 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.3529 |val_class:1.2493 val_recon:0.8485 val_smooth: 0.0225 val_latent:16.5417
# Learning rate changed to 0.000063
# Epoch 15
# Epoch 16:total=3.0782, cls=0.1248, recon=1.0404 (0.9496, 1.0470),  smooth=0.0233, latent=15.9596
# Validation loss: 13.3259 | Val acc: 0.8493 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1683 val_recon:0.8400 val_smooth: 0.0246 val_latent:15.6881
# Epoch 16
# Epoch 17:total=3.0457, cls=0.1217, recon=1.0398 (0.9504, 1.0463),  smooth=0.0232, latent=15.8574
# Validation loss: 13.5325 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1888 val_recon:0.8415 val_smooth: 0.0246 val_latent:15.9361
# Epoch 17
# Epoch 18:total=2.9895, cls=0.1163, recon=1.0391 (0.9499, 1.0444),  smooth=0.0230, latent=15.8558
# Validation loss: 13.5433 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1899 val_recon:0.8400 val_smooth: 0.0247 val_latent:15.7205
# Epoch 18
# Epoch 19:total=2.9264, cls=0.1098, recon=1.0416 (0.9584, 1.0471),  smooth=0.0229, latent=15.8795
# Validation loss: 12.4696 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.4118 |val_class:1.0840 val_recon:0.8293 val_smooth: 0.0243 val_latent:15.5327
# Epoch 19
# Epoch 20:total=3.0796, cls=0.1253, recon=1.0410 (0.9704, 1.0476),  smooth=0.0229, latent=15.8763
# Validation loss: 12.7508 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1128 val_recon:0.8357 val_smooth: 0.0230 val_latent:15.7306
# Train accuracy: 0.96994 | Val accuracy: 0.84018 | Test accuracy: 0.84307
#
# === Fold 2/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=91.9140, cls=1.3174, recon=59.7040 (60.4715, 59.6584),  smooth=1.8492, latent=21.5383
# Validation loss: 14.3262 | Val acc: 0.6758 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1424 val_recon:2.0877 val_smooth: 0.0258 val_latent:33.8769
# Epoch 1
# Epoch 2:total=13.1232, cls=1.0849, recon=1.3230 (1.1495, 1.3350),  smooth=0.0404, latent=24.2803
# Validation loss: 11.6579 | Val acc: 0.7900 |Val acc (NS/BH/CV): 0.6471 |val_class:0.9354 val_recon:1.5780 val_smooth: 0.0171 val_latent:31.2068
# Epoch 2
# Epoch 3:total=11.9854, cls=0.9885, recon=1.1979 (1.1923, 1.1984),  smooth=0.0356, latent=22.7061
# Validation loss: 13.4883 | Val acc: 0.4521 |Val acc (NS/BH/CV): 0.4706 |val_class:1.0760 val_recon:2.0731 val_smooth: 0.0096 val_latent:34.6566
# Epoch 3
# Epoch 4:total=10.2350, cls=0.8188, recon=1.1702 (1.1304, 1.1730),  smooth=0.0329, latent=22.0743
# Validation loss: 13.0669 | Val acc: 0.6119 |Val acc (NS/BH/CV): 0.7059 |val_class:0.9144 val_recon:3.3149 val_smooth: 0.0035 val_latent:46.7617
# Epoch 4
# Epoch 5:total=9.2902, cls=0.7244, recon=1.1659 (1.1211, 1.1705),  smooth=0.0331, latent=21.4915
# Validation loss: 11.3908 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.4118 |val_class:0.9215 val_recon:1.4485 val_smooth: 0.0170 val_latent:27.6470
# Epoch 5
# Epoch 6:total=8.2938, cls=0.6275, recon=1.1492 (1.1311, 1.1511),  smooth=0.0318, latent=20.7137
# Validation loss: 14.9687 | Val acc: 0.6210 |Val acc (NS/BH/CV): 0.2941 |val_class:1.3035 val_recon:1.0192 val_smooth: 0.0361 val_latent:20.6820
# Epoch 6
# Epoch 7:total=7.3025, cls=0.5298, recon=1.1410 (1.0927, 1.1424),  smooth=0.0310, latent=19.6227
# Validation loss: 11.3725 | Val acc: 0.7763 |Val acc (NS/BH/CV): 0.5882 |val_class:0.9081 val_recon:1.1933 val_smooth: 0.0547 val_latent:15.6009
# Epoch 7
# Epoch 8:total=6.8392, cls=0.4859, recon=1.1341 (1.0826, 1.1403),  smooth=0.0291, latent=18.7653
# Validation loss: 12.1559 | Val acc: 0.7215 |Val acc (NS/BH/CV): 0.5882 |val_class:0.9996 val_recon:1.4677 val_smooth: 0.0129 val_latent:25.1020
# Epoch 8
# Epoch 9:total=6.1980, cls=0.4243, recon=1.1179 (1.0343, 1.1236),  smooth=0.0280, latent=17.9155
# Validation loss: 13.4572 | Val acc: 0.7352 |Val acc (NS/BH/CV): 0.3529 |val_class:1.1550 val_recon:1.1660 val_smooth: 0.0180 val_latent:20.3936
# Epoch 9
# Epoch 10:total=5.5815, cls=0.3640, recon=1.1062 (1.0101, 1.1135),  smooth=0.0276, latent=17.1009
# Validation loss: 23.7753 | Val acc: 0.6575 |Val acc (NS/BH/CV): 0.4706 |val_class:2.0157 val_recon:3.0066 val_smooth: 0.0034 val_latent:33.2699
# Epoch 10
# Epoch 11:total=4.9461, cls=0.3026, recon=1.0932 (1.0054, 1.0994),  smooth=0.0265, latent=16.8741
# Validation loss: 14.6599 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.5294 |val_class:1.2813 val_recon:0.9595 val_smooth: 0.0325 val_latent:15.7811
# Epoch 11
# Epoch 12:total=4.5835, cls=0.2668, recon=1.0931 (1.0131, 1.0995),  smooth=0.0258, latent=16.5055
# Validation loss: 16.8225 | Val acc: 0.8174 |Val acc (NS/BH/CV): 0.3529 |val_class:1.4629 val_recon:1.1720 val_smooth: 0.0459 val_latent:13.4937
# Epoch 12
# Epoch 13:total=4.3197, cls=0.2433, recon=1.0722 (0.9608, 1.0798),  smooth=0.0248, latent=16.0967
# Validation loss: 17.8223 | Val acc: 0.8493 |Val acc (NS/BH/CV): 0.3529 |val_class:1.5412 val_recon:1.3476 val_smooth: 0.0499 val_latent:12.5251
# Learning rate changed to 0.000250
# Epoch 13
# Epoch 14:total=3.5777, cls=0.1705, recon=1.0670 (0.9767, 1.0732),  smooth=0.0239, latent=16.1600
# Validation loss: 15.6779 | Val acc: 0.8493 |Val acc (NS/BH/CV): 0.5882 |val_class:1.3835 val_recon:1.1222 val_smooth: 0.0151 val_latent:19.0528
# Epoch 14
# Epoch 15:total=3.4386, cls=0.1574, recon=1.0637 (0.9618, 1.0694),  smooth=0.0234, latent=16.2807
# Validation loss: 16.6028 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.4706 |val_class:1.4575 val_recon:1.0754 val_smooth: 0.0387 val_latent:13.7641
# Epoch 15
# Epoch 16:total=3.2601, cls=0.1402, recon=1.0582 (0.9518, 1.0649),  smooth=0.0232, latent=16.1577
# Validation loss: 15.6695 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.5294 |val_class:1.3947 val_recon:0.9137 val_smooth: 0.0241 val_latent:16.1766
# Epoch 16
# Epoch 17:total=3.2403, cls=0.1385, recon=1.0567 (0.9403, 1.0658),  smooth=0.0230, latent=16.3316
# Validation loss: 17.8024 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.4118 |val_class:1.5889 val_recon:1.0039 val_smooth: 0.0343 val_latent:14.2140
# Epoch 17
# Epoch 18:total=3.2253, cls=0.1374, recon=1.0573 (0.9714, 1.0638),  smooth=0.0226, latent=16.3782
# Validation loss: 16.5542 | Val acc: 0.8174 |Val acc (NS/BH/CV): 0.5294 |val_class:1.4637 val_recon:0.9947 val_smooth: 0.0356 val_latent:14.3616
# Epoch 18
# Epoch 19:total=3.0669, cls=0.1219, recon=1.0540 (0.9471, 1.0614),  smooth=0.0226, latent=16.4648
# Validation loss: 18.1140 | Val acc: 0.8630 |Val acc (NS/BH/CV): 0.4706 |val_class:1.6414 val_recon:0.9231 val_smooth: 0.0207 val_latent:17.5851
# Learning rate changed to 0.000063
# Early stopping at epoch 18
# Train accuracy: 0.83393 | Val accuracy: 0.77626 | Test accuracy: 0.79197
#
# === Fold 3/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=37.3544, cls=1.2683, recon=18.2489 (18.2707, 18.2485),  smooth=0.5880, latent=17.5977
# Validation loss: 20.1304 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.3750 |val_class:1.0586 val_recon:6.0987 val_smooth: 0.2915 val_latent:5.9440
# Epoch 1
# Epoch 2:total=12.3527, cls=1.0243, recon=1.2217 (1.1980, 1.2222),  smooth=0.0347, latent=15.8384
# Validation loss: 14.6900 | Val acc: 0.3257 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2701 val_recon:1.2296 val_smooth: 0.0214 val_latent:19.3098
# Epoch 2
# Epoch 3:total=10.8332, cls=0.8775, recon=1.1767 (1.1485, 1.1770),  smooth=0.0339, latent=15.1094
# Validation loss: 14.0318 | Val acc: 0.7202 |Val acc (NS/BH/CV): 0.1875 |val_class:1.1908 val_recon:1.0675 val_smooth: 0.0512 val_latent:15.0446
# Epoch 3
# Epoch 4:total=9.5715, cls=0.7556, recon=1.1505 (1.1211, 1.1523),  smooth=0.0320, latent=14.2534
# Validation loss: 14.9506 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.1250 |val_class:1.0288 val_recon:2.8262 val_smooth: 0.1295 val_latent:8.3928
# Epoch 4
# Epoch 5:total=8.3649, cls=0.6416, recon=1.1258 (1.1019, 1.1282),  smooth=0.0274, latent=13.6079
# Validation loss: 10.4712 | Val acc: 0.6697 |Val acc (NS/BH/CV): 0.5000 |val_class:0.8434 val_recon:1.0482 val_smooth: 0.0441 val_latent:11.5918
# Epoch 5
# Epoch 6:total=7.4316, cls=0.5520, recon=1.0975 (1.0843, 1.0981),  smooth=0.0262, latent=12.9301
# Validation loss: 10.7581 | Val acc: 0.5963 |Val acc (NS/BH/CV): 0.6250 |val_class:0.8977 val_recon:1.0204 val_smooth: 0.0206 val_latent:13.9230
# Epoch 6
# Epoch 7:total=6.6270, cls=0.4735, recon=1.0855 (1.0499, 1.0877),  smooth=0.0251, latent=12.3993
# Validation loss: 14.0479 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.2500 |val_class:1.1941 val_recon:1.1613 val_smooth: 0.0389 val_latent:11.5739
# Epoch 7
# Epoch 8:total=5.6830, cls=0.3807, recon=1.0786 (1.0460, 1.0807),  smooth=0.0239, latent=12.0538
# Validation loss: 11.8265 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.3125 |val_class:0.9886 val_recon:1.0279 val_smooth: 0.0354 val_latent:10.8682
# Epoch 8
# Epoch 9:total=5.2295, cls=0.3369, recon=1.0643 (1.0374, 1.0671),  smooth=0.0235, latent=11.8235
# Validation loss: 12.1966 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.4375 |val_class:1.0031 val_recon:1.1720 val_smooth: 0.0432 val_latent:10.6172
# Epoch 9
# Epoch 10:total=4.3728, cls=0.2537, recon=1.0481 (0.9880, 1.0526),  smooth=0.0224, latent=11.8974
# Validation loss: 12.9628 | Val acc: 0.7294 |Val acc (NS/BH/CV): 0.5625 |val_class:1.1293 val_recon:0.8948 val_smooth: 0.0208 val_latent:13.7924
# Epoch 10
# Epoch 11:total=4.2067, cls=0.2380, recon=1.0441 (0.9810, 1.0483),  smooth=0.0218, latent=12.0835
# Validation loss: 13.8873 | Val acc: 0.7615 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2181 val_recon:0.9480 val_smooth: 0.0191 val_latent:13.7071
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=3.6333, cls=0.1824, recon=1.0350 (0.9854, 1.0381),  smooth=0.0209, latent=12.0658
# Validation loss: 13.3697 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.5625 |val_class:1.1716 val_recon:0.8712 val_smooth: 0.0215 val_latent:13.2626
# Epoch 12
# Epoch 13:total=3.3939, cls=0.1587, recon=1.0325 (0.9803, 1.0371),  smooth=0.0208, latent=12.2241
# Validation loss: 12.2681 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.6250 |val_class:1.0583 val_recon:0.9578 val_smooth: 0.0160 val_latent:13.7545
# Epoch 13
# Epoch 14:total=3.2681, cls=0.1466, recon=1.0303 (0.9893, 1.0322),  smooth=0.0206, latent=12.1751
# Validation loss: 13.7256 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2079 val_recon:0.8475 val_smooth: 0.0233 val_latent:13.0595
# Epoch 14
# Epoch 15:total=3.2583, cls=0.1460, recon=1.0295 (0.9730, 1.0324),  smooth=0.0203, latent=12.2973
# Validation loss: 12.3727 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.5625 |val_class:1.0740 val_recon:0.8502 val_smooth: 0.0216 val_latent:13.7629
# Epoch 15
# Epoch 16:total=3.0500, cls=0.1256, recon=1.0268 (0.9628, 1.0310),  smooth=0.0202, latent=12.4145
# Validation loss: 13.7766 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2142 val_recon:0.8484 val_smooth: 0.0220 val_latent:13.3571
# Epoch 16
# Epoch 17:total=3.0729, cls=0.1285, recon=1.0228 (0.9471, 1.0278),  smooth=0.0200, latent=12.5775
# Validation loss: 12.4865 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.5625 |val_class:1.0853 val_recon:0.8669 val_smooth: 0.0201 val_latent:13.4215
# Learning rate changed to 0.000063
# Early stopping at epoch 16
# Train accuracy: 0.69348 | Val accuracy: 0.66972 | Test accuracy: 0.62956
#
# === Fold 4/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=63.7911, cls=1.2619, recon=39.8672 (40.5159, 39.8267),  smooth=1.0755, latent=24.4393
# Validation loss: 19.4508 | Val acc: 0.5000 |Val acc (NS/BH/CV): 0.3750 |val_class:1.1933 val_recon:3.9236 val_smooth: 0.3056 val_latent:11.3497
# Epoch 1
# Epoch 2:total=12.7866, cls=1.0538, recon=1.3162 (1.2696, 1.3222),  smooth=0.0382, latent=23.9011
# Validation loss: 14.6660 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.3750 |val_class:1.1358 val_recon:1.8998 val_smooth: 0.0866 val_latent:14.8125
# Epoch 2
# Epoch 3:total=11.3535, cls=0.9311, recon=1.1936 (1.2269, 1.1919),  smooth=0.0298, latent=22.6565
# Validation loss: 13.4753 | Val acc: 0.4587 |Val acc (NS/BH/CV): 0.5000 |val_class:1.1358 val_recon:1.1566 val_smooth: 0.0410 val_latent:21.1650
# Epoch 3
# Epoch 4:total=9.8743, cls=0.7827, recon=1.1845 (1.2219, 1.1853),  smooth=0.0310, latent=21.8865
# Validation loss: 14.2219 | Val acc: 0.5367 |Val acc (NS/BH/CV): 0.5000 |val_class:1.2092 val_recon:1.2348 val_smooth: 0.0340 val_latent:21.9878
# Epoch 4
# Epoch 5:total=8.0459, cls=0.6028, recon=1.1638 (1.1664, 1.1644),  smooth=0.0298, latent=21.1541
# Validation loss: 16.1783 | Val acc: 0.6606 |Val acc (NS/BH/CV): 0.5000 |val_class:1.3682 val_recon:1.3808 val_smooth: 0.0562 val_latent:16.0802
# Epoch 5
# Epoch 6:total=7.2981, cls=0.5311, recon=1.1545 (1.1789, 1.1531),  smooth=0.0274, latent=20.4927
# Validation loss: 15.3789 | Val acc: 0.7615 |Val acc (NS/BH/CV): 0.4375 |val_class:1.3272 val_recon:1.3912 val_smooth: 0.0150 val_latent:26.0320
# Epoch 6
# Epoch 7:total=6.2740, cls=0.4313, recon=1.1320 (1.1019, 1.1371),  smooth=0.0268, latent=19.9460
# Validation loss: 14.7819 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2171 val_recon:1.5092 val_smooth: 0.0544 val_latent:14.5172
# Epoch 7
# Epoch 8:total=5.8693, cls=0.3929, recon=1.1235 (1.0987, 1.1261),  smooth=0.0253, latent=19.1160
# Validation loss: 27.5634 | Val acc: 0.7294 |Val acc (NS/BH/CV): 0.0000 |val_class:2.4731 val_recon:1.4736 val_smooth: 0.0797 val_latent:15.4892
# Epoch 8
# Epoch 9:total=5.1088, cls=0.3180, recon=1.1120 (1.0744, 1.1139),  smooth=0.0251, latent=18.5435
# Validation loss: 19.6348 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.3125 |val_class:1.7504 val_recon:1.2507 val_smooth: 0.0315 val_latent:16.8395
# Learning rate changed to 0.000250
# Epoch 9
# Epoch 10:total=4.2449, cls=0.2341, recon=1.1004 (1.0246, 1.1072),  smooth=0.0237, latent=17.9663
# Validation loss: 16.9678 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.4375 |val_class:1.5054 val_recon:1.0339 val_smooth: 0.0314 val_latent:16.9784
# Epoch 10
# Epoch 11:total=4.0363, cls=0.2137, recon=1.0962 (1.0407, 1.0989),  smooth=0.0237, latent=17.9463
# Validation loss: 17.1204 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.5000 |val_class:1.5243 val_recon:1.0245 val_smooth: 0.0286 val_latent:17.2352
# Epoch 11
# Epoch 12:total=3.9793, cls=0.2090, recon=1.0893 (1.0140, 1.0937),  smooth=0.0233, latent=18.0299
# Validation loss: 16.5753 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.5000 |val_class:1.4747 val_recon:1.0143 val_smooth: 0.0246 val_latent:18.3582
# Epoch 12
# Epoch 13:total=3.8644, cls=0.1979, recon=1.0854 (1.0182, 1.0898),  smooth=0.0233, latent=18.0880
# Validation loss: 17.2090 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.4375 |val_class:1.5297 val_recon:1.0359 val_smooth: 0.0309 val_latent:16.7665
# Epoch 13
# Epoch 14:total=3.6716, cls=0.1790, recon=1.0837 (1.0274, 1.0882),  smooth=0.0230, latent=18.0786
# Validation loss: 17.6316 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.4375 |val_class:1.5814 val_recon:0.9996 val_smooth: 0.0250 val_latent:18.2341
# Epoch 14
# Epoch 15:total=3.5880, cls=0.1713, recon=1.0779 (1.0093, 1.0832),  smooth=0.0229, latent=18.1374
# Validation loss: 17.3351 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.4375 |val_class:1.5533 val_recon:0.9962 val_smooth: 0.0237 val_latent:18.5789
# Learning rate changed to 0.000063
# Early stopping at epoch 14
# Train accuracy: 0.45927 | Val accuracy: 0.45872 | Test accuracy: 0.37591
#
# === Fold 5/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=119.2356, cls=1.3548, recon=90.4727 (90.9978, 90.4387),  smooth=1.4680, latent=13.6731
# Validation loss: 15.0363 | Val acc: 0.2339 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2780 val_recon:1.0731 val_smooth: 0.0638 val_latent:21.2403
# Epoch 1
# Epoch 2:total=13.5411, cls=1.1316, recon=1.3379 (1.2696, 1.3334),  smooth=0.0341, latent=22.5599
# Validation loss: 15.2154 | Val acc: 0.4587 |Val acc (NS/BH/CV): 0.5000 |val_class:1.2036 val_recon:1.8972 val_smooth: 0.0745 val_latent:13.5333
# Epoch 2
# Epoch 3:total=11.9994, cls=0.9974, recon=1.2036 (1.2876, 1.1979),  smooth=0.0276, latent=21.1338
# Validation loss: 14.3613 | Val acc: 0.7477 |Val acc (NS/BH/CV): 0.3750 |val_class:1.1400 val_recon:1.7486 val_smooth: 0.0674 val_latent:13.3182
# Epoch 3
# Epoch 4:total=10.2935, cls=0.8317, recon=1.1759 (1.2462, 1.1710),  smooth=0.0254, latent=20.6087
# Validation loss: 21.4846 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.2500 |val_class:1.3042 val_recon:6.2589 val_smooth: 0.1649 val_latent:7.7961
# Epoch 4
# Epoch 5:total=9.3734, cls=0.7410, recon=1.1654 (1.2408, 1.1592),  smooth=0.0250, latent=20.3700
# Validation loss: 15.5890 | Val acc: 0.7385 |Val acc (NS/BH/CV): 0.3750 |val_class:1.3058 val_recon:1.4483 val_smooth: 0.0539 val_latent:14.1751
# Epoch 5
# Epoch 6:total=8.1212, cls=0.6180, recon=1.1514 (1.2254, 1.1467),  smooth=0.0240, latent=19.9023
# Validation loss: 13.0259 | Val acc: 0.6330 |Val acc (NS/BH/CV): 0.5000 |val_class:1.1086 val_recon:1.2532 val_smooth: 0.0129 val_latent:26.5386
# Epoch 6
# Epoch 7:total=7.3438, cls=0.5421, recon=1.1420 (1.2131, 1.1356),  smooth=0.0229, latent=19.1791
# Validation loss: 19.9176 | Val acc: 0.7294 |Val acc (NS/BH/CV): 0.1875 |val_class:1.7151 val_recon:1.6597 val_smooth: 0.0560 val_latent:13.2070
# Epoch 7
# Epoch 8:total=7.0406, cls=0.5133, recon=1.1285 (1.1834, 1.1253),  smooth=0.0226, latent=17.7546
# Validation loss: 15.4410 | Val acc: 0.6606 |Val acc (NS/BH/CV): 0.1875 |val_class:1.3618 val_recon:0.9726 val_smooth: 0.0298 val_latent:15.4432
# Epoch 8
# Epoch 9:total=6.0672, cls=0.4176, recon=1.1173 (1.1879, 1.1154),  smooth=0.0220, latent=16.3135
# Validation loss: 19.7727 | Val acc: 0.6101 |Val acc (NS/BH/CV): 0.4375 |val_class:1.7748 val_recon:1.1090 val_smooth: 0.0364 val_latent:13.1078
# Epoch 9
# Epoch 10:total=5.3429, cls=0.3472, recon=1.1014 (1.0949, 1.1020),  smooth=0.0214, latent=15.4128
# Validation loss: 23.0981 | Val acc: 0.5642 |Val acc (NS/BH/CV): 0.3750 |val_class:2.1236 val_recon:1.1707 val_smooth: 0.0131 val_latent:20.0765
# Epoch 10
# Epoch 11:total=4.7370, cls=0.2888, recon=1.0887 (1.1007, 1.0889),  smooth=0.0204, latent=14.9588
# Validation loss: 21.6383 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.4375 |val_class:1.9298 val_recon:1.3620 val_smooth: 0.0426 val_latent:11.3273
# Epoch 11
# Epoch 12:total=4.6253, cls=0.2784, recon=1.0853 (1.0926, 1.0845),  smooth=0.0200, latent=14.4672
# Validation loss: 23.1397 | Val acc: 0.6468 |Val acc (NS/BH/CV): 0.3750 |val_class:2.0495 val_recon:1.6119 val_smooth: 0.0479 val_latent:10.1158
# Learning rate changed to 0.000250
# Epoch 12
# Epoch 13:total=3.9328, cls=0.2101, recon=1.0792 (1.0816, 1.0790),  smooth=0.0195, latent=13.9714
# Validation loss: 16.1014 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.3750 |val_class:1.4418 val_recon:0.8909 val_smooth: 0.0236 val_latent:13.1713
# Epoch 13
# Epoch 14:total=3.7112, cls=0.1890, recon=1.0697 (1.0329, 1.0700),  smooth=0.0194, latent=14.1679
# Validation loss: 17.5267 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3750 |val_class:1.5877 val_recon:0.8854 val_smooth: 0.0208 val_latent:13.8557
# Epoch 14
# Epoch 15:total=3.7177, cls=0.1903, recon=1.0643 (1.0258, 1.0692),  smooth=0.0193, latent=14.2549
# Validation loss: 16.8648 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.3750 |val_class:1.5209 val_recon:0.8723 val_smooth: 0.0227 val_latent:13.4797
# Epoch 15
# Epoch 16:total=3.4401, cls=0.1627, recon=1.0637 (1.0603, 1.0638),  smooth=0.0192, latent=14.2942
# Validation loss: 18.6042 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.3750 |val_class:1.6946 val_recon:0.8786 val_smooth: 0.0223 val_latent:13.6881
# Epoch 16
# Epoch 17:total=3.5339, cls=0.1724, recon=1.0627 (1.0510, 1.0635),  smooth=0.0191, latent=14.2064
# Validation loss: 17.1009 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3750 |val_class:1.5467 val_recon:0.8682 val_smooth: 0.0210 val_latent:13.5822
# Epoch 17
# Epoch 18:total=3.4468, cls=0.1643, recon=1.0575 (1.0246, 1.0600),  smooth=0.0189, latent=14.1731
# Validation loss: 19.5642 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3125 |val_class:1.7937 val_recon:0.8929 val_smooth: 0.0177 val_latent:14.3168
# Learning rate changed to 0.000063
# Early stopping at epoch 17
# Train accuracy: 0.70010 | Val accuracy: 0.63303 | Test accuracy: 0.64599
#
# === Fold 6/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=31.1065, cls=1.2416, recon=12.1298 (12.0629, 12.1381),  smooth=0.6009, latent=23.9927
# Validation loss: 21.7187 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.0625 |val_class:1.2539 val_recon:5.0209 val_smooth: 0.3621 val_latent:9.3625
# Epoch 1
# Epoch 2:total=11.9569, cls=0.9706, recon=1.2746 (1.1540, 1.2821),  smooth=0.0428, latent=19.7701
# Validation loss: 13.1249 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.5000 |val_class:0.9824 val_recon:1.6739 val_smooth: 0.1084 val_latent:12.9364
# Epoch 2
# Epoch 3:total=10.3648, cls=0.8250, recon=1.1813 (1.1263, 1.1853),  smooth=0.0383, latent=18.9487
# Validation loss: 11.6491 | Val acc: 0.6514 |Val acc (NS/BH/CV): 0.6250 |val_class:0.9447 val_recon:1.0964 val_smooth: 0.0555 val_latent:16.7847
# Epoch 3
# Epoch 4:total=8.5242, cls=0.6470, recon=1.1486 (1.0861, 1.1523),  smooth=0.0352, latent=18.6700
# Validation loss: 11.3992 | Val acc: 0.8807 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8749 val_recon:1.4698 val_smooth: 0.0629 val_latent:13.4549
# Epoch 4
# Epoch 5:total=7.2195, cls=0.5221, recon=1.1197 (1.0651, 1.1244),  smooth=0.0321, latent=18.2250
# Validation loss: 13.3266 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.1875 |val_class:1.1271 val_recon:1.0734 val_smooth: 0.0424 val_latent:16.4694
# Epoch 5
# Epoch 6:total=6.4087, cls=0.4437, recon=1.1138 (1.0456, 1.1178),  smooth=0.0297, latent=18.2245
# Validation loss: 12.8647 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.3750 |val_class:1.0868 val_recon:1.2472 val_smooth: 0.0182 val_latent:21.9630
# Epoch 6
# Epoch 7:total=5.6702, cls=0.3738, recon=1.0899 (1.0310, 1.0926),  smooth=0.0278, latent=16.8358
# Validation loss: 11.8356 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.5000 |val_class:0.9640 val_recon:1.1709 val_smooth: 0.0462 val_latent:13.6002
# Epoch 7
# Epoch 8:total=4.6947, cls=0.2788, recon=1.0767 (1.0195, 1.0805),  smooth=0.0263, latent=16.7818
# Validation loss: 16.7916 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.1250 |val_class:1.4912 val_recon:0.9788 val_smooth: 0.0333 val_latent:16.6725
# Epoch 8
# Epoch 9:total=4.4657, cls=0.2577, recon=1.0682 (1.0165, 1.0743),  smooth=0.0252, latent=16.6626
# Validation loss: 13.1541 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3750 |val_class:1.1365 val_recon:0.9737 val_smooth: 0.0247 val_latent:16.2003
# Epoch 9
# Epoch 10:total=4.0736, cls=0.2204, recon=1.0593 (0.9999, 1.0631),  smooth=0.0240, latent=16.4846
# Validation loss: 12.3995 | Val acc: 0.7615 |Val acc (NS/BH/CV): 0.3125 |val_class:1.0434 val_recon:1.0419 val_smooth: 0.0355 val_latent:13.9785
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=3.4700, cls=0.1621, recon=1.0484 (0.9937, 1.0523),  smooth=0.0231, latent=16.1409
# Validation loss: 12.4143 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:1.0610 val_recon:0.9543 val_smooth: 0.0280 val_latent:15.1305
# Epoch 11
# Epoch 12:total=3.2140, cls=0.1370, recon=1.0468 (0.9895, 1.0499),  smooth=0.0226, latent=16.2725
# Validation loss: 13.4058 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.5000 |val_class:1.1629 val_recon:0.9533 val_smooth: 0.0254 val_latent:15.5644
# Epoch 12
# Epoch 13:total=3.1233, cls=0.1283, recon=1.0440 (0.9972, 1.0463),  smooth=0.0226, latent=16.4782
# Validation loss: 14.3054 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.3125 |val_class:1.2499 val_recon:0.9464 val_smooth: 0.0290 val_latent:15.5338
# Epoch 13
# Epoch 14:total=3.0587, cls=0.1227, recon=1.0406 (0.9722, 1.0461),  smooth=0.0221, latent=16.5673
# Validation loss: 13.0455 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.4375 |val_class:1.1279 val_recon:0.9303 val_smooth: 0.0267 val_latent:15.6968
# Epoch 14
# Epoch 15:total=3.0386, cls=0.1209, recon=1.0408 (0.9720, 1.0457),  smooth=0.0219, latent=16.6661
# Validation loss: 12.9021 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:1.1147 val_recon:0.9367 val_smooth: 0.0249 val_latent:16.1169
# Epoch 15
# Epoch 16:total=2.8999, cls=0.1077, recon=1.0377 (0.9587, 1.0426),  smooth=0.0216, latent=16.6035
# Validation loss: 14.8122 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.4375 |val_class:1.2972 val_recon:0.9806 val_smooth: 0.0291 val_latent:15.5184
# Learning rate changed to 0.000063
# Early stopping at epoch 15
# Train accuracy: 0.89969 | Val accuracy: 0.88073 | Test accuracy: 0.86314
#
# === Fold 7/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=42.9583, cls=1.2050, recon=21.4401 (21.6342, 21.4296),  smooth=0.8909, latent=32.0498
# Validation loss: 16.5905 | Val acc: 0.2339 |Val acc (NS/BH/CV): 0.5000 |val_class:1.4170 val_recon:1.0230 val_smooth: 0.0842 val_latent:28.1718
# Epoch 1
# Epoch 2:total=11.5256, cls=0.9277, recon=1.2743 (1.1086, 1.2834),  smooth=0.0416, latent=29.9507
# Validation loss: 13.4451 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.3125 |val_class:1.0881 val_recon:1.1604 val_smooth: 0.0851 val_latent:22.7676
# Epoch 2
# Epoch 3:total=10.2512, cls=0.8063, recon=1.2237 (1.1558, 1.2248),  smooth=0.0403, latent=29.9704
# Validation loss: 14.0317 | Val acc: 0.6239 |Val acc (NS/BH/CV): 0.3750 |val_class:1.1615 val_recon:1.1139 val_smooth: 0.0746 val_latent:23.8627
# Epoch 3
# Epoch 4:total=8.7319, cls=0.6578, recon=1.2185 (1.1393, 1.2247),  smooth=0.0372, latent=29.0868
# Validation loss: 19.8913 | Val acc: 0.7018 |Val acc (NS/BH/CV): 0.3125 |val_class:1.1415 val_recon:5.3506 val_smooth: 0.2577 val_latent:12.7822
# Epoch 4
# Epoch 5:total=7.6939, cls=0.5592, recon=1.1977 (1.2041, 1.1971),  smooth=0.0338, latent=27.7498
# Validation loss: 16.0894 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.3125 |val_class:1.2969 val_recon:1.6314 val_smooth: 0.0929 val_latent:19.5363
# Epoch 5
# Epoch 6:total=6.5166, cls=0.4473, recon=1.1731 (1.1725, 1.1727),  smooth=0.0302, latent=26.9436
# Validation loss: 14.4909 | Val acc: 0.6560 |Val acc (NS/BH/CV): 0.3125 |val_class:1.2036 val_recon:1.2845 val_smooth: 0.0607 val_latent:19.8596
# Epoch 6
# Epoch 7:total=5.6955, cls=0.3685, recon=1.1519 (1.0911, 1.1530),  smooth=0.0287, latent=26.2768
# Validation loss: 16.0599 | Val acc: 0.6101 |Val acc (NS/BH/CV): 0.4375 |val_class:1.4171 val_recon:1.0059 val_smooth: 0.0310 val_latent:25.4392
# Epoch 7
# Epoch 8:total=5.4751, cls=0.3492, recon=1.1364 (1.0783, 1.1408),  smooth=0.0272, latent=25.2003
# Validation loss: 24.1723 | Val acc: 0.6514 |Val acc (NS/BH/CV): 0.3125 |val_class:2.2216 val_recon:1.1535 val_smooth: 0.0223 val_latent:28.6997
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=4.4564, cls=0.2496, recon=1.1214 (1.1143, 1.1228),  smooth=0.0264, latent=24.0614
# Validation loss: 12.7690 | Val acc: 0.7431 |Val acc (NS/BH/CV): 0.4375 |val_class:1.0980 val_recon:0.9751 val_smooth: 0.0238 val_latent:24.7551
# Epoch 9
# Epoch 10:total=4.0848, cls=0.2136, recon=1.1159 (1.0582, 1.1211),  smooth=0.0257, latent=24.0769
# Validation loss: 12.0360 | Val acc: 0.7661 |Val acc (NS/BH/CV): 0.5625 |val_class:1.0209 val_recon:1.0549 val_smooth: 0.0194 val_latent:27.1612
# Epoch 10
# Epoch 11:total=4.0360, cls=0.2089, recon=1.1160 (1.0932, 1.1184),  smooth=0.0255, latent=24.0783
# Validation loss: 13.1834 | Val acc: 0.7339 |Val acc (NS/BH/CV): 0.4375 |val_class:1.1375 val_recon:0.9522 val_smooth: 0.0281 val_latent:23.2276
# Epoch 11
# Epoch 12:total=3.9115, cls=0.1972, recon=1.1104 (1.0837, 1.1135),  smooth=0.0253, latent=24.0591
# Validation loss: 13.2230 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.5000 |val_class:1.1441 val_recon:0.9890 val_smooth: 0.0215 val_latent:25.9332
# Epoch 12
# Epoch 13:total=3.5718, cls=0.1644, recon=1.1006 (1.0326, 1.1066),  smooth=0.0251, latent=24.0685
# Validation loss: 13.2247 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.4375 |val_class:1.1458 val_recon:0.9587 val_smooth: 0.0231 val_latent:24.7890
# Epoch 13
# Epoch 14:total=3.6136, cls=0.1690, recon=1.1006 (1.0541, 1.1029),  smooth=0.0247, latent=24.0149
# Validation loss: 14.3527 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.3750 |val_class:1.2518 val_recon:0.9672 val_smooth: 0.0293 val_latent:22.3523
# Epoch 14
# Epoch 15:total=3.6309, cls=0.1715, recon=1.0957 (1.0461, 1.0984),  smooth=0.0243, latent=23.9754
# Validation loss: 14.3253 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.4375 |val_class:1.2374 val_recon:1.0317 val_smooth: 0.0346 val_latent:20.4934
# Epoch 15
# Epoch 16:total=3.4386, cls=0.1530, recon=1.0894 (1.0148, 1.0945),  smooth=0.0242, latent=23.9408
# Validation loss: 13.4773 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.4375 |val_class:1.1722 val_recon:0.9489 val_smooth: 0.0229 val_latent:23.9451
# Learning rate changed to 0.000063
# Epoch 16
# Epoch 17:total=3.2436, cls=0.1343, recon=1.0872 (1.0072, 1.0924),  smooth=0.0237, latent=23.9406
# Validation loss: 14.9158 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.5000 |val_class:1.3153 val_recon:0.9402 val_smooth: 0.0246 val_latent:23.6306
# Epoch 17
# Epoch 18:total=3.3287, cls=0.1431, recon=1.0837 (1.0331, 1.0881),  smooth=0.0237, latent=23.8625
# Validation loss: 13.8152 | Val acc: 0.7844 |Val acc (NS/BH/CV): 0.5000 |val_class:1.2051 val_recon:0.9263 val_smooth: 0.0262 val_latent:22.9517
# Epoch 18
# Epoch 19:total=3.3154, cls=0.1417, recon=1.0836 (1.0361, 1.0875),  smooth=0.0238, latent=23.7906
# Validation loss: 13.4028 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.4375 |val_class:1.1617 val_recon:0.9384 val_smooth: 0.0272 val_latent:22.2502
# Epoch 19
# Epoch 20:total=3.3394, cls=0.1446, recon=1.0816 (1.0256, 1.0854),  smooth=0.0235, latent=23.8429
# Validation loss: 14.5286 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.3750 |val_class:1.2777 val_recon:0.9328 val_smooth: 0.0242 val_latent:23.6746
# Train accuracy: 0.96130 | Val accuracy: 0.79358 | Test accuracy: 0.84307
#
# === Fold 8/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=48.4302, cls=1.3713, recon=22.4730 (22.7109, 22.4581),  smooth=1.1689, latent=29.0786
# Validation loss: 14.3698 | Val acc: 0.6147 |Val acc (NS/BH/CV): 0.3529 |val_class:1.1778 val_recon:1.6701 val_smooth: 0.0362 val_latent:34.2275
# Epoch 1
# Epoch 2:total=12.4665, cls=1.0039, recon=1.3990 (1.2357, 1.4090),  smooth=0.0477, latent=25.6347
# Validation loss: 19.3834 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.1176 |val_class:1.2540 val_recon:3.5537 val_smooth: 0.2752 val_latent:12.4009
# Epoch 2
# Epoch 3:total=10.7015, cls=0.8477, recon=1.2616 (1.1546, 1.2693),  smooth=0.0413, latent=23.5741
# Validation loss: 13.5718 | Val acc: 0.7706 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0712 val_recon:1.4479 val_smooth: 0.0868 val_latent:16.9405
# Epoch 3
# Epoch 4:total=9.4358, cls=0.7258, recon=1.2407 (1.1327, 1.2474),  smooth=0.0387, latent=22.9304
# Validation loss: 12.0546 | Val acc: 0.7431 |Val acc (NS/BH/CV): 0.3529 |val_class:1.0126 val_recon:1.0247 val_smooth: 0.0352 val_latent:23.5633
# Epoch 4
# Epoch 5:total=8.6991, cls=0.6575, recon=1.2107 (1.1192, 1.2153),  smooth=0.0362, latent=22.2800
# Validation loss: 11.4392 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.4706 |val_class:0.9549 val_recon:1.0141 val_smooth: 0.0324 val_latent:21.9961
# Epoch 5
# Epoch 6:total=7.4426, cls=0.5367, recon=1.1969 (1.1333, 1.2024),  smooth=0.0326, latent=21.6505
# Validation loss: 13.3443 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.2353 |val_class:1.1352 val_recon:1.0216 val_smooth: 0.0419 val_latent:19.8219
# Epoch 6
# Epoch 7:total=6.9271, cls=0.4883, recon=1.1694 (1.0970, 1.1749),  smooth=0.0320, latent=20.7799
# Validation loss: 16.6894 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.1765 |val_class:1.4735 val_recon:1.1923 val_smooth: 0.0203 val_latent:23.8146
# Epoch 7
# Epoch 8:total=6.5517, cls=0.4524, recon=1.1700 (1.1028, 1.1765),  smooth=0.0303, latent=19.3976
# Validation loss: 12.5190 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.4118 |val_class:1.0388 val_recon:1.4488 val_smooth: 0.0119 val_latent:25.9003
# Epoch 8
# Epoch 9:total=5.7419, cls=0.3749, recon=1.1489 (1.0745, 1.1536),  smooth=0.0287, latent=18.1089
# Validation loss: 14.5285 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.3529 |val_class:1.2134 val_recon:1.3249 val_smooth: 0.0516 val_latent:13.5528
# Epoch 9
# Epoch 10:total=5.2902, cls=0.3336, recon=1.1201 (1.0352, 1.1271),  smooth=0.0276, latent=16.8882
# Validation loss: 13.5713 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.3529 |val_class:1.1624 val_recon:1.2529 val_smooth: 0.0132 val_latent:20.3932
# Epoch 10
# Epoch 11:total=4.5992, cls=0.2678, recon=1.0922 (0.9926, 1.0999),  smooth=0.0269, latent=16.4881
# Validation loss: 13.5339 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.4706 |val_class:1.1615 val_recon:1.0118 val_smooth: 0.0350 val_latent:13.6960
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=4.0401, cls=0.2144, recon=1.0801 (1.0011, 1.0870),  smooth=0.0256, latent=16.1298
# Validation loss: 15.4023 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.4118 |val_class:1.3570 val_recon:0.9421 val_smooth: 0.0331 val_latent:14.6827
# Epoch 12
# Epoch 13:total=3.8187, cls=0.1929, recon=1.0756 (0.9877, 1.0808),  smooth=0.0253, latent=16.3402
# Validation loss: 14.7207 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4706 |val_class:1.3020 val_recon:0.8913 val_smooth: 0.0249 val_latent:16.2821
# Epoch 13
# Epoch 14:total=3.6599, cls=0.1778, recon=1.0696 (0.9727, 1.0761),  smooth=0.0252, latent=16.4546
# Validation loss: 13.8315 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.4706 |val_class:1.2140 val_recon:0.9255 val_smooth: 0.0204 val_latent:17.5245
# Epoch 14
# Epoch 15:total=3.6135, cls=0.1736, recon=1.0689 (0.9761, 1.0755),  smooth=0.0248, latent=16.5952
# Validation loss: 14.3136 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4118 |val_class:1.2623 val_recon:0.9233 val_smooth: 0.0205 val_latent:17.6687
# Epoch 15
# Epoch 16:total=3.5468, cls=0.1675, recon=1.0635 (0.9732, 1.0692),  smooth=0.0247, latent=16.6815
# Validation loss: 14.1194 | Val acc: 0.8761 |Val acc (NS/BH/CV): 0.4118 |val_class:1.2409 val_recon:0.9628 val_smooth: 0.0184 val_latent:18.4130
# Epoch 16
# Epoch 17:total=3.4573, cls=0.1590, recon=1.0629 (0.9685, 1.0717),  smooth=0.0243, latent=16.7565
# Validation loss: 14.9428 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.4118 |val_class:1.3211 val_recon:1.0035 val_smooth: 0.0165 val_latent:18.7733
# Learning rate changed to 0.000063
# Early stopping at epoch 16
# Train accuracy: 0.86762 | Val accuracy: 0.80734 | Test accuracy: 0.81569
#
# === Fold 9/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=149.3513, cls=1.2770, recon=112.7314 (113.7404, 112.6716),  smooth=2.3316, latent=15.8769
# Validation loss: 15.8243 | Val acc: 0.7110 |Val acc (NS/BH/CV): 0.3529 |val_class:1.3033 val_recon:1.8048 val_smooth: 0.0441 val_latent:26.4221
# Epoch 1
# Epoch 2:total=13.1146, cls=1.0852, recon=1.3748 (1.1639, 1.3874),  smooth=0.0346, latent=23.0477
# Validation loss: 15.2616 | Val acc: 0.4817 |Val acc (NS/BH/CV): 0.3529 |val_class:1.2961 val_recon:1.5560 val_smooth: 0.0200 val_latent:26.2490
# Epoch 2
# Epoch 3:total=11.4872, cls=0.9434, recon=1.2268 (1.1656, 1.2299),  smooth=0.0286, latent=21.7487
# Validation loss: 17.9575 | Val acc: 0.3486 |Val acc (NS/BH/CV): 0.4706 |val_class:1.5366 val_recon:1.9062 val_smooth: 0.0134 val_latent:31.3547
# Epoch 3
# Epoch 4:total=10.8856, cls=0.8838, recon=1.2086 (1.1675, 1.2146),  smooth=0.0297, latent=21.2445
# Validation loss: 15.6166 | Val acc: 0.4312 |Val acc (NS/BH/CV): 0.4118 |val_class:1.3398 val_recon:1.4980 val_smooth: 0.0174 val_latent:25.6590
# Epoch 4
# Epoch 5:total=9.7485, cls=0.7732, recon=1.1852 (1.1694, 1.1840),  smooth=0.0289, latent=20.4297
# Validation loss: 16.1055 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.2941 |val_class:1.3977 val_recon:1.2495 val_smooth: 0.0336 val_latent:19.8604
# Epoch 5
# Epoch 6:total=8.6520, cls=0.6650, recon=1.1706 (1.1172, 1.1752),  smooth=0.0287, latent=19.6136
# Validation loss: 19.3329 | Val acc: 0.7477 |Val acc (NS/BH/CV): 0.3529 |val_class:1.7261 val_recon:1.2501 val_smooth: 0.0275 val_latent:20.7627
# Epoch 6
# Epoch 7:total=7.8811, cls=0.5890, recon=1.1637 (1.1178, 1.1665),  smooth=0.0282, latent=18.7103
# Validation loss: 20.7576 | Val acc: 0.6789 |Val acc (NS/BH/CV): 0.3529 |val_class:1.8652 val_recon:1.2198 val_smooth: 0.0340 val_latent:17.2613
# Epoch 7
# Epoch 8:total=6.3702, cls=0.4434, recon=1.1237 (1.0413, 1.1310),  smooth=0.0265, latent=17.8984
# Validation loss: 22.8191 | Val acc: 0.7294 |Val acc (NS/BH/CV): 0.2353 |val_class:2.0774 val_recon:1.2203 val_smooth: 0.0276 val_latent:17.9017
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=5.5603, cls=0.3641, recon=1.1145 (1.0477, 1.1198),  smooth=0.0256, latent=17.6517
# Validation loss: 20.0539 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.2941 |val_class:1.8000 val_recon:1.1647 val_smooth: 0.0343 val_latent:15.6605
# Epoch 9
# Epoch 10:total=4.9476, cls=0.3039, recon=1.1064 (1.0233, 1.1126),  smooth=0.0253, latent=17.5234
# Validation loss: 20.8773 | Val acc: 0.7156 |Val acc (NS/BH/CV): 0.4706 |val_class:1.8980 val_recon:1.1311 val_smooth: 0.0216 val_latent:18.7857
# Epoch 10
# Epoch 11:total=5.0603, cls=0.3157, recon=1.1035 (1.0215, 1.1095),  smooth=0.0250, latent=17.5359
# Validation loss: 20.7569 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.3529 |val_class:1.8866 val_recon:1.1095 val_smooth: 0.0231 val_latent:18.3047
# Epoch 11
# Epoch 12:total=4.9344, cls=0.3035, recon=1.0992 (1.0179, 1.1051),  smooth=0.0251, latent=17.4921
# Validation loss: 21.9591 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.3529 |val_class:2.0093 val_recon:1.0549 val_smooth: 0.0262 val_latent:17.3293
# Epoch 12
# Epoch 13:total=4.6806, cls=0.2787, recon=1.0972 (1.0034, 1.1032),  smooth=0.0246, latent=17.5799
# Validation loss: 22.6317 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.4118 |val_class:2.0774 val_recon:1.0899 val_smooth: 0.0216 val_latent:18.8858
# Epoch 13
# Epoch 14:total=4.4676, cls=0.2582, recon=1.0879 (0.9904, 1.0946),  smooth=0.0247, latent=17.5056
# Validation loss: 25.3347 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.2941 |val_class:2.3351 val_recon:1.0996 val_smooth: 0.0335 val_latent:15.8502
# Learning rate changed to 0.000063
# Early stopping at epoch 13
# Train accuracy: 0.50407 | Val accuracy: 0.48165 | Test accuracy: 0.47080
#
# === Fold 10/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=122.4894, cls=1.3528, recon=89.1236 (89.8911, 89.0809),  smooth=1.9306, latent=13.9685
# Validation loss: 14.9170 | Val acc: 0.4495 |Val acc (NS/BH/CV): 0.4118 |val_class:1.2512 val_recon:1.1936 val_smooth: 0.0674 val_latent:18.5848
# Epoch 1
# Epoch 2:total=13.5212, cls=1.1267, recon=1.3698 (1.2893, 1.3779),  smooth=0.0346, latent=19.5049
# Validation loss: 14.6211 | Val acc: 0.6881 |Val acc (NS/BH/CV): 0.1765 |val_class:1.1096 val_recon:2.1069 val_smooth: 0.0888 val_latent:11.5996
# Epoch 2
# Epoch 3:total=11.6825, cls=0.9638, recon=1.2182 (1.2274, 1.2186),  smooth=0.0289, latent=18.1746
# Validation loss: 12.8064 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.3529 |val_class:1.0612 val_recon:1.1585 val_smooth: 0.0502 val_latent:14.3434
# Epoch 3
# Epoch 4:total=10.6550, cls=0.8669, recon=1.1712 (1.2037, 1.1714),  smooth=0.0278, latent=17.5961
# Validation loss: 12.0456 | Val acc: 0.6697 |Val acc (NS/BH/CV): 0.5882 |val_class:0.9910 val_recon:1.1217 val_smooth: 0.0479 val_latent:14.2734
# Epoch 4
# Epoch 5:total=9.3431, cls=0.7379, recon=1.1577 (1.2098, 1.1536),  smooth=0.0269, latent=17.2277
# Validation loss: 13.4501 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.2353 |val_class:1.1367 val_recon:1.1315 val_smooth: 0.0416 val_latent:14.0293
# Epoch 5
# Epoch 6:total=8.2833, cls=0.6349, recon=1.1401 (1.1510, 1.1406),  smooth=0.0255, latent=17.1095
# Validation loss: 16.2102 | Val acc: 0.5275 |Val acc (NS/BH/CV): 0.3529 |val_class:1.4352 val_recon:1.0249 val_smooth: 0.0293 val_latent:17.4067
# Epoch 6
# Epoch 7:total=7.7025, cls=0.5760, recon=1.1469 (1.1727, 1.1451),  smooth=0.0255, latent=16.7467
# Validation loss: 12.7149 | Val acc: 0.5321 |Val acc (NS/BH/CV): 0.4706 |val_class:1.0884 val_recon:1.0720 val_smooth: 0.0218 val_latent:16.4540
# Epoch 7
# Epoch 8:total=6.8475, cls=0.4941, recon=1.1192 (1.1379, 1.1180),  smooth=0.0246, latent=15.7695
# Validation loss: 21.6296 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.1176 |val_class:1.9076 val_recon:1.9212 val_smooth: 0.0081 val_latent:24.8788
# Epoch 8
# Epoch 9:total=6.0854, cls=0.4194, recon=1.1075 (1.0790, 1.1092),  smooth=0.0242, latent=15.3889
# Validation loss: 17.0224 | Val acc: 0.6147 |Val acc (NS/BH/CV): 0.3529 |val_class:1.4590 val_recon:1.3603 val_smooth: 0.0533 val_latent:11.5535
# Epoch 9
# Epoch 10:total=5.5300, cls=0.3661, recon=1.0928 (1.0544, 1.0991),  smooth=0.0233, latent=15.0648
# Validation loss: 17.2083 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.2941 |val_class:1.5300 val_recon:1.0303 val_smooth: 0.0337 val_latent:13.2573
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=4.7175, cls=0.2865, recon=1.0780 (1.0338, 1.0817),  smooth=0.0231, latent=15.0111
# Validation loss: 15.1628 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.4118 |val_class:1.3447 val_recon:0.9575 val_smooth: 0.0214 val_latent:15.5853
# Epoch 11
# Epoch 12:total=4.4429, cls=0.2596, recon=1.0757 (1.0071, 1.0804),  smooth=0.0227, latent=14.8989
# Validation loss: 14.5843 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4118 |val_class:1.2861 val_recon:0.9508 val_smooth: 0.0229 val_latent:15.2195
# Epoch 12
# Epoch 13:total=4.2381, cls=0.2394, recon=1.0743 (1.0002, 1.0790),  smooth=0.0226, latent=14.9905
# Validation loss: 17.8772 | Val acc: 0.7752 |Val acc (NS/BH/CV): 0.3529 |val_class:1.6088 val_recon:0.9472 val_smooth: 0.0300 val_latent:13.9497
# Epoch 13
# Epoch 14:total=4.1483, cls=0.2303, recon=1.0759 (1.0334, 1.0798),  smooth=0.0226, latent=15.0143
# Validation loss: 16.8483 | Val acc: 0.7706 |Val acc (NS/BH/CV): 0.3529 |val_class:1.4888 val_recon:1.0563 val_smooth: 0.0363 val_latent:12.5799
# Epoch 14
# Epoch 15:total=4.0389, cls=0.2194, recon=1.0778 (1.0460, 1.0761),  smooth=0.0223, latent=15.0182
# Validation loss: 15.2891 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.4118 |val_class:1.3573 val_recon:0.9321 val_smooth: 0.0240 val_latent:14.9214
# Epoch 15
# Epoch 16:total=3.9193, cls=0.2085, recon=1.0686 (0.9948, 1.0721),  smooth=0.0222, latent=15.1203
# Validation loss: 16.6057 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.4118 |val_class:1.4825 val_recon:0.9439 val_smooth: 0.0294 val_latent:13.7038
# Learning rate changed to 0.000063
# Early stopping at epoch 15
# Train accuracy: 0.64155 | Val accuracy: 0.66972 | Test accuracy: 0.56752

# %%
all_results3, train_data, test_data = semisupervised_kfold_test(
    SemiSupervisedAE,
    np.column_stack([pn_normspec_labelled, pn_counts_labelled]),
    pn_spec_labels,
    np.column_stack([pn_normspec[unlabelled_args], pn_counts[unlabelled_args]]),
    epochs=20, lambda_cls=10, l2_lambda=1.0e-3, l1_lambda=1.0e-4, lr=1.0e-3,
    train_ids=pn_labelled_trainids.astype(int),
    test_ids=pn_labelled_testids.astype(int),
    weights=(class_weights**2).tolist(), k_folds=5)
# Out:
# === Fold 1/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=37.7078, cls=1.1738, recon=17.8422 (18.1423, 17.8250),  smooth=0.7573, latent=29.3624
# Validation loss: 35.1182 | Val acc: 0.1050 |Val acc (NS/BH/CV): 0.5294 |val_class:1.2642 val_recon:11.8994 val_smooth: 1.0044 val_latent:7.0145
# Epoch 1
# Epoch 2:total=12.1582, cls=0.9633, recon=1.4382 (1.1959, 1.4545),  smooth=0.0536, latent=25.3825
# Validation loss: 19.6074 | Val acc: 0.1187 |Val acc (NS/BH/CV): 0.4706 |val_class:1.2670 val_recon:4.0765 val_smooth: 0.2325 val_latent:10.2971
# Epoch 2
# Epoch 3:total=10.1309, cls=0.7907, recon=1.2468 (1.1463, 1.2545),  smooth=0.0430, latent=21.6499
# Validation loss: 16.8240 | Val acc: 0.2603 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1826 val_recon:3.0030 val_smooth: 0.1456 val_latent:11.3181
# Epoch 3
# Epoch 4:total=9.0014, cls=0.6844, recon=1.2135 (1.1192, 1.2181),  smooth=0.0396, latent=20.7061
# Validation loss: 15.3376 | Val acc: 0.2557 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2762 val_recon:1.2839 val_smooth: 0.0748 val_latent:15.1296
# Epoch 4
# Epoch 5:total=7.7027, cls=0.5610, recon=1.1934 (1.1283, 1.1965),  smooth=0.0350, latent=19.0090
# Validation loss: 23.2468 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.1176 |val_class:1.7229 val_recon:3.8148 val_smooth: 0.1661 val_latent:10.7887
# Epoch 5
# Epoch 6:total=7.7656, cls=0.5670, recon=1.2181 (1.1427, 1.2258),  smooth=0.0327, latent=17.9678
# Validation loss: 16.0373 | Val acc: 0.2009 |Val acc (NS/BH/CV): 0.4706 |val_class:1.2981 val_recon:1.6420 val_smooth: 0.0869 val_latent:11.1808
# Epoch 6
# Epoch 7:total=6.3030, cls=0.4315, recon=1.1366 (1.0641, 1.1419),  smooth=0.0300, latent=16.3058
# Validation loss: 15.6439 | Val acc: 0.7306 |Val acc (NS/BH/CV): 0.4118 |val_class:1.3390 val_recon:1.2136 val_smooth: 0.0491 val_latent:13.0214
# Epoch 7
# Epoch 8:total=6.2975, cls=0.4320, recon=1.1359 (1.0598, 1.1433),  smooth=0.0287, latent=15.6932
# Validation loss: 18.6444 | Val acc: 0.6621 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1952 val_recon:4.7060 val_smooth: 0.1439 val_latent:7.3688
# Epoch 8
# Epoch 9:total=5.3566, cls=0.3425, recon=1.1059 (1.0078, 1.1132),  smooth=0.0270, latent=14.3616
# Validation loss: 17.5960 | Val acc: 0.5388 |Val acc (NS/BH/CV): 0.4118 |val_class:1.5856 val_recon:0.9347 val_smooth: 0.0249 val_latent:13.7946
# Epoch 9
# Epoch 10:total=5.1012, cls=0.3181, recon=1.0971 (1.0077, 1.1027),  smooth=0.0265, latent=14.0034
# Validation loss: 14.0406 | Val acc: 0.5662 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2358 val_recon:0.9011 val_smooth: 0.0224 val_latent:13.0298
# Epoch 10
# Epoch 11:total=3.7458, cls=0.1876, recon=1.0699 (0.9912, 1.0754),  smooth=0.0241, latent=13.4215
# Validation loss: 16.9175 | Val acc: 0.6804 |Val acc (NS/BH/CV): 0.2353 |val_class:1.5247 val_recon:0.8773 val_smooth: 0.0233 val_latent:14.1777
# Epoch 11
# Epoch 12:total=4.0721, cls=0.2210, recon=1.0655 (0.9780, 1.0699),  smooth=0.0236, latent=13.7359
# Validation loss: 14.8552 | Val acc: 0.6347 |Val acc (NS/BH/CV): 0.3529 |val_class:1.3171 val_recon:0.9164 val_smooth: 0.0205 val_latent:15.9473
# Epoch 12
# Epoch 13:total=4.1533, cls=0.2313, recon=1.0536 (0.9580, 1.0584),  smooth=0.0226, latent=13.9582
# Validation loss: 23.8381 | Val acc: 0.4840 |Val acc (NS/BH/CV): 0.4118 |val_class:2.1265 val_recon:1.9501 val_smooth: 0.0055 val_latent:19.8581
# Epoch 13
# Epoch 14:total=3.5584, cls=0.1721, recon=1.0518 (0.9658, 1.0565),  smooth=0.0223, latent=13.7585
# Validation loss: 15.5573 | Val acc: 0.5753 |Val acc (NS/BH/CV): 0.3529 |val_class:1.3873 val_recon:0.8968 val_smooth: 0.0224 val_latent:14.5392
# Epoch 14
# Epoch 15:total=3.0114, cls=0.1195, recon=1.0432 (0.9570, 1.0497),  smooth=0.0211, latent=13.2628
# Validation loss: 21.9704 | Val acc: 0.8037 |Val acc (NS/BH/CV): 0.2353 |val_class:1.8741 val_recon:2.0947 val_smooth: 0.0577 val_latent:9.5946
# Epoch 15
# Epoch 16:total=3.7077, cls=0.1888, recon=1.0482 (0.9835, 1.0518),  smooth=0.0209, latent=13.7188
# Validation loss: 22.2277 | Val acc: 0.7215 |Val acc (NS/BH/CV): 0.3529 |val_class:2.0341 val_recon:0.9542 val_smooth: 0.0371 val_latent:12.7073
# Learning rate changed to 0.000250
# Epoch 16
# Epoch 17:total=2.7283, cls=0.0939, recon=1.0320 (0.9593, 1.0375),  smooth=0.0195, latent=13.3371
# Validation loss: 22.9110 | Val acc: 0.7489 |Val acc (NS/BH/CV): 0.2353 |val_class:2.1233 val_recon:0.8647 val_smooth: 0.0252 val_latent:12.2517
# Epoch 17
# Epoch 18:total=2.8936, cls=0.1110, recon=1.0302 (0.9560, 1.0362),  smooth=0.0191, latent=13.3609
# Validation loss: 23.9545 | Val acc: 0.7900 |Val acc (NS/BH/CV): 0.1765 |val_class:2.2338 val_recon:0.8551 val_smooth: 0.0200 val_latent:13.3375
# Epoch 18
# Epoch 19:total=2.7330, cls=0.0953, recon=1.0282 (0.9417, 1.0336),  smooth=0.0190, latent=13.5669
# Validation loss: 24.0026 | Val acc: 0.7945 |Val acc (NS/BH/CV): 0.1765 |val_class:2.2300 val_recon:0.8979 val_smooth: 0.0245 val_latent:12.6493
# Epoch 19
# Epoch 20:total=2.6683, cls=0.0894, recon=1.0246 (0.9429, 1.0299),  smooth=0.0189, latent=13.6314
# Validation loss: 23.9465 | Val acc: 0.7854 |Val acc (NS/BH/CV): 0.1765 |val_class:2.2334 val_recon:0.8528 val_smooth: 0.0199 val_latent:14.0940
# Train accuracy: 0.89659 | Val accuracy: 0.78539 | Test accuracy: 0.77737
#
# === Fold 2/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=41.2763, cls=1.2649, recon=18.5292 (18.4609, 18.5342),  smooth=0.9553, latent=19.4512
# Validation loss: 15.6937 | Val acc: 0.0457 |Val acc (NS/BH/CV): 0.5294 |val_class:1.3007 val_recon:1.7869 val_smooth: 0.0353 val_latent:20.3731
# Epoch 1
# Epoch 2:total=11.8790, cls=0.9492, recon=1.3358 (1.1546, 1.3461),  smooth=0.0510, latent=15.2204
# Validation loss: 9.4663 | Val acc: 0.2648 |Val acc (NS/BH/CV): 0.6471 |val_class:0.7207 val_recon:1.4038 val_smooth: 0.0311 val_latent:18.2630
# Epoch 2
# Epoch 3:total=11.2881, cls=0.9054, recon=1.2477 (1.1359, 1.2556),  smooth=0.0445, latent=13.5834
# Validation loss: 9.6304 | Val acc: 0.3014 |Val acc (NS/BH/CV): 0.8824 |val_class:0.6975 val_recon:1.2495 val_smooth: 0.0868 val_latent:9.8343
# Epoch 3
# Epoch 4:total=10.2985, cls=0.8109, recon=1.2378 (1.1741, 1.2438),  smooth=0.0411, latent=11.8647
# Validation loss: 10.5796 | Val acc: 0.2283 |Val acc (NS/BH/CV): 0.7059 |val_class:0.8630 val_recon:1.0668 val_smooth: 0.0341 val_latent:12.0570
# Epoch 4
# Epoch 5:total=9.3802, cls=0.7291, recon=1.1738 (1.1576, 1.1749),  smooth=0.0374, latent=11.1981
# Validation loss: 13.1164 | Val acc: 0.6530 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9405 val_recon:1.8958 val_smooth: 0.1277 val_latent:7.2605
# Epoch 5
# Epoch 6:total=8.1948, cls=0.6158, recon=1.1540 (1.0716, 1.1577),  smooth=0.0340, latent=10.7651
# Validation loss: 10.0597 | Val acc: 0.4018 |Val acc (NS/BH/CV): 0.7647 |val_class:0.7985 val_recon:1.3576 val_smooth: 0.0170 val_latent:14.1803
# Epoch 6
# Epoch 7:total=8.0677, cls=0.6046, recon=1.1385 (1.0505, 1.1444),  smooth=0.0338, latent=10.3344
# Validation loss: 13.4104 | Val acc: 0.4247 |Val acc (NS/BH/CV): 0.6471 |val_class:1.1285 val_recon:1.0586 val_smooth: 0.0522 val_latent:8.4287
# Epoch 7
# Epoch 8:total=6.5778, cls=0.4597, recon=1.1178 (1.0660, 1.1209),  smooth=0.0315, latent=9.8436
# Validation loss: 14.0497 | Val acc: 0.2146 |Val acc (NS/BH/CV): 0.7059 |val_class:1.2249 val_recon:0.9485 val_smooth: 0.0303 val_latent:9.4264
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=6.5251, cls=0.4578, recon=1.0935 (1.0054, 1.0987),  smooth=0.0304, latent=9.5136
# Validation loss: 14.0458 | Val acc: 0.5845 |Val acc (NS/BH/CV): 0.7059 |val_class:1.2186 val_recon:0.9341 val_smooth: 0.0377 val_latent:8.8747
# Epoch 9
# Epoch 10:total=5.6423, cls=0.3711, recon=1.0894 (1.0101, 1.0948),  smooth=0.0292, latent=9.6833
# Validation loss: 16.3853 | Val acc: 0.6849 |Val acc (NS/BH/CV): 0.7647 |val_class:1.4428 val_recon:0.9886 val_smooth: 0.0420 val_latent:8.7588
# Epoch 10
# Epoch 11:total=5.4936, cls=0.3571, recon=1.0860 (0.9959, 1.0929),  smooth=0.0287, latent=9.8717
# Validation loss: 14.3930 | Val acc: 0.5114 |Val acc (NS/BH/CV): 0.7647 |val_class:1.2547 val_recon:0.9266 val_smooth: 0.0370 val_latent:8.8985
# Epoch 11
# Epoch 12:total=4.8538, cls=0.2940, recon=1.0797 (0.9603, 1.0873),  smooth=0.0283, latent=9.9537
# Validation loss: 13.6274 | Val acc: 0.4977 |Val acc (NS/BH/CV): 0.7647 |val_class:1.1846 val_recon:0.9469 val_smooth: 0.0284 val_latent:9.8485
# Epoch 12
# Epoch 13:total=4.9098, cls=0.3000, recon=1.0777 (0.9973, 1.0837),  smooth=0.0281, latent=10.1490
# Validation loss: 14.5790 | Val acc: 0.5434 |Val acc (NS/BH/CV): 0.7647 |val_class:1.2818 val_recon:0.9760 val_smooth: 0.0232 val_latent:11.0250
# Epoch 13
# Epoch 14:total=5.2430, cls=0.3344, recon=1.0715 (0.9751, 1.0778),  smooth=0.0276, latent=10.2970
# Validation loss: 17.2090 | Val acc: 0.5616 |Val acc (NS/BH/CV): 0.7059 |val_class:1.5443 val_recon:0.9249 val_smooth: 0.0290 val_latent:10.2339
# Learning rate changed to 0.000063
# Early stopping at epoch 13
# Train accuracy: 0.26184 | Val accuracy: 0.26484 | Test accuracy: 0.19343
#
# === Fold 3/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=202.8844, cls=1.2764, recon=166.9523 (167.3302, 166.9380),  smooth=2.2639, latent=11.2578
# Validation loss: 20.1103 | Val acc: 0.0367 |Val acc (NS/BH/CV): 0.5000 |val_class:1.2820 val_recon:6.1662 val_smooth: 0.0578 val_latent:24.5910
# Epoch 1
# Epoch 2:total=13.2350, cls=0.9521, recon=2.5266 (2.0054, 2.5607),  smooth=0.0650, latent=17.6013
# Validation loss: 12.5604 | Val acc: 0.1239 |Val acc (NS/BH/CV): 0.5625 |val_class:1.0294 val_recon:1.1469 val_smooth: 0.0585 val_latent:13.8439
# Epoch 2
# Epoch 3:total=11.3064, cls=0.9123, recon=1.2854 (1.2823, 1.2866),  smooth=0.0365, latent=14.0563
# Validation loss: 11.8575 | Val acc: 0.1193 |Val acc (NS/BH/CV): 0.6875 |val_class:1.0019 val_recon:1.0051 val_smooth: 0.0299 val_latent:14.2062
# Epoch 3
# Epoch 4:total=10.1681, cls=0.8132, recon=1.2001 (1.2159, 1.1996),  smooth=0.0302, latent=13.1435
# Validation loss: 11.4700 | Val acc: 0.1972 |Val acc (NS/BH/CV): 0.6250 |val_class:0.9459 val_recon:1.3345 val_smooth: 0.0139 val_latent:16.5576
# Epoch 4
# Epoch 5:total=10.1812, cls=0.8166, recon=1.1855 (1.2572, 1.1798),  smooth=0.0296, latent=12.5809
# Validation loss: 9.4679 | Val acc: 0.3624 |Val acc (NS/BH/CV): 0.7500 |val_class:0.7367 val_recon:1.1167 val_smooth: 0.0452 val_latent:9.8292
# Epoch 5
# Epoch 6:total=9.3497, cls=0.7387, recon=1.1544 (1.2435, 1.1497),  smooth=0.0274, latent=11.5423
# Validation loss: 10.5706 | Val acc: 0.4495 |Val acc (NS/BH/CV): 0.5625 |val_class:0.8759 val_recon:1.1009 val_smooth: 0.0175 val_latent:12.0786
# Epoch 6
# Epoch 7:total=8.3505, cls=0.6428, recon=1.1276 (1.1240, 1.1271),  smooth=0.0260, latent=10.7888
# Validation loss: 10.3086 | Val acc: 0.4817 |Val acc (NS/BH/CV): 0.7500 |val_class:0.7856 val_recon:1.4158 val_smooth: 0.0505 val_latent:7.5068
# Epoch 7
# Epoch 8:total=6.7343, cls=0.4855, recon=1.1051 (1.1058, 1.1063),  smooth=0.0239, latent=10.2495
# Validation loss: 9.7506 | Val acc: 0.3028 |Val acc (NS/BH/CV): 0.8125 |val_class:0.7608 val_recon:1.5079 val_smooth: 0.0094 val_latent:13.6622
# Epoch 8
# Epoch 9:total=6.6010, cls=0.4718, recon=1.1104 (1.1609, 1.1075),  smooth=0.0236, latent=9.8713
# Validation loss: 9.5993 | Val acc: 0.5413 |Val acc (NS/BH/CV): 0.6250 |val_class:0.7891 val_recon:0.9783 val_smooth: 0.0192 val_latent:10.2609
# Epoch 9
# Epoch 10:total=6.4369, cls=0.4561, recon=1.1068 (1.1204, 1.1063),  smooth=0.0231, latent=9.5552
# Validation loss: 9.3249 | Val acc: 0.5688 |Val acc (NS/BH/CV): 0.6875 |val_class:0.7600 val_recon:1.0217 val_smooth: 0.0163 val_latent:10.2575
# Epoch 10
# Epoch 11:total=5.8016, cls=0.3952, recon=1.0861 (1.0721, 1.0869),  smooth=0.0224, latent=9.1522
# Validation loss: 14.0441 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.5625 |val_class:1.1968 val_recon:1.1364 val_smooth: 0.0400 val_latent:7.9870
# Epoch 11
# Epoch 12:total=5.9519, cls=0.4123, recon=1.0712 (1.0575, 1.0730),  smooth=0.0217, latent=8.9061
# Validation loss: 13.1767 | Val acc: 0.7339 |Val acc (NS/BH/CV): 0.6250 |val_class:1.1383 val_recon:1.1175 val_smooth: 0.0134 val_latent:10.1775
# Epoch 12
# Epoch 13:total=4.9571, cls=0.3125, recon=1.0759 (1.0309, 1.0790),  smooth=0.0214, latent=9.2650
# Validation loss: 17.4958 | Val acc: 0.5183 |Val acc (NS/BH/CV): 0.3750 |val_class:1.5561 val_recon:1.0261 val_smooth: 0.0367 val_latent:8.3971
# Epoch 13
# Epoch 14:total=4.9617, cls=0.3143, recon=1.0677 (1.0259, 1.0696),  smooth=0.0208, latent=9.3004
# Validation loss: 14.7104 | Val acc: 0.6972 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2988 val_recon:0.8938 val_smooth: 0.0285 val_latent:8.6109
# Epoch 14
# Epoch 15:total=5.6139, cls=0.3784, recon=1.0750 (1.0415, 1.0780),  smooth=0.0210, latent=8.8021
# Validation loss: 10.5334 | Val acc: 0.6743 |Val acc (NS/BH/CV): 0.6250 |val_class:0.8599 val_recon:1.2839 val_smooth: 0.0102 val_latent:10.3523
# Epoch 15
# Epoch 16:total=4.5787, cls=0.2775, recon=1.0612 (1.0485, 1.0632),  smooth=0.0195, latent=8.7615
# Validation loss: 15.6337 | Val acc: 0.7844 |Val acc (NS/BH/CV): 0.4375 |val_class:1.3892 val_recon:1.0007 val_smooth: 0.0194 val_latent:8.2780
# Learning rate changed to 0.000250
# Epoch 16
# Epoch 17:total=3.8249, cls=0.2027, recon=1.0544 (1.0451, 1.0551),  smooth=0.0196, latent=8.3155
# Validation loss: 13.7846 | Val acc: 0.7477 |Val acc (NS/BH/CV): 0.6250 |val_class:1.2133 val_recon:0.9372 val_smooth: 0.0166 val_latent:8.6415
# Epoch 17
# Epoch 18:total=3.6555, cls=0.1867, recon=1.0506 (1.0423, 1.0527),  smooth=0.0190, latent=8.5895
# Validation loss: 15.7209 | Val acc: 0.7294 |Val acc (NS/BH/CV): 0.5000 |val_class:1.4098 val_recon:0.8772 val_smooth: 0.0198 val_latent:8.4676
# Epoch 18
# Epoch 19:total=3.5489, cls=0.1763, recon=1.0476 (1.0484, 1.0471),  smooth=0.0191, latent=8.7013
# Validation loss: 20.2300 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.5000 |val_class:1.6284 val_recon:2.7233 val_smooth: 0.0679 val_latent:6.0226
# Epoch 19
# Epoch 20:total=3.1804, cls=0.1392, recon=1.0507 (1.0103, 1.0443),  smooth=0.0190, latent=8.7296
# Validation loss: 14.7900 | Val acc: 0.7431 |Val acc (NS/BH/CV): 0.5625 |val_class:1.3141 val_recon:0.8939 val_smooth: 0.0209 val_latent:8.1007
# Train accuracy: 0.82179 | Val accuracy: 0.74312 | Test accuracy: 0.69161
#
# === Fold 4/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=95.5545, cls=1.2453, recon=65.0858 (65.8699, 65.0372),  smooth=1.7475, latent=17.5430
# Validation loss: 14.0699 | Val acc: 0.0505 |Val acc (NS/BH/CV): 0.6875 |val_class:1.1650 val_recon:1.5686 val_smooth: 0.0303 val_latent:24.3686
# Epoch 1
# Epoch 2:total=12.3386, cls=1.0122, recon=1.3113 (1.2101, 1.3179),  smooth=0.0362, latent=19.8652
# Validation loss: 14.6259 | Val acc: 0.1560 |Val acc (NS/BH/CV): 0.4375 |val_class:1.2579 val_recon:1.1258 val_smooth: 0.0378 val_latent:18.8577
# Epoch 2
# Epoch 3:total=10.9575, cls=0.8882, recon=1.1969 (1.1745, 1.1999),  smooth=0.0335, latent=18.4295
# Validation loss: 14.3362 | Val acc: 0.1284 |Val acc (NS/BH/CV): 0.6875 |val_class:1.1814 val_recon:1.8555 val_smooth: 0.0117 val_latent:24.5788
# Epoch 3
# Epoch 4:total=9.7857, cls=0.7749, recon=1.1879 (1.2021, 1.1868),  smooth=0.0305, latent=17.9338
# Validation loss: 14.5251 | Val acc: 0.2982 |Val acc (NS/BH/CV): 0.3750 |val_class:1.2382 val_recon:1.4337 val_smooth: 0.0161 val_latent:22.9403
# Epoch 4
# Epoch 5:total=9.5233, cls=0.7488, recon=1.1847 (1.1896, 1.1845),  smooth=0.0307, latent=17.2538
# Validation loss: 15.3063 | Val acc: 0.2018 |Val acc (NS/BH/CV): 0.6250 |val_class:1.2985 val_recon:1.6311 val_smooth: 0.0142 val_latent:21.5354
# Epoch 5
# Epoch 6:total=8.8196, cls=0.6813, recon=1.1679 (1.2259, 1.1638),  smooth=0.0294, latent=16.5503
# Validation loss: 15.9548 | Val acc: 0.2661 |Val acc (NS/BH/CV): 0.5625 |val_class:1.3827 val_recon:1.2027 val_smooth: 0.0379 val_latent:16.4516
# Epoch 6
# Epoch 7:total=8.0534, cls=0.6020, recon=1.2078 (1.2682, 1.2027),  smooth=0.0280, latent=15.2108
# Validation loss: 18.2795 | Val acc: 0.4541 |Val acc (NS/BH/CV): 0.4375 |val_class:1.6267 val_recon:1.2391 val_smooth: 0.0224 val_latent:17.3354
# Learning rate changed to 0.000250
# Epoch 7
# Epoch 8:total=6.5702, cls=0.4618, recon=1.1516 (1.1651, 1.1505),  smooth=0.0254, latent=15.0125
# Validation loss: 13.5829 | Val acc: 0.4817 |Val acc (NS/BH/CV): 0.6250 |val_class:1.1717 val_recon:1.0789 val_smooth: 0.0240 val_latent:15.2058
# Epoch 8
# Epoch 9:total=6.9413, cls=0.4996, recon=1.1442 (1.1346, 1.1461),  smooth=0.0255, latent=15.0004
# Validation loss: 14.3628 | Val acc: 0.5092 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2474 val_recon:1.1005 val_smooth: 0.0241 val_latent:15.3399
# Epoch 9
# Epoch 10:total=6.3187, cls=0.4379, recon=1.1395 (1.1291, 1.1414),  smooth=0.0253, latent=14.9800
# Validation loss: 13.7395 | Val acc: 0.5642 |Val acc (NS/BH/CV): 0.6250 |val_class:1.1863 val_recon:1.0618 val_smooth: 0.0268 val_latent:15.0284
# Epoch 10
# Epoch 11:total=5.8171, cls=0.3886, recon=1.1329 (1.1519, 1.1332),  smooth=0.0251, latent=14.8631
# Validation loss: 13.4646 | Val acc: 0.4633 |Val acc (NS/BH/CV): 0.6250 |val_class:1.1547 val_recon:1.1853 val_smooth: 0.0183 val_latent:16.6575
# Epoch 11
# Epoch 12:total=5.5979, cls=0.3676, recon=1.1238 (1.0819, 1.1250),  smooth=0.0250, latent=14.8640
# Validation loss: 14.4613 | Val acc: 0.6697 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2597 val_recon:1.0483 val_smooth: 0.0268 val_latent:14.7749
# Epoch 12
# Epoch 13:total=5.7755, cls=0.3860, recon=1.1243 (1.0892, 1.1277),  smooth=0.0243, latent=14.9405
# Validation loss: 14.9444 | Val acc: 0.6193 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2902 val_recon:1.1314 val_smooth: 0.0364 val_latent:13.3588
# Epoch 13
# Epoch 14:total=5.2378, cls=0.3327, recon=1.1194 (1.1015, 1.1225),  smooth=0.0243, latent=14.8563
# Validation loss: 15.2836 | Val acc: 0.6376 |Val acc (NS/BH/CV): 0.5000 |val_class:1.3416 val_recon:1.1124 val_smooth: 0.0205 val_latent:15.9026
# Epoch 14
# Epoch 15:total=5.4739, cls=0.3554, recon=1.1308 (1.1279, 1.1313),  smooth=0.0241, latent=14.8811
# Validation loss: 15.6237 | Val acc: 0.6514 |Val acc (NS/BH/CV): 0.5625 |val_class:1.3769 val_recon:1.0612 val_smooth: 0.0244 val_latent:14.9775
# Epoch 15
# Epoch 16:total=4.8335, cls=0.2932, recon=1.1141 (1.0947, 1.1161),  smooth=0.0238, latent=14.8480
# Validation loss: 15.9873 | Val acc: 0.5963 |Val acc (NS/BH/CV): 0.5625 |val_class:1.4114 val_recon:1.0532 val_smooth: 0.0271 val_latent:14.0800
# Epoch 16
# Epoch 17:total=4.5213, cls=0.2633, recon=1.1044 (1.0537, 1.1090),  smooth=0.0235, latent=14.7661
# Validation loss: 15.6937 | Val acc: 0.5550 |Val acc (NS/BH/CV): 0.5625 |val_class:1.3842 val_recon:1.0155 val_smooth: 0.0287 val_latent:14.2729
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=4.4627, cls=0.2576, recon=1.0999 (1.1041, 1.1002),  smooth=0.0238, latent=14.6151
# Validation loss: 15.2980 | Val acc: 0.5917 |Val acc (NS/BH/CV): 0.5625 |val_class:1.3448 val_recon:1.0437 val_smooth: 0.0258 val_latent:14.2280
# Epoch 18
# Epoch 19:total=4.3842, cls=0.2496, recon=1.1075 (1.0993, 1.1051),  smooth=0.0232, latent=14.6560
# Validation loss: 15.9877 | Val acc: 0.6514 |Val acc (NS/BH/CV): 0.5625 |val_class:1.4126 val_recon:1.0515 val_smooth: 0.0262 val_latent:14.2551
# Epoch 19
# Epoch 20:total=4.4186, cls=0.2535, recon=1.1030 (1.0902, 1.1045),  smooth=0.0231, latent=14.7174
# Validation loss: 16.1551 | Val acc: 0.6468 |Val acc (NS/BH/CV): 0.5625 |val_class:1.4312 val_recon:1.0415 val_smooth: 0.0252 val_latent:14.3677
# Train accuracy: 0.71894 | Val accuracy: 0.64679 | Test accuracy: 0.60401
#
# === Fold 5/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=33.7401, cls=1.2547, recon=13.8701 (13.9856, 13.8625),  smooth=0.6775, latent=23.6987
# Validation loss: 11.1236 | Val acc: 0.0505 |Val acc (NS/BH/CV): 0.6250 |val_class:0.8556 val_recon:1.1925 val_smooth: 0.0833 val_latent:16.7764
# Epoch 1
# Epoch 2:total=12.2779, cls=0.9969, recon=1.3310 (1.2805, 1.3385),  smooth=0.0432, latent=20.5500
# Validation loss: 17.3234 | Val acc: 0.4862 |Val acc (NS/BH/CV): 0.3750 |val_class:1.3815 val_recon:1.8643 val_smooth: 0.1106 val_latent:12.7047
# Epoch 2
# Epoch 3:total=9.7651, cls=0.7597, recon=1.2632 (1.2313, 1.2660),  smooth=0.0359, latent=18.9603
# Validation loss: 11.6065 | Val acc: 0.1651 |Val acc (NS/BH/CV): 0.6250 |val_class:0.8434 val_recon:1.7158 val_smooth: 0.0917 val_latent:11.5456
# Epoch 3
# Epoch 4:total=9.4233, cls=0.7297, recon=1.2294 (1.2496, 1.2273),  smooth=0.0350, latent=18.0048
# Validation loss: 17.0670 | Val acc: 0.1835 |Val acc (NS/BH/CV): 0.5000 |val_class:1.4311 val_recon:1.4563 val_smooth: 0.0757 val_latent:12.4055
# Epoch 4
# Epoch 5:total=7.7917, cls=0.5736, recon=1.2006 (1.2084, 1.2003),  smooth=0.0307, latent=16.9372
# Validation loss: 15.0281 | Val acc: 0.4450 |Val acc (NS/BH/CV): 0.5000 |val_class:1.3205 val_recon:0.9063 val_smooth: 0.0368 val_latent:15.8601
# Epoch 5
# Epoch 6:total=7.6976, cls=0.5672, recon=1.1817 (1.2031, 1.1797),  smooth=0.0293, latent=16.3360
# Validation loss: 38.9026 | Val acc: 0.7844 |Val acc (NS/BH/CV): 0.3750 |val_class:1.8652 val_recon:15.6261 val_smooth: 0.4084 val_latent:4.6375
# Epoch 6
# Epoch 7:total=6.6947, cls=0.4705, recon=1.1612 (1.1541, 1.1625),  smooth=0.0275, latent=15.5308
# Validation loss: 17.5655 | Val acc: 0.6009 |Val acc (NS/BH/CV): 0.4375 |val_class:1.5759 val_recon:0.9468 val_smooth: 0.0306 val_latent:14.0991
# Learning rate changed to 0.000250
# Epoch 7
# Epoch 8:total=5.8078, cls=0.3871, recon=1.1239 (1.1382, 1.1232),  smooth=0.0258, latent=14.8859
# Validation loss: 17.4511 | Val acc: 0.4862 |Val acc (NS/BH/CV): 0.5000 |val_class:1.5735 val_recon:0.8999 val_smooth: 0.0262 val_latent:14.3618
# Epoch 8
# Epoch 9:total=5.1194, cls=0.3194, recon=1.1205 (1.1236, 1.1205),  smooth=0.0250, latent=14.9584
# Validation loss: 17.7957 | Val acc: 0.4771 |Val acc (NS/BH/CV): 0.5625 |val_class:1.6081 val_recon:0.9212 val_smooth: 0.0239 val_latent:14.7066
# Epoch 9
# Epoch 10:total=5.8802, cls=0.3948, recon=1.1249 (1.1523, 1.1236),  smooth=0.0251, latent=14.9791
# Validation loss: 18.9210 | Val acc: 0.6101 |Val acc (NS/BH/CV): 0.4375 |val_class:1.7206 val_recon:0.9007 val_smooth: 0.0259 val_latent:14.3331
# Epoch 10
# Epoch 11:total=4.9451, cls=0.3026, recon=1.1152 (1.1298, 1.1150),  smooth=0.0248, latent=15.0656
# Validation loss: 19.9683 | Val acc: 0.4679 |Val acc (NS/BH/CV): 0.6250 |val_class:1.8271 val_recon:0.9230 val_smooth: 0.0218 val_latent:15.5186
# Epoch 11
# Epoch 12:total=5.1118, cls=0.3203, recon=1.1088 (1.1018, 1.1105),  smooth=0.0244, latent=15.2599
# Validation loss: 17.1086 | Val acc: 0.4495 |Val acc (NS/BH/CV): 0.5000 |val_class:1.5406 val_recon:0.8889 val_smooth: 0.0257 val_latent:14.7366
# Epoch 12
# Epoch 13:total=4.6840, cls=0.2781, recon=1.1021 (1.1045, 1.1019),  smooth=0.0245, latent=15.2275
# Validation loss: 20.3453 | Val acc: 0.6147 |Val acc (NS/BH/CV): 0.4375 |val_class:1.8582 val_recon:0.9219 val_smooth: 0.0286 val_latent:13.6910
# Learning rate changed to 0.000063
# Early stopping at epoch 12
# Train accuracy: 0.05550 | Val accuracy: 0.05046 | Test accuracy: 0.03650
#
# === Fold 6/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=40.4852, cls=1.1474, recon=19.1707 (19.2983, 19.1619),  smooth=0.9290, latent=23.5068
# Validation loss: 16.5961 | Val acc: 0.2615 |Val acc (NS/BH/CV): 0.4375 |val_class:1.2663 val_recon:1.7959 val_smooth: 0.1598 val_latent:12.8128
# Epoch 1
# Epoch 2:total=11.3895, cls=0.9075, recon=1.3025 (1.1364, 1.3156),  smooth=0.0466, latent=19.9236
# Validation loss: 14.1462 | Val acc: 0.3073 |Val acc (NS/BH/CV): 0.5625 |val_class:1.1840 val_recon:1.1649 val_smooth: 0.0598 val_latent:17.1032
# Epoch 2
# Epoch 3:total=10.8022, cls=0.8600, recon=1.2321 (1.1209, 1.2407),  smooth=0.0425, latent=18.1737
# Validation loss: 16.8590 | Val acc: 0.1376 |Val acc (NS/BH/CV): 0.5000 |val_class:1.3515 val_recon:1.6207 val_smooth: 0.1183 val_latent:12.3038
# Epoch 3
# Epoch 4:total=9.9585, cls=0.7804, recon=1.2190 (1.1728, 1.2235),  smooth=0.0391, latent=16.4873
# Validation loss: 13.8138 | Val acc: 0.3670 |Val acc (NS/BH/CV): 0.6250 |val_class:1.1694 val_recon:1.0260 val_smooth: 0.0551 val_latent:13.5058
# Epoch 4
# Epoch 5:total=8.3589, cls=0.6310, recon=1.1703 (1.1336, 1.1719),  smooth=0.0333, latent=15.6635
# Validation loss: 13.8563 | Val acc: 0.3853 |Val acc (NS/BH/CV): 0.5625 |val_class:1.1217 val_recon:1.4249 val_smooth: 0.0671 val_latent:11.4817
# Epoch 5
# Epoch 6:total=7.6987, cls=0.5671, recon=1.1678 (1.1703, 1.1681),  smooth=0.0312, latent=14.8273
# Validation loss: 15.1170 | Val acc: 0.3853 |Val acc (NS/BH/CV): 0.5625 |val_class:1.2820 val_recon:1.2216 val_smooth: 0.0530 val_latent:11.0081
# Epoch 6
# Epoch 7:total=6.9741, cls=0.4979, recon=1.1505 (1.1000, 1.1517),  smooth=0.0294, latent=13.7525
# Validation loss: 13.2004 | Val acc: 0.5688 |Val acc (NS/BH/CV): 0.5625 |val_class:1.1311 val_recon:0.9433 val_smooth: 0.0395 val_latent:12.7526
# Epoch 7
# Epoch 8:total=6.4919, cls=0.4547, recon=1.1152 (1.0280, 1.1237),  smooth=0.0277, latent=13.6924
# Validation loss: 19.4170 | Val acc: 0.3257 |Val acc (NS/BH/CV): 0.5625 |val_class:1.7008 val_recon:1.7601 val_smooth: 0.0089 val_latent:18.9135
# Epoch 8
# Epoch 9:total=6.1766, cls=0.4228, recon=1.1187 (1.0316, 1.1246),  smooth=0.0275, latent=12.8535
# Validation loss: 15.9757 | Val acc: 0.6743 |Val acc (NS/BH/CV): 0.5000 |val_class:1.3773 val_recon:1.1506 val_smooth: 0.0497 val_latent:10.9172
# Epoch 9
# Epoch 10:total=5.7364, cls=0.3822, recon=1.0924 (1.0230, 1.0975),  smooth=0.0263, latent=12.4433
# Validation loss: 16.8233 | Val acc: 0.4495 |Val acc (NS/BH/CV): 0.5625 |val_class:1.4758 val_recon:1.3797 val_smooth: 0.0123 val_latent:15.2419
# Epoch 10
# Epoch 11:total=4.7378, cls=0.2850, recon=1.0808 (1.0020, 1.0856),  smooth=0.0246, latent=12.4873
# Validation loss: 16.5193 | Val acc: 0.6239 |Val acc (NS/BH/CV): 0.5625 |val_class:1.4553 val_recon:0.9838 val_smooth: 0.0422 val_latent:11.4824
# Epoch 11
# Epoch 12:total=4.5323, cls=0.2657, recon=1.0742 (1.0185, 1.0779),  smooth=0.0240, latent=12.8160
# Validation loss: 60.9022 | Val acc: 0.4450 |Val acc (NS/BH/CV): 0.0000 |val_class:5.3061 val_recon:4.6843 val_smooth: 0.2596 val_latent:11.5083
# Epoch 12
# Epoch 13:total=3.8596, cls=0.1989, recon=1.0740 (0.9951, 1.0809),  smooth=0.0233, latent=12.9547
# Validation loss: 21.0449 | Val acc: 0.6881 |Val acc (NS/BH/CV): 0.3125 |val_class:1.9218 val_recon:1.0666 val_smooth: 0.0196 val_latent:14.2759
# Learning rate changed to 0.000250
# Epoch 13
# Epoch 14:total=3.6170, cls=0.1768, recon=1.0584 (0.9810, 1.0629),  smooth=0.0227, latent=13.2080
# Validation loss: 18.7807 | Val acc: 0.7110 |Val acc (NS/BH/CV): 0.5625 |val_class:1.7070 val_recon:0.9239 val_smooth: 0.0223 val_latent:13.4222
# Epoch 14
# Epoch 15:total=3.3010, cls=0.1467, recon=1.0502 (0.9459, 1.0560),  smooth=0.0220, latent=13.3544
# Validation loss: 19.4545 | Val acc: 0.6881 |Val acc (NS/BH/CV): 0.5625 |val_class:1.7735 val_recon:0.9213 val_smooth: 0.0235 val_latent:13.1937
# Epoch 15
# Epoch 16:total=3.1703, cls=0.1339, recon=1.0490 (0.9543, 1.0543),  smooth=0.0219, latent=13.2229
# Validation loss: 18.6972 | Val acc: 0.6376 |Val acc (NS/BH/CV): 0.5625 |val_class:1.6965 val_recon:0.9839 val_smooth: 0.0184 val_latent:13.8944
# Epoch 16
# Epoch 17:total=3.0827, cls=0.1254, recon=1.0490 (0.9627, 1.0551),  smooth=0.0216, latent=13.2103
# Validation loss: 21.6840 | Val acc: 0.7523 |Val acc (NS/BH/CV): 0.4375 |val_class:1.9885 val_recon:1.0773 val_smooth: 0.0157 val_latent:14.9743
# Epoch 17
# Epoch 18:total=3.2442, cls=0.1422, recon=1.0464 (0.9427, 1.0540),  smooth=0.0213, latent=13.5914
# Validation loss: 19.1343 | Val acc: 0.5642 |Val acc (NS/BH/CV): 0.5625 |val_class:1.7387 val_recon:1.0189 val_smooth: 0.0165 val_latent:14.2082
# Epoch 18
# Epoch 19:total=3.0619, cls=0.1244, recon=1.0440 (0.9401, 1.0505),  smooth=0.0212, latent=13.5661
# Validation loss: 19.7760 | Val acc: 0.6468 |Val acc (NS/BH/CV): 0.5000 |val_class:1.8067 val_recon:0.9638 val_smooth: 0.0182 val_latent:14.3527
# Learning rate changed to 0.000063
# Early stopping at epoch 18
# Train accuracy: 0.62882 | Val accuracy: 0.56881 | Test accuracy: 0.53650
#
# === Fold 7/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=63.2259, cls=1.1643, recon=39.3311 (39.4796, 39.3226),  smooth=1.1703, latent=23.8716
# Validation loss: 11.1619 | Val acc: 0.2202 |Val acc (NS/BH/CV): 0.6875 |val_class:0.8871 val_recon:1.2541 val_smooth: 0.0489 val_latent:23.6219
# Epoch 1
# Epoch 2:total=12.6477, cls=1.0332, recon=1.3345 (1.2055, 1.3435),  smooth=0.0434, latent=21.8862
# Validation loss: 10.8299 | Val acc: 0.3303 |Val acc (NS/BH/CV): 0.6875 |val_class:0.8755 val_recon:1.0141 val_smooth: 0.0517 val_latent:17.9491
# Epoch 2
# Epoch 3:total=10.4141, cls=0.8310, recon=1.2159 (1.1737, 1.2190),  smooth=0.0342, latent=19.7719
# Validation loss: 11.0463 | Val acc: 0.2523 |Val acc (NS/BH/CV): 0.5625 |val_class:0.9148 val_recon:1.0245 val_smooth: 0.0325 val_latent:20.6395
# Epoch 3
# Epoch 4:total=8.9971, cls=0.6955, recon=1.1783 (1.1528, 1.1760),  smooth=0.0316, latent=18.7432
# Validation loss: 10.6340 | Val acc: 0.3532 |Val acc (NS/BH/CV): 0.5625 |val_class:0.8788 val_recon:0.9665 val_smooth: 0.0331 val_latent:18.0678
# Epoch 4
# Epoch 5:total=8.9079, cls=0.6887, recon=1.1656 (1.1856, 1.1653),  smooth=0.0307, latent=17.4049
# Validation loss: 19.0188 | Val acc: 0.6009 |Val acc (NS/BH/CV): 0.5000 |val_class:1.6961 val_recon:1.0598 val_smooth: 0.0451 val_latent:14.9890
# Epoch 5
# Epoch 6:total=7.6257, cls=0.5636, recon=1.1501 (1.1853, 1.1514),  smooth=0.0290, latent=16.1812
# Validation loss: 14.9429 | Val acc: 0.5413 |Val acc (NS/BH/CV): 0.6250 |val_class:1.3053 val_recon:1.1221 val_smooth: 0.0215 val_latent:17.0025
# Epoch 6
# Epoch 7:total=6.6530, cls=0.4700, recon=1.1267 (1.1310, 1.1263),  smooth=0.0275, latent=14.9228
# Validation loss: 12.9103 | Val acc: 0.6055 |Val acc (NS/BH/CV): 0.6250 |val_class:1.1083 val_recon:0.9915 val_smooth: 0.0283 val_latent:15.4929
# Epoch 7
# Epoch 8:total=6.3409, cls=0.4418, recon=1.1089 (1.1064, 1.1092),  smooth=0.0261, latent=14.1465
# Validation loss: 17.5450 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.5625 |val_class:1.5772 val_recon:1.0096 val_smooth: 0.0207 val_latent:15.2967
# Epoch 8
# Epoch 9:total=5.0951, cls=0.3204, recon=1.0911 (1.0529, 1.0936),  smooth=0.0244, latent=14.0333
# Validation loss: 14.9511 | Val acc: 0.3716 |Val acc (NS/BH/CV): 0.5625 |val_class:1.0298 val_recon:3.0214 val_smooth: 0.1081 val_latent:7.9298
# Epoch 9
# Epoch 10:total=4.6121, cls=0.2731, recon=1.0851 (1.0607, 1.0902),  smooth=0.0238, latent=14.1084
# Validation loss: 20.1058 | Val acc: 0.3991 |Val acc (NS/BH/CV): 0.7500 |val_class:1.8364 val_recon:0.9622 val_smooth: 0.0220 val_latent:14.8499
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=4.3038, cls=0.2443, recon=1.0723 (1.0690, 1.0727),  smooth=0.0231, latent=13.8174
# Validation loss: 14.6393 | Val acc: 0.5872 |Val acc (NS/BH/CV): 0.6250 |val_class:1.2929 val_recon:0.9190 val_smooth: 0.0233 val_latent:13.8167
# Epoch 11
# Epoch 12:total=3.8901, cls=0.2039, recon=1.0628 (1.0270, 1.0658),  smooth=0.0230, latent=13.8997
# Validation loss: 18.5031 | Val acc: 0.7202 |Val acc (NS/BH/CV): 0.5625 |val_class:1.6791 val_recon:0.9307 val_smooth: 0.0223 val_latent:14.3822
# Epoch 12
# Epoch 13:total=3.8282, cls=0.1980, recon=1.0622 (1.0291, 1.0635),  smooth=0.0227, latent=14.0676
# Validation loss: 18.9182 | Val acc: 0.6743 |Val acc (NS/BH/CV): 0.7500 |val_class:1.7133 val_recon:0.9595 val_smooth: 0.0269 val_latent:12.8001
# Epoch 13
# Epoch 14:total=3.8192, cls=0.1979, recon=1.0573 (1.0035, 1.0602),  smooth=0.0224, latent=14.0647
# Validation loss: 20.3898 | Val acc: 0.6743 |Val acc (NS/BH/CV): 0.7500 |val_class:1.8660 val_recon:0.9701 val_smooth: 0.0200 val_latent:14.2540
# Epoch 14
# Epoch 15:total=3.3483, cls=0.1511, recon=1.0566 (0.9918, 1.0614),  smooth=0.0222, latent=14.1102
# Validation loss: 16.7734 | Val acc: 0.5917 |Val acc (NS/BH/CV): 0.6875 |val_class:1.5074 val_recon:0.9078 val_smooth: 0.0233 val_latent:13.8459
# Epoch 15
# Epoch 16:total=3.5308, cls=0.1702, recon=1.0506 (0.9873, 1.0553),  smooth=0.0219, latent=14.2399
# Validation loss: 20.0764 | Val acc: 0.6972 |Val acc (NS/BH/CV): 0.5000 |val_class:1.8332 val_recon:0.9144 val_smooth: 0.0272 val_latent:13.4155
# Learning rate changed to 0.000063
# Early stopping at epoch 15
# Train accuracy: 0.38340 | Val accuracy: 0.35321 | Test accuracy: 0.32847
#
# === Fold 8/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=38.8284, cls=1.2771, recon=16.7093 (16.7131, 16.7075),  smooth=0.8791, latent=28.4863
# Validation loss: 12.8743 | Val acc: 0.0596 |Val acc (NS/BH/CV): 0.6471 |val_class:0.9027 val_recon:1.4502 val_smooth: 0.1851 val_latent:16.5177
# Epoch 1
# Epoch 2:total=12.5249, cls=1.0050, recon=1.4004 (1.2476, 1.4105),  smooth=0.0521, latent=23.2120
# Validation loss: 14.4203 | Val acc: 0.2339 |Val acc (NS/BH/CV): 0.4706 |val_class:1.1504 val_recon:1.3260 val_smooth: 0.1045 val_latent:14.6930
# Epoch 2
# Epoch 3:total=10.7481, cls=0.8482, recon=1.2678 (1.1851, 1.2715),  smooth=0.0446, latent=21.1695
# Validation loss: 11.2976 | Val acc: 0.3349 |Val acc (NS/BH/CV): 0.8235 |val_class:0.7865 val_recon:1.8211 val_smooth: 0.1066 val_latent:13.0367
# Epoch 3
# Epoch 4:total=9.2369, cls=0.7085, recon=1.2195 (1.2516, 1.2167),  smooth=0.0380, latent=19.7211
# Validation loss: 12.5979 | Val acc: 0.3303 |Val acc (NS/BH/CV): 0.7647 |val_class:0.7856 val_recon:2.8670 val_smooth: 0.1330 val_latent:10.9072
# Epoch 4
# Epoch 5:total=9.1589, cls=0.7027, recon=1.2200 (1.3119, 1.2152),  smooth=0.0358, latent=18.9828
# Validation loss: 8.5620 | Val acc: 0.2615 |Val acc (NS/BH/CV): 0.7647 |val_class:0.6391 val_recon:1.4801 val_smooth: 0.0131 val_latent:25.1481
# Epoch 5
# Epoch 6:total=8.0694, cls=0.6015, recon=1.1862 (1.2697, 1.1813),  smooth=0.0314, latent=17.9262
# Validation loss: 18.6205 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.4706 |val_class:1.1067 val_recon:5.3683 val_smooth: 0.1639 val_latent:8.5087
# Epoch 6
# Epoch 7:total=7.9960, cls=0.5950, recon=1.1864 (1.2867, 1.1675),  smooth=0.0304, latent=16.6995
# Validation loss: 11.4748 | Val acc: 0.7018 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9020 val_recon:1.3525 val_smooth: 0.0550 val_latent:12.6294
# Epoch 7
# Epoch 8:total=7.0577, cls=0.5056, recon=1.1635 (1.2613, 1.1585),  smooth=0.0282, latent=15.8620
# Validation loss: 11.8962 | Val acc: 0.7339 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9422 val_recon:1.4116 val_smooth: 0.0508 val_latent:11.1090
# Epoch 8
# Epoch 9:total=6.0600, cls=0.4091, recon=1.1400 (1.2039, 1.1359),  smooth=0.0270, latent=15.3581
# Validation loss: 13.5789 | Val acc: 0.7661 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1602 val_recon:1.1233 val_smooth: 0.0295 val_latent:14.5870
# Epoch 9
# Epoch 10:total=5.8245, cls=0.3866, recon=1.1298 (1.2905, 1.1208),  smooth=0.0269, latent=14.5059
# Validation loss: 10.4557 | Val acc: 0.6606 |Val acc (NS/BH/CV): 0.7059 |val_class:0.8634 val_recon:0.9200 val_smooth: 0.0342 val_latent:12.1633
# Epoch 10
# Epoch 11:total=4.7504, cls=0.2825, recon=1.1076 (1.1423, 1.1045),  smooth=0.0256, latent=14.4794
# Validation loss: 11.6730 | Val acc: 0.6330 |Val acc (NS/BH/CV): 0.5882 |val_class:0.9289 val_recon:1.3698 val_smooth: 0.0455 val_latent:11.2717
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=4.4755, cls=0.2563, recon=1.1057 (1.1801, 1.1005),  smooth=0.0245, latent=14.5212
# Validation loss: 10.9087 | Val acc: 0.6422 |Val acc (NS/BH/CV): 0.5294 |val_class:0.9165 val_recon:0.9140 val_smooth: 0.0269 val_latent:13.5532
# Epoch 12
# Epoch 13:total=3.9130, cls=0.2014, recon=1.0894 (1.1122, 1.0887),  smooth=0.0248, latent=14.7114
# Validation loss: 11.4643 | Val acc: 0.6835 |Val acc (NS/BH/CV): 0.4706 |val_class:0.9725 val_recon:0.9094 val_smooth: 0.0270 val_latent:13.4689
# Epoch 13
# Epoch 14:total=4.1300, cls=0.2246, recon=1.0810 (1.0787, 1.0809),  smooth=0.0241, latent=14.8163
# Validation loss: 10.7718 | Val acc: 0.6422 |Val acc (NS/BH/CV): 0.6471 |val_class:0.9055 val_recon:0.8992 val_smooth: 0.0256 val_latent:13.9099
# Epoch 14
# Epoch 15:total=3.4007, cls=0.1516, recon=1.0815 (1.0935, 1.0780),  smooth=0.0241, latent=14.8477
# Validation loss: 10.7249 | Val acc: 0.6193 |Val acc (NS/BH/CV): 0.5882 |val_class:0.8898 val_recon:0.9460 val_smooth: 0.0321 val_latent:12.5242
# Epoch 15
# Epoch 16:total=3.9121, cls=0.2032, recon=1.0775 (1.0780, 1.0768),  smooth=0.0240, latent=15.1981
# Validation loss: 14.5141 | Val acc: 0.7477 |Val acc (NS/BH/CV): 0.4706 |val_class:1.2777 val_recon:0.9184 val_smooth: 0.0258 val_latent:14.2326
# Epoch 16
# Epoch 17:total=3.5305, cls=0.1662, recon=1.0737 (1.0535, 1.0749),  smooth=0.0234, latent=15.1403
# Validation loss: 14.1095 | Val acc: 0.7018 |Val acc (NS/BH/CV): 0.4706 |val_class:1.2419 val_recon:0.8735 val_smooth: 0.0257 val_latent:14.2762
# Learning rate changed to 0.000063
# Early stopping at epoch 16
# Train accuracy: 0.27800 | Val accuracy: 0.26147 | Test accuracy: 0.22263
#
# === Fold 9/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=43.4859, cls=1.1749, recon=22.9926 (23.5566, 22.9593),  smooth=0.8197, latent=20.4156
# Validation loss: 13.3974 | Val acc: 0.1009 |Val acc (NS/BH/CV): 0.4706 |val_class:1.0849 val_recon:1.3075 val_smooth: 0.0697 val_latent:16.4706
# Epoch 1
# Epoch 2:total=12.4838, cls=1.0349, recon=1.2221 (1.1981, 1.2220),  smooth=0.0366, latent=19.2041
# Validation loss: 11.4151 | Val acc: 0.0688 |Val acc (NS/BH/CV): 0.6471 |val_class:0.9285 val_recon:1.1882 val_smooth: 0.0397 val_latent:17.0937
# Epoch 2
# Epoch 3:total=11.8452, cls=0.9734, recon=1.1800 (1.1969, 1.1806),  smooth=0.0384, latent=17.9850
# Validation loss: 23.7361 | Val acc: 0.3532 |Val acc (NS/BH/CV): 0.4118 |val_class:1.4459 val_recon:5.9534 val_smooth: 0.2786 val_latent:6.9456
# Epoch 3
# Epoch 4:total=10.2369, cls=0.8156, recon=1.1834 (1.1840, 1.1849),  smooth=0.0350, latent=16.4264
# Validation loss: 17.5006 | Val acc: 0.2385 |Val acc (NS/BH/CV): 0.5882 |val_class:1.3726 val_recon:2.1597 val_smooth: 0.1072 val_latent:9.8144
# Epoch 4
# Epoch 5:total=9.3040, cls=0.7272, recon=1.1627 (1.1807, 1.1632),  smooth=0.0320, latent=14.8425
# Validation loss: 18.4578 | Val acc: 0.2890 |Val acc (NS/BH/CV): 0.4706 |val_class:1.5940 val_recon:1.4031 val_smooth: 0.0568 val_latent:10.9715
# Epoch 5
# Epoch 6:total=8.5324, cls=0.6531, recon=1.1459 (1.1369, 1.1467),  smooth=0.0304, latent=14.3149
# Validation loss: 25.5214 | Val acc: 0.5229 |Val acc (NS/BH/CV): 0.5882 |val_class:1.9734 val_recon:3.7831 val_smooth: 0.1457 val_latent:7.4502
# Epoch 6
# Epoch 7:total=6.2589, cls=0.4303, recon=1.1165 (1.0775, 1.1197),  smooth=0.0285, latent=13.8812
# Validation loss: 23.8170 | Val acc: 0.3349 |Val acc (NS/BH/CV): 0.5294 |val_class:2.1456 val_recon:1.2553 val_smooth: 0.0554 val_latent:10.6292
# Epoch 7
# Epoch 8:total=6.0350, cls=0.4092, recon=1.1137 (1.0826, 1.1165),  smooth=0.0273, latent=13.6425
# Validation loss: 32.7337 | Val acc: 0.5688 |Val acc (NS/BH/CV): 0.5294 |val_class:3.0664 val_recon:1.1024 val_smooth: 0.0411 val_latent:12.3323
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=5.2625, cls=0.3344, recon=1.0982 (1.0621, 1.1017),  smooth=0.0263, latent=13.6021
# Validation loss: 29.0531 | Val acc: 0.5275 |Val acc (NS/BH/CV): 0.5294 |val_class:2.6887 val_recon:1.1894 val_smooth: 0.0422 val_latent:11.0449
# Epoch 9
# Epoch 10:total=4.8219, cls=0.2917, recon=1.0907 (1.0377, 1.0939),  smooth=0.0257, latent=13.4133
# Validation loss: 31.8464 | Val acc: 0.5826 |Val acc (NS/BH/CV): 0.5294 |val_class:2.9859 val_recon:1.0871 val_smooth: 0.0344 val_latent:12.3175
# Epoch 10
# Epoch 11:total=4.6408, cls=0.2740, recon=1.0877 (1.0300, 1.0914),  smooth=0.0256, latent=13.4787
# Validation loss: 32.2084 | Val acc: 0.6743 |Val acc (NS/BH/CV): 0.4118 |val_class:3.0310 val_recon:1.0586 val_smooth: 0.0282 val_latent:13.0592
# Epoch 11
# Epoch 12:total=4.6616, cls=0.2770, recon=1.0822 (1.0238, 1.0867),  smooth=0.0251, latent=13.6037
# Validation loss: 31.6262 | Val acc: 0.6284 |Val acc (NS/BH/CV): 0.5294 |val_class:2.9262 val_recon:1.3292 val_smooth: 0.0479 val_latent:10.8357
# Epoch 12
# Epoch 13:total=4.4629, cls=0.2576, recon=1.0792 (1.0140, 1.0830),  smooth=0.0249, latent=13.4391
# Validation loss: 31.8235 | Val acc: 0.5459 |Val acc (NS/BH/CV): 0.5294 |val_class:3.0000 val_recon:1.0399 val_smooth: 0.0225 val_latent:14.1099
# Epoch 13
# Epoch 14:total=4.3603, cls=0.2479, recon=1.0753 (0.9983, 1.0819),  smooth=0.0248, latent=13.4638
# Validation loss: 33.6613 | Val acc: 0.7110 |Val acc (NS/BH/CV): 0.4118 |val_class:3.1841 val_recon:1.0354 val_smooth: 0.0226 val_latent:14.0326
# Learning rate changed to 0.000063
# Early stopping at epoch 13
# Train accuracy: 0.06874 | Val accuracy: 0.06881 | Test accuracy: 0.05109
#
# === Fold 10/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=38.3478, cls=1.2631, recon=17.7961 (18.0602, 17.7837),  smooth=0.7378, latent=19.3196
# Validation loss: 10.3680 | Val acc: 0.0642 |Val acc (NS/BH/CV): 0.7647 |val_class:0.7907 val_recon:1.6898 val_smooth: 0.0222 val_latent:25.2451
# Epoch 1
# Epoch 2:total=11.7271, cls=0.9566, recon=1.2105 (1.1309, 1.2164),  smooth=0.0410, latent=16.1389
# Validation loss: 9.1616 | Val acc: 0.2064 |Val acc (NS/BH/CV): 0.7647 |val_class:0.7188 val_recon:1.0594 val_smooth: 0.0371 val_latent:17.3566
# Epoch 2
# Epoch 3:total=11.3870, cls=0.9258, recon=1.2145 (1.1543, 1.2202),  smooth=0.0374, latent=14.7985
# Validation loss: 9.0483 | Val acc: 0.3532 |Val acc (NS/BH/CV): 0.7647 |val_class:0.7013 val_recon:1.2929 val_smooth: 0.0198 val_latent:16.6397
# Epoch 3
# Epoch 4:total=8.6955, cls=0.6664, recon=1.1822 (1.1610, 1.1830),  smooth=0.0307, latent=13.5231
# Validation loss: 9.0412 | Val acc: 0.1927 |Val acc (NS/BH/CV): 0.8235 |val_class:0.7011 val_recon:1.3216 val_smooth: 0.0162 val_latent:16.7202
# Epoch 4
# Epoch 5:total=8.1987, cls=0.6231, recon=1.1196 (1.0800, 1.1226),  smooth=0.0304, latent=12.6298
# Validation loss: 9.5049 | Val acc: 0.2110 |Val acc (NS/BH/CV): 0.6471 |val_class:0.7636 val_recon:1.0750 val_smooth: 0.0248 val_latent:13.9217
# Epoch 5
# Epoch 6:total=7.9155, cls=0.5924, recon=1.1570 (1.1354, 1.1567),  smooth=0.0289, latent=11.3193
# Validation loss: 12.5263 | Val acc: 0.3716 |Val acc (NS/BH/CV): 0.5294 |val_class:1.0691 val_recon:0.9610 val_smooth: 0.0329 val_latent:9.2959
# Epoch 6
# Epoch 7:total=6.2287, cls=0.4312, recon=1.1010 (1.0323, 1.1062),  smooth=0.0267, latent=10.6541
# Validation loss: 11.0673 | Val acc: 0.4679 |Val acc (NS/BH/CV): 0.6471 |val_class:0.9296 val_recon:1.0104 val_smooth: 0.0210 val_latent:11.4908
# Epoch 7
# Epoch 8:total=6.4710, cls=0.4530, recon=1.1309 (1.0854, 1.1329),  smooth=0.0258, latent=10.4089
# Validation loss: 12.4494 | Val acc: 0.5459 |Val acc (NS/BH/CV): 0.5294 |val_class:1.0548 val_recon:0.9659 val_smooth: 0.0384 val_latent:8.6767
# Epoch 8
# Epoch 9:total=5.7639, cls=0.3871, recon=1.0882 (1.0155, 1.0938),  smooth=0.0250, latent=10.4334
# Validation loss: 11.0692 | Val acc: 0.4495 |Val acc (NS/BH/CV): 0.6471 |val_class:0.9197 val_recon:1.1592 val_smooth: 0.0154 val_latent:12.1153
# Epoch 9
# Epoch 10:total=5.5078, cls=0.3622, recon=1.0807 (1.0162, 1.0846),  smooth=0.0248, latent=10.3262
# Validation loss: 17.7312 | Val acc: 0.6101 |Val acc (NS/BH/CV): 0.5294 |val_class:1.5795 val_recon:1.0679 val_smooth: 0.0310 val_latent:9.1835
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=4.0735, cls=0.2215, recon=1.0652 (0.9947, 1.0708),  smooth=0.0234, latent=9.9671
# Validation loss: 14.3904 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.4706 |val_class:1.2671 val_recon:0.9399 val_smooth: 0.0220 val_latent:10.0474
# Epoch 11
# Epoch 12:total=4.1199, cls=0.2268, recon=1.0646 (0.9871, 1.0696),  smooth=0.0228, latent=10.2267
# Validation loss: 16.4995 | Val acc: 0.7018 |Val acc (NS/BH/CV): 0.4706 |val_class:1.4752 val_recon:0.9303 val_smooth: 0.0258 val_latent:9.9977
# Epoch 12
# Epoch 13:total=3.8071, cls=0.1953, recon=1.0678 (1.0240, 1.0698),  smooth=0.0227, latent=10.2553
# Validation loss: 17.6605 | Val acc: 0.6972 |Val acc (NS/BH/CV): 0.4118 |val_class:1.5938 val_recon:0.9639 val_smooth: 0.0199 val_latent:11.0807
# Epoch 13
# Epoch 14:total=3.9325, cls=0.2087, recon=1.0624 (0.9974, 1.0673),  smooth=0.0224, latent=10.5370
# Validation loss: 13.5532 | Val acc: 0.6835 |Val acc (NS/BH/CV): 0.5294 |val_class:1.1849 val_recon:0.9181 val_smooth: 0.0228 val_latent:10.1300
# Epoch 14
# Epoch 15:total=3.4280, cls=0.1586, recon=1.0592 (0.9827, 1.0613),  smooth=0.0223, latent=10.5879
# Validation loss: 14.5173 | Val acc: 0.6972 |Val acc (NS/BH/CV): 0.5294 |val_class:1.2805 val_recon:0.9370 val_smooth: 0.0216 val_latent:10.2536
# Epoch 15
# Epoch 16:total=3.4483, cls=0.1615, recon=1.0572 (0.9792, 1.0633),  smooth=0.0217, latent=10.6896
# Validation loss: 17.4632 | Val acc: 0.7477 |Val acc (NS/BH/CV): 0.4706 |val_class:1.5759 val_recon:0.9300 val_smooth: 0.0216 val_latent:10.7958
# Learning rate changed to 0.000063
# Early stopping at epoch 15
# Train accuracy: 0.18788 | Val accuracy: 0.19266 | Test accuracy: 0.13869

# %%
all_results, train_data, test_data = semisupervised_kfold_test(
    SemiSupervisedAE,
    np.column_stack([pn_normspec_labelled, pn_counts_labelled]),
    pn_spec_labels,
    np.column_stack([pn_normspec[unlabelled_args], pn_counts[unlabelled_args]]),
    epochs=20, lambda_cls=10, l2_lambda=1.0e-3, l1_lambda=1.0e-4, lr=1.0e-3,
    train_ids=pn_labelled_trainids.astype(int),
    test_ids=pn_labelled_testids.astype(int),
    weights=(class_weights**0.5).tolist())
# Out:
# === Fold 1/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=105.3042, cls=1.2053, recon=74.5378 (75.0358, 74.5090),  smooth=1.8178, latent=15.3049
# Validation loss: 13.6696 | Val acc: 0.7808 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9456 val_recon:1.9720 val_smooth: 0.1710 val_latent:10.7611
# Epoch 1
# Epoch 2:total=10.2773, cls=0.8141, recon=1.2479 (1.1745, 1.2517),  smooth=0.0349, latent=17.8100
# Validation loss: 10.4821 | Val acc: 0.7900 |Val acc (NS/BH/CV): 0.1176 |val_class:0.8557 val_recon:1.0182 val_smooth: 0.0368 val_latent:17.7516
# Epoch 2
# Epoch 3:total=8.9613, cls=0.6963, recon=1.1611 (1.1602, 1.1620),  smooth=0.0299, latent=17.4110
# Validation loss: 9.6769 | Val acc: 0.8219 |Val acc (NS/BH/CV): 0.0588 |val_class:0.7344 val_recon:1.2440 val_smooth: 0.0553 val_latent:14.0302
# Epoch 3
# Epoch 4:total=7.6011, cls=0.5630, recon=1.1504 (1.1719, 1.1487),  smooth=0.0280, latent=17.5326
# Validation loss: 8.6483 | Val acc: 0.8447 |Val acc (NS/BH/CV): 0.1176 |val_class:0.6761 val_recon:0.9780 val_smooth: 0.0370 val_latent:16.0639
# Epoch 4
# Epoch 5:total=6.7982, cls=0.4855, recon=1.1361 (1.1793, 1.1341),  smooth=0.0266, latent=17.6988
# Validation loss: 8.5439 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.1176 |val_class:0.6336 val_recon:1.1928 val_smooth: 0.0477 val_latent:14.1987
# Epoch 5
# Epoch 6:total=6.4186, cls=0.4474, recon=1.1395 (1.1544, 1.1395),  smooth=0.0263, latent=17.5465
# Validation loss: 12.0489 | Val acc: 0.5753 |Val acc (NS/BH/CV): 0.4706 |val_class:0.9946 val_recon:1.1087 val_smooth: 0.0454 val_latent:14.8203
# Epoch 6
# Epoch 7:total=5.9493, cls=0.4032, recon=1.1229 (1.1188, 1.1239),  smooth=0.0251, latent=17.0603
# Validation loss: 9.6794 | Val acc: 0.7945 |Val acc (NS/BH/CV): 0.1765 |val_class:0.6844 val_recon:1.7193 val_smooth: 0.0578 val_latent:11.6495
# Epoch 7
# Epoch 8:total=5.0690, cls=0.3175, recon=1.1101 (1.0896, 1.1134),  smooth=0.0240, latent=16.8893
# Validation loss: 8.4125 | Val acc: 0.8630 |Val acc (NS/BH/CV): 0.1765 |val_class:0.6694 val_recon:0.9535 val_smooth: 0.0220 val_latent:16.9813
# Epoch 8
# Epoch 9:total=4.8493, cls=0.2955, recon=1.1093 (1.1008, 1.1052),  smooth=0.0241, latent=16.5662
# Validation loss: 9.0077 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.2941 |val_class:0.6461 val_recon:1.4925 val_smooth: 0.0514 val_latent:11.7971
# Epoch 9
# Epoch 10:total=4.1699, cls=0.2299, recon=1.0959 (1.0750, 1.0967),  smooth=0.0230, latent=16.2103
# Validation loss: 11.5567 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.1765 |val_class:0.7795 val_recon:2.5003 val_smooth: 0.0722 val_latent:9.9700
# Epoch 10
# Epoch 11:total=4.1736, cls=0.2307, recon=1.0932 (1.0510, 1.0952),  smooth=0.0228, latent=15.7922
# Validation loss: 9.8809 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.1176 |val_class:0.7227 val_recon:1.6004 val_smooth: 0.0512 val_latent:10.8984
# Epoch 11
# Epoch 12:total=3.8586, cls=0.2012, recon=1.0784 (1.0245, 1.0840),  smooth=0.0223, latent=15.0438
# Validation loss: 17.3638 | Val acc: 0.7808 |Val acc (NS/BH/CV): 0.0588 |val_class:1.5698 val_recon:0.9380 val_smooth: 0.0181 val_latent:16.5488
# Epoch 12
# Epoch 13:total=3.4427, cls=0.1614, recon=1.0679 (1.0347, 1.0702),  smooth=0.0216, latent=14.7171
# Validation loss: 11.7903 | Val acc: 0.8082 |Val acc (NS/BH/CV): 0.2353 |val_class:0.9659 val_recon:1.4965 val_smooth: 0.0082 val_latent:21.3652
# Epoch 13
# Epoch 14:total=3.4184, cls=0.1597, recon=1.0620 (1.0201, 1.0650),  smooth=0.0214, latent=14.3044
# Validation loss: 10.3317 | Val acc: 0.8721 |Val acc (NS/BH/CV): 0.1765 |val_class:0.8664 val_recon:0.9552 val_smooth: 0.0165 val_latent:16.3064
# Learning rate changed to 0.000250
# Epoch 14
# Epoch 15:total=3.0056, cls=0.1199, recon=1.0555 (1.0139, 1.0574),  smooth=0.0206, latent=13.9711
# Validation loss: 8.8284 | Val acc: 0.8767 |Val acc (NS/BH/CV): 0.3529 |val_class:0.7208 val_recon:0.8809 val_smooth: 0.0194 val_latent:14.6828
# Epoch 15
# Epoch 16:total=2.8383, cls=0.1037, recon=1.0524 (0.9932, 1.0566),  smooth=0.0204, latent=13.9237
# Validation loss: 8.9642 | Val acc: 0.8767 |Val acc (NS/BH/CV): 0.2353 |val_class:0.7330 val_recon:0.8650 val_smooth: 0.0225 val_latent:13.8404
# Epoch 16
# Epoch 17:total=2.8068, cls=0.1006, recon=1.0525 (1.0046, 1.0558),  smooth=0.0203, latent=13.9620
# Validation loss: 9.4188 | Val acc: 0.8813 |Val acc (NS/BH/CV): 0.2941 |val_class:0.7793 val_recon:0.8667 val_smooth: 0.0215 val_latent:14.0695
# Epoch 17
# Epoch 18:total=2.6815, cls=0.0888, recon=1.0475 (0.9725, 1.0518),  smooth=0.0201, latent=13.9833
# Validation loss: 9.6614 | Val acc: 0.8767 |Val acc (NS/BH/CV): 0.2353 |val_class:0.8045 val_recon:0.8931 val_smooth: 0.0178 val_latent:15.3594
# Epoch 18
# Epoch 19:total=2.6123, cls=0.0823, recon=1.0452 (0.9714, 1.0510),  smooth=0.0200, latent=14.0236
# Validation loss: 9.6846 | Val acc: 0.8584 |Val acc (NS/BH/CV): 0.2941 |val_class:0.8080 val_recon:0.8632 val_smooth: 0.0197 val_latent:14.5381
# Epoch 19
# Epoch 20:total=2.6217, cls=0.0837, recon=1.0445 (0.9811, 1.0499),  smooth=0.0197, latent=13.9929
# Validation loss: 9.9076 | Val acc: 0.8676 |Val acc (NS/BH/CV): 0.2353 |val_class:0.8303 val_recon:0.8581 val_smooth: 0.0202 val_latent:14.6857
# Learning rate changed to 0.000063
# Train accuracy: 0.99185 (0.95946)| Val accuracy: 0.86758 (0.23529) | Test accuracy: 0.87226 (0.33333)
#
# === Fold 2/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=64.8284, cls=1.1371, recon=40.9872 (41.4567, 40.9597),  smooth=1.1927, latent=20.9417
# Validation loss: 11.5419 | Val acc: 0.7900 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9052 val_recon:1.6904 val_smooth: 0.0246 val_latent:30.9157
# Epoch 1
# Epoch 2:total=10.1602, cls=0.8024, recon=1.2430 (1.1597, 1.2482),  smooth=0.0347, latent=22.9641
# Validation loss: 9.8054 | Val acc: 0.8174 |Val acc (NS/BH/CV): 0.2353 |val_class:0.7757 val_recon:1.2389 val_smooth: 0.0262 val_latent:24.4578
# Epoch 2
# Epoch 3:total=9.0165, cls=0.6997, recon=1.1578 (1.1466, 1.1582),  smooth=0.0316, latent=22.1376
# Validation loss: 9.2000 | Val acc: 0.8265 |Val acc (NS/BH/CV): 0.2941 |val_class:0.7117 val_recon:1.3513 val_smooth: 0.0180 val_latent:27.2574
# Epoch 3
# Epoch 4:total=8.1638, cls=0.6192, recon=1.1336 (1.1678, 1.1331),  smooth=0.0292, latent=21.2601
# Validation loss: 9.1409 | Val acc: 0.7991 |Val acc (NS/BH/CV): 0.5294 |val_class:0.7115 val_recon:1.3046 val_smooth: 0.0169 val_latent:26.8924
# Epoch 4
# Epoch 5:total=7.5485, cls=0.5601, recon=1.1188 (1.1274, 1.1196),  smooth=0.0282, latent=20.8508
# Validation loss: 8.3763 | Val acc: 0.8813 |Val acc (NS/BH/CV): 0.1765 |val_class:0.6436 val_recon:1.1214 val_smooth: 0.0273 val_latent:19.6942
# Epoch 5
# Epoch 6:total=6.6740, cls=0.4731, recon=1.1240 (1.1500, 1.1221),  smooth=0.0272, latent=20.2539
# Validation loss: 8.7022 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.5294 |val_class:0.6836 val_recon:1.1205 val_smooth: 0.0195 val_latent:23.0980
# Epoch 6
# Epoch 7:total=5.9390, cls=0.4033, recon=1.0975 (1.0428, 1.1007),  smooth=0.0260, latent=19.6486
# Validation loss: 13.4467 | Val acc: 0.6301 |Val acc (NS/BH/CV): 0.4118 |val_class:1.1581 val_recon:0.9903 val_smooth: 0.0328 val_latent:18.2239
# Epoch 7
# Epoch 8:total=5.3160, cls=0.3432, recon=1.0850 (1.0451, 1.0889),  smooth=0.0249, latent=19.3092
# Validation loss: 11.1921 | Val acc: 0.8447 |Val acc (NS/BH/CV): 0.6471 |val_class:0.8345 val_recon:2.2226 val_smooth: 0.0058 val_latent:34.5087
# Epoch 8
# Epoch 9:total=4.6845, cls=0.2820, recon=1.0718 (1.0122, 1.0753),  smooth=0.0242, latent=18.9116
# Validation loss: 21.2409 | Val acc: 0.5616 |Val acc (NS/BH/CV): 0.0588 |val_class:1.9399 val_recon:1.1023 val_smooth: 0.0184 val_latent:23.1809
# Epoch 9
# Epoch 10:total=4.3079, cls=0.2460, recon=1.0592 (0.9964, 1.0636),  smooth=0.0237, latent=18.4492
# Validation loss: 11.7278 | Val acc: 0.8082 |Val acc (NS/BH/CV): 0.4118 |val_class:0.9930 val_recon:1.0597 val_smooth: 0.0184 val_latent:20.0867
# Epoch 10
# Epoch 11:total=3.9885, cls=0.2147, recon=1.0563 (0.9861, 1.0603),  smooth=0.0232, latent=17.8677
# Validation loss: 12.2200 | Val acc: 0.8447 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0493 val_recon:0.9406 val_smooth: 0.0234 val_latent:17.7756
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=3.3842, cls=0.1569, recon=1.0430 (0.9631, 1.0488),  smooth=0.0219, latent=17.5448
# Validation loss: 9.6335 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.4706 |val_class:0.7937 val_recon:0.9549 val_smooth: 0.0188 val_latent:19.2151
# Epoch 12
# Epoch 13:total=3.3078, cls=0.1488, recon=1.0491 (0.9732, 1.0498),  smooth=0.0219, latent=17.5320
# Validation loss: 9.7817 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.4118 |val_class:0.8022 val_recon:0.9395 val_smooth: 0.0269 val_latent:16.2038
# Epoch 13
# Epoch 14:total=3.0906, cls=0.1281, recon=1.0420 (0.9512, 1.0485),  smooth=0.0215, latent=17.5361
# Validation loss: 9.5160 | Val acc: 0.8493 |Val acc (NS/BH/CV): 0.5294 |val_class:0.7766 val_recon:0.9291 val_smooth: 0.0270 val_latent:16.4750
# Epoch 14
# Epoch 15:total=3.0297, cls=0.1223, recon=1.0394 (0.9664, 1.0443),  smooth=0.0215, latent=17.4890
# Validation loss: 9.6041 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.4118 |val_class:0.7891 val_recon:0.9184 val_smooth: 0.0243 val_latent:16.6599
# Epoch 15
# Epoch 16:total=3.0465, cls=0.1245, recon=1.0368 (0.9440, 1.0443),  smooth=0.0213, latent=17.5356
# Validation loss: 10.1077 | Val acc: 0.8447 |Val acc (NS/BH/CV): 0.4706 |val_class:0.8430 val_recon:0.9019 val_smooth: 0.0224 val_latent:17.7309
# Epoch 16
# Epoch 17:total=3.0259, cls=0.1226, recon=1.0377 (0.9640, 1.0438),  smooth=0.0210, latent=17.5449
# Validation loss: 12.5187 | Val acc: 0.8539 |Val acc (NS/BH/CV): 0.3529 |val_class:1.0834 val_recon:0.9219 val_smooth: 0.0211 val_latent:17.6713
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=2.8573, cls=0.1063, recon=1.0343 (0.9471, 1.0404),  smooth=0.0209, latent=17.4684
# Validation loss: 10.3993 | Val acc: 0.8265 |Val acc (NS/BH/CV): 0.4118 |val_class:0.8732 val_recon:0.8888 val_smooth: 0.0227 val_latent:17.3663
# Epoch 18
# Epoch 19:total=2.7361, cls=0.0945, recon=1.0320 (0.9474, 1.0379),  smooth=0.0207, latent=17.4230
# Validation loss: 10.4409 | Val acc: 0.8402 |Val acc (NS/BH/CV): 0.4118 |val_class:0.8774 val_recon:0.8907 val_smooth: 0.0225 val_latent:17.5913
# Epoch 19
# Epoch 20:total=2.7147, cls=0.0924, recon=1.0325 (0.9455, 1.0377),  smooth=0.0207, latent=17.4010
# Validation loss: 10.3982 | Val acc: 0.8311 |Val acc (NS/BH/CV): 0.4118 |val_class:0.8735 val_recon:0.8888 val_smooth: 0.0223 val_latent:17.6086
# Train accuracy: 0.98166 (0.97297)| Val accuracy: 0.83105 (0.41176) | Test accuracy: 0.85584 (0.42424)
#
# === Fold 3/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=138.1694, cls=1.1457, recon=104.3732 (105.5404, 104.2992),  smooth=2.1810, latent=9.6390
# Validation loss: 11.9011 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9644 val_recon:1.3983 val_smooth: 0.0318 val_latent:18.8281
# Epoch 1
# Epoch 2:total=10.9383, cls=0.8739, recon=1.3856 (1.3576, 1.3876),  smooth=0.0275, latent=17.9242
# Validation loss: 9.9303 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.1875 |val_class:0.7720 val_recon:1.2261 val_smooth: 0.0448 val_latent:14.6941
# Epoch 2
# Epoch 3:total=9.5674, cls=0.7584, recon=1.1826 (1.2118, 1.1808),  smooth=0.0261, latent=17.9339
# Validation loss: 10.0655 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.3125 |val_class:0.7190 val_recon:1.6770 val_smooth: 0.0664 val_latent:12.1433
# Epoch 3
# Epoch 4:total=8.8069, cls=0.6858, recon=1.1534 (1.2105, 1.1512),  smooth=0.0254, latent=17.9819
# Validation loss: 10.1448 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8116 val_recon:1.3094 val_smooth: 0.0174 val_latent:22.3432
# Epoch 4
# Epoch 5:total=7.8551, cls=0.5918, recon=1.1448 (1.1965, 1.1419),  smooth=0.0250, latent=17.7874
# Validation loss: 12.8783 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.0625 |val_class:0.8039 val_recon:3.1738 val_smooth: 0.1131 val_latent:9.5646
# Epoch 5
# Epoch 6:total=7.1473, cls=0.5217, recon=1.1396 (1.1939, 1.1373),  smooth=0.0247, latent=17.6643
# Validation loss: 12.7055 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.1875 |val_class:0.9730 val_recon:1.7567 val_smooth: 0.0680 val_latent:11.7708
# Epoch 6
# Epoch 7:total=6.6865, cls=0.4762, recon=1.1314 (1.1634, 1.1292),  smooth=0.0248, latent=17.3929
# Validation loss: 11.9477 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.1875 |val_class:0.6565 val_recon:3.7981 val_smooth: 0.1047 val_latent:8.4292
# Epoch 7
# Epoch 8:total=6.1604, cls=0.4260, recon=1.1136 (1.1472, 1.1115),  smooth=0.0241, latent=16.7510
# Validation loss: 20.3094 | Val acc: 0.6697 |Val acc (NS/BH/CV): 0.1250 |val_class:1.8155 val_recon:1.4500 val_smooth: 0.0152 val_latent:22.6592
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=5.3721, cls=0.3483, recon=1.1076 (1.1160, 1.1071),  smooth=0.0235, latent=16.4841
# Validation loss: 8.0443 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.3750 |val_class:0.6164 val_recon:1.0038 val_smooth: 0.0332 val_latent:14.4866
# Epoch 9
# Epoch 10:total=5.4324, cls=0.3548, recon=1.1008 (1.1417, 1.0974),  smooth=0.0237, latent=16.4049
# Validation loss: 7.9945 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3750 |val_class:0.6245 val_recon:0.9455 val_smooth: 0.0258 val_latent:15.7431
# Epoch 10
# Epoch 11:total=5.2034, cls=0.3324, recon=1.0966 (1.1012, 1.0968),  smooth=0.0235, latent=16.3572
# Validation loss: 8.4616 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.5000 |val_class:0.6737 val_recon:0.9288 val_smooth: 0.0249 val_latent:16.1817
# Epoch 11
# Epoch 12:total=5.1326, cls=0.3258, recon=1.0930 (1.0820, 1.0936),  smooth=0.0234, latent=16.1893
# Validation loss: 10.2019 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8378 val_recon:1.1228 val_smooth: 0.0150 val_latent:19.7878
# Epoch 12
# Epoch 13:total=4.7521, cls=0.2888, recon=1.0832 (1.0443, 1.0882),  smooth=0.0233, latent=16.2498
# Validation loss: 8.1594 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.3750 |val_class:0.6443 val_recon:0.9168 val_smooth: 0.0252 val_latent:15.8180
# Epoch 13
# Epoch 14:total=4.7712, cls=0.2912, recon=1.0784 (1.0366, 1.0815),  smooth=0.0232, latent=16.1736
# Validation loss: 9.8912 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8196 val_recon:0.9185 val_smooth: 0.0228 val_latent:16.8968
# Epoch 14
# Epoch 15:total=4.7461, cls=0.2890, recon=1.0776 (1.0481, 1.0800),  smooth=0.0230, latent=15.9959
# Validation loss: 8.6167 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.3750 |val_class:0.6809 val_recon:0.9566 val_smooth: 0.0305 val_latent:14.5012
# Epoch 15
# Epoch 16:total=4.4681, cls=0.2620, recon=1.0718 (1.0099, 1.0770),  smooth=0.0228, latent=15.9662
# Validation loss: 8.8515 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7090 val_recon:0.9283 val_smooth: 0.0286 val_latent:14.8235
# Learning rate changed to 0.000063
# Epoch 16
# Epoch 17:total=4.4298, cls=0.2582, recon=1.0699 (1.0502, 1.0716),  smooth=0.0229, latent=15.8344
# Validation loss: 9.0607 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7287 val_recon:0.9395 val_smooth: 0.0287 val_latent:14.5847
# Epoch 17
# Epoch 18:total=4.2907, cls=0.2448, recon=1.0675 (1.0112, 1.0730),  smooth=0.0226, latent=15.9014
# Validation loss: 9.0992 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7391 val_recon:0.9066 val_smooth: 0.0253 val_latent:15.5281
# Epoch 18
# Epoch 19:total=4.2170, cls=0.2376, recon=1.0663 (1.0002, 1.0696),  smooth=0.0226, latent=15.8909
# Validation loss: 9.0659 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7364 val_recon:0.9078 val_smooth: 0.0246 val_latent:15.5086
# Epoch 19
# Epoch 20:total=4.1484, cls=0.2308, recon=1.0666 (1.0079, 1.0706),  smooth=0.0226, latent=15.9383
# Validation loss: 8.9031 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7216 val_recon:0.8990 val_smooth: 0.0239 val_latent:15.9222
# Train accuracy: 0.96589 (0.80537)| Val accuracy: 0.86697 (0.37500) | Test accuracy: 0.86496 (0.36364)
#
# === Fold 4/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=92.7917, cls=1.1465, recon=66.8188 (67.6607, 66.7665),  smooth=1.3973, latent=15.4034
# Validation loss: 14.8553 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.1875 |val_class:0.9054 val_recon:3.2947 val_smooth: 0.1974 val_latent:11.3907
# Epoch 1
# Epoch 2:total=10.6387, cls=0.8426, recon=1.3352 (1.2876, 1.3391),  smooth=0.0335, latent=20.3312
# Validation loss: 12.8650 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7617 val_recon:3.2560 val_smooth: 0.1458 val_latent:10.9000
# Epoch 2
# Epoch 3:total=8.8968, cls=0.6857, recon=1.1951 (1.2453, 1.1916),  smooth=0.0300, latent=20.2826
# Validation loss: 12.4939 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.1875 |val_class:0.7209 val_recon:3.3721 val_smooth: 0.1377 val_latent:10.6514
# Epoch 3
# Epoch 4:total=8.1018, cls=0.6135, recon=1.1521 (1.2006, 1.1489),  smooth=0.0270, latent=20.0458
# Validation loss: 13.4760 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8107 val_recon:3.4788 val_smooth: 0.1353 val_latent:11.3367
# Epoch 4
# Epoch 5:total=7.6038, cls=0.5669, recon=1.1306 (1.1786, 1.1272),  smooth=0.0257, latent=19.8382
# Validation loss: 12.1276 | Val acc: 0.6147 |Val acc (NS/BH/CV): 0.5000 |val_class:1.0028 val_recon:1.1239 val_smooth: 0.0431 val_latent:16.7039
# Epoch 5
# Epoch 6:total=6.8423, cls=0.4924, recon=1.1199 (1.1567, 1.1186),  smooth=0.0250, latent=19.4505
# Validation loss: 13.4091 | Val acc: 0.6468 |Val acc (NS/BH/CV): 0.5625 |val_class:1.1077 val_recon:1.2734 val_smooth: 0.0513 val_latent:15.9240
# Epoch 6
# Epoch 7:total=6.2723, cls=0.4374, recon=1.1041 (1.1193, 1.1029),  smooth=0.0245, latent=19.0243
# Validation loss: 11.7988 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8646 val_recon:1.9111 val_smooth: 0.0697 val_latent:13.3758
# Epoch 7
# Epoch 8:total=5.8160, cls=0.3930, recon=1.0935 (1.0970, 1.0944),  smooth=0.0242, latent=18.3978
# Validation loss: 9.4626 | Val acc: 0.8899 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7002 val_recon:1.4400 val_smooth: 0.0473 val_latent:14.2624
# Epoch 8
# Epoch 9:total=5.3013, cls=0.3431, recon=1.0832 (1.0698, 1.0838),  smooth=0.0236, latent=17.8834
# Validation loss: 14.8336 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.2500 |val_class:1.2541 val_recon:1.3901 val_smooth: 0.0353 val_latent:14.6497
# Epoch 9
# Epoch 10:total=4.8469, cls=0.2986, recon=1.0775 (1.0562, 1.0780),  smooth=0.0231, latent=17.1945
# Validation loss: 9.5845 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7789 val_recon:1.0130 val_smooth: 0.0228 val_latent:17.7349
# Epoch 10
# Epoch 11:total=4.7533, cls=0.2904, recon=1.0658 (1.0310, 1.0686),  smooth=0.0230, latent=16.6555
# Validation loss: 17.2365 | Val acc: 0.6330 |Val acc (NS/BH/CV): 0.2500 |val_class:1.3142 val_recon:2.6721 val_smooth: 0.0874 val_latent:10.5932
# Epoch 11
# Epoch 12:total=4.3065, cls=0.2480, recon=1.0519 (1.0099, 1.0549),  smooth=0.0220, latent=15.9592
# Validation loss: 19.8837 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.0000 |val_class:1.6005 val_recon:2.5162 val_smooth: 0.0812 val_latent:11.5435
# Epoch 12
# Epoch 13:total=3.8536, cls=0.2036, recon=1.0470 (1.0007, 1.0511),  smooth=0.0216, latent=15.4110
# Validation loss: 9.2611 | Val acc: 0.7982 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7491 val_recon:0.9853 val_smooth: 0.0229 val_latent:15.8897
# Epoch 13
# Epoch 14:total=4.6969, cls=0.2880, recon=1.0469 (0.9936, 1.0499),  smooth=0.0214, latent=15.3707
# Validation loss: 10.5332 | Val acc: 0.7752 |Val acc (NS/BH/CV): 0.5625 |val_class:0.8748 val_recon:1.0025 val_smooth: 0.0225 val_latent:15.8815
# Epoch 14
# Epoch 15:total=3.6175, cls=0.1811, recon=1.0452 (1.0590, 1.0431),  smooth=0.0205, latent=14.0309
# Validation loss: 10.4736 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8720 val_recon:0.9899 val_smooth: 0.0207 val_latent:14.5213
# Epoch 15
# Epoch 16:total=3.1128, cls=0.1318, recon=1.0347 (1.0001, 1.0372),  smooth=0.0203, latent=13.8511
# Validation loss: 11.0203 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9303 val_recon:0.9731 val_smooth: 0.0186 val_latent:15.4668
# Epoch 16
# Epoch 17:total=3.0416, cls=0.1256, recon=1.0324 (0.9827, 1.0351),  smooth=0.0198, latent=13.7270
# Validation loss: 12.0074 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9813 val_recon:1.2374 val_smooth: 0.0404 val_latent:11.4786
# Epoch 17
# Epoch 18:total=3.0223, cls=0.1245, recon=1.0291 (0.9729, 1.0326),  smooth=0.0193, latent=13.4832
# Validation loss: 13.8894 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4375 |val_class:1.2130 val_recon:0.9588 val_smooth: 0.0246 val_latent:13.7985
# Epoch 18
# Epoch 19:total=2.7654, cls=0.0984, recon=1.0337 (0.9904, 1.0291),  smooth=0.0194, latent=13.3259
# Validation loss: 13.9731 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.2500 |val_class:1.1451 val_recon:1.5099 val_smooth: 0.0461 val_latent:10.6337
# Learning rate changed to 0.000250
# Epoch 19
# Epoch 20:total=2.4145, cls=0.0658, recon=1.0221 (0.9479, 1.0277),  smooth=0.0182, latent=13.2822
# Validation loss: 12.4299 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.5000 |val_class:1.0734 val_recon:0.9364 val_smooth: 0.0206 val_latent:13.5301
# Train accuracy: 0.99236 (0.95973)| Val accuracy: 0.83028 (0.50000) | Test accuracy: 0.86679 (0.42424)
#
# === Fold 5/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=56.5824, cls=1.2079, recon=32.0394 (33.0124, 31.9796),  smooth=1.1917, latent=21.8921
# Validation loss: 11.2012 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.2500 |val_class:0.8941 val_recon:1.0446 val_smooth: 0.0670 val_latent:19.8489
# Epoch 1
# Epoch 2:total=10.3920, cls=0.8093, recon=1.3052 (1.2242, 1.3113),  smooth=0.0448, latent=19.7789
# Validation loss: 12.5780 | Val acc: 0.5275 |Val acc (NS/BH/CV): 0.3750 |val_class:1.0361 val_recon:1.3969 val_smooth: 0.0267 val_latent:26.7111
# Epoch 2
# Epoch 3:total=8.6402, cls=0.6493, recon=1.2110 (1.2012, 1.2123),  smooth=0.0390, latent=19.6986
# Validation loss: 12.6993 | Val acc: 0.5872 |Val acc (NS/BH/CV): 0.5625 |val_class:1.0312 val_recon:1.6468 val_smooth: 0.0183 val_latent:29.7400
# Epoch 3
# Epoch 4:total=7.6047, cls=0.5529, recon=1.1743 (1.1524, 1.1773),  smooth=0.0353, latent=19.7441
# Validation loss: 8.2950 | Val acc: 0.8853 |Val acc (NS/BH/CV): 0.4375 |val_class:0.6237 val_recon:0.9616 val_smooth: 0.0550 val_latent:16.8273
# Epoch 4
# Epoch 5:total=6.7977, cls=0.4745, recon=1.1640 (1.1508, 1.1660),  smooth=0.0338, latent=19.7591
# Validation loss: 10.7352 | Val acc: 0.6514 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8655 val_recon:0.9641 val_smooth: 0.0568 val_latent:17.5566
# Epoch 5
# Epoch 6:total=6.2741, cls=0.4265, recon=1.1395 (1.1003, 1.1432),  smooth=0.0317, latent=19.1973
# Validation loss: 8.8996 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.6250 |val_class:0.7061 val_recon:1.0676 val_smooth: 0.0214 val_latent:22.8521
# Epoch 6
# Epoch 7:total=5.4261, cls=0.3449, recon=1.1271 (1.1333, 1.1277),  smooth=0.0296, latent=18.9611
# Validation loss: 12.7323 | Val acc: 0.6514 |Val acc (NS/BH/CV): 0.4375 |val_class:1.0978 val_recon:0.9192 val_smooth: 0.0278 val_latent:21.3404
# Epoch 7
# Epoch 8:total=5.1288, cls=0.3172, recon=1.1093 (1.0897, 1.1114),  smooth=0.0292, latent=18.3726
# Validation loss: 9.3606 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.5625 |val_class:0.7397 val_recon:1.2628 val_smooth: 0.0138 val_latent:23.9839
# Epoch 8
# Epoch 9:total=4.7293, cls=0.2801, recon=1.0953 (1.0941, 1.0959),  smooth=0.0276, latent=17.6594
# Validation loss: 10.7300 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.3125 |val_class:0.8906 val_recon:0.9734 val_smooth: 0.0293 val_latent:17.1569
# Epoch 9
# Epoch 10:total=4.3199, cls=0.2406, recon=1.0912 (1.1004, 1.0903),  smooth=0.0264, latent=17.0335
# Validation loss: 11.2144 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9259 val_recon:1.2446 val_smooth: 0.0146 val_latent:22.2302
# Learning rate changed to 0.000250
# Epoch 10
# Epoch 11:total=3.5902, cls=0.1700, recon=1.0763 (1.0853, 1.0758),  smooth=0.0255, latent=16.7821
# Validation loss: 10.0839 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8392 val_recon:0.8528 val_smooth: 0.0280 val_latent:16.6955
# Epoch 11
# Epoch 12:total=3.3939, cls=0.1512, recon=1.0703 (1.0301, 1.0749),  smooth=0.0252, latent=16.9374
# Validation loss: 11.1750 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.5625 |val_class:0.9516 val_recon:0.8566 val_smooth: 0.0242 val_latent:17.9680
# Epoch 12
# Epoch 13:total=3.2844, cls=0.1406, recon=1.0674 (1.0313, 1.0698),  smooth=0.0252, latent=17.0006
# Validation loss: 10.8948 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.5000 |val_class:0.9237 val_recon:0.8556 val_smooth: 0.0242 val_latent:17.6848
# Epoch 13
# Epoch 14:total=3.3184, cls=0.1442, recon=1.0682 (1.0472, 1.0704),  smooth=0.0248, latent=17.0358
# Validation loss: 10.6825 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9030 val_recon:0.8589 val_smooth: 0.0233 val_latent:17.7701
# Epoch 14
# Epoch 15:total=3.1648, cls=0.1291, recon=1.0695 (1.0559, 1.0698),  smooth=0.0244, latent=17.0666
# Validation loss: 11.4223 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.2500 |val_class:0.9702 val_recon:0.8650 val_smooth: 0.0296 val_latent:16.1984
# Epoch 15
# Epoch 16:total=3.3533, cls=0.1485, recon=1.0651 (1.0587, 1.0636),  smooth=0.0244, latent=17.0143
# Validation loss: 11.5586 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9869 val_recon:0.8455 val_smooth: 0.0284 val_latent:16.6104
# Learning rate changed to 0.000063
# Epoch 16
# Epoch 17:total=3.0540, cls=0.1192, recon=1.0625 (1.0213, 1.0641),  smooth=0.0240, latent=16.9763
# Validation loss: 11.1004 | Val acc: 0.8670 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9438 val_recon:0.8437 val_smooth: 0.0258 val_latent:16.8240
# Epoch 17
# Epoch 18:total=3.0228, cls=0.1164, recon=1.0604 (1.0170, 1.0655),  smooth=0.0239, latent=17.0100
# Validation loss: 11.3727 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9715 val_recon:0.8412 val_smooth: 0.0257 val_latent:16.9288
# Epoch 18
# Epoch 19:total=2.9799, cls=0.1123, recon=1.0590 (1.0143, 1.0621),  smooth=0.0238, latent=17.0467
# Validation loss: 11.3807 | Val acc: 0.8716 |Val acc (NS/BH/CV): 0.5000 |val_class:0.9710 val_recon:0.8468 val_smooth: 0.0264 val_latent:16.5716
# Epoch 19
# Epoch 20:total=3.0895, cls=0.1226, recon=1.0634 (1.0632, 1.0621),  smooth=0.0240, latent=17.0132
# Validation loss: 11.3372 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9654 val_recon:0.8490 val_smooth: 0.0275 val_latent:16.4199
# Train accuracy: 0.98473 (0.93960)| Val accuracy: 0.85321 (0.43750) | Test accuracy: 0.85766 (0.39394)
#
# === Fold 6/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=133.7548, cls=1.1381, recon=102.1786 (102.5393, 102.1525),  smooth=1.9666, latent=11.1879
# Validation loss: 13.9547 | Val acc: 0.6651 |Val acc (NS/BH/CV): 0.0000 |val_class:1.0480 val_recon:2.0184 val_smooth: 0.0926 val_latent:12.7139
# Epoch 1
# Epoch 2:total=11.5863, cls=0.9153, recon=1.5473 (1.4043, 1.5538),  smooth=0.0352, latent=15.8026
# Validation loss: 10.6382 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.1875 |val_class:0.8590 val_recon:1.1869 val_smooth: 0.0328 val_latent:15.1384
# Epoch 2
# Epoch 3:total=9.9231, cls=0.7839, recon=1.2611 (1.3406, 1.2567),  smooth=0.0290, latent=15.1222
# Validation loss: 10.0111 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7761 val_recon:1.2165 val_smooth: 0.0503 val_latent:12.5112
# Epoch 3
# Epoch 4:total=9.1137, cls=0.7125, recon=1.1852 (1.2457, 1.1793),  smooth=0.0270, latent=15.1941
# Validation loss: 9.2153 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.0625 |val_class:0.7203 val_recon:1.1162 val_smooth: 0.0363 val_latent:13.4143
# Epoch 4
# Epoch 5:total=8.0977, cls=0.6165, recon=1.1435 (1.1760, 1.1510),  smooth=0.0255, latent=15.1027
# Validation loss: 9.9332 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.4375 |val_class:0.7615 val_recon:1.6761 val_smooth: 0.0102 val_latent:21.4865
# Epoch 5
# Epoch 6:total=7.2734, cls=0.5374, recon=1.1144 (1.1428, 1.1141),  smooth=0.0251, latent=15.2879
# Validation loss: 9.3196 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.1875 |val_class:0.6441 val_recon:2.2701 val_smooth: 0.0062 val_latent:26.4109
# Epoch 6
# Epoch 7:total=6.6442, cls=0.4752, recon=1.1058 (1.1121, 1.1054),  smooth=0.0251, latent=15.4051
# Validation loss: 12.4434 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.0000 |val_class:0.8297 val_recon:2.6563 val_smooth: 0.0959 val_latent:9.4062
# Epoch 7
# Epoch 8:total=6.0651, cls=0.4189, recon=1.0904 (1.0477, 1.0925),  smooth=0.0249, latent=15.3863
# Validation loss: 8.1498 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3750 |val_class:0.6333 val_recon:1.0455 val_smooth: 0.0233 val_latent:15.2836
# Epoch 8
# Epoch 9:total=5.4165, cls=0.3552, recon=1.0800 (1.0368, 1.0822),  smooth=0.0247, latent=14.9718
# Validation loss: 14.3779 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.1250 |val_class:1.2136 val_recon:1.3005 val_smooth: 0.0405 val_latent:12.2172
# Epoch 9
# Epoch 10:total=4.9089, cls=0.3060, recon=1.0708 (1.0095, 1.0758),  smooth=0.0239, latent=14.7402
# Validation loss: 8.7803 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.2500 |val_class:0.7003 val_recon:0.9745 val_smooth: 0.0264 val_latent:13.8451
# Epoch 10
# Epoch 11:total=4.5088, cls=0.2670, recon=1.0631 (1.0277, 1.0663),  smooth=0.0236, latent=14.5543
# Validation loss: 9.9795 | Val acc: 0.7615 |Val acc (NS/BH/CV): 0.6250 |val_class:0.8256 val_recon:0.9477 val_smooth: 0.0236 val_latent:14.5400
# Epoch 11
# Epoch 12:total=4.2154, cls=0.2388, recon=1.0561 (0.9954, 1.0605),  smooth=0.0231, latent=14.1229
# Validation loss: 10.6934 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.2500 |val_class:0.8509 val_recon:1.2022 val_smooth: 0.0445 val_latent:11.3231
# Epoch 12
# Epoch 13:total=3.9738, cls=0.2159, recon=1.0464 (1.0010, 1.0497),  smooth=0.0228, latent=13.6073
# Validation loss: 15.4160 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.1875 |val_class:1.3488 val_recon:1.2588 val_smooth: 0.0126 val_latent:16.6073
# Epoch 13
# Epoch 14:total=3.7531, cls=0.1945, recon=1.0452 (0.9979, 1.0487),  smooth=0.0222, latent=13.2224
# Validation loss: 12.3896 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.2500 |val_class:0.8480 val_recon:2.5794 val_smooth: 0.0795 val_latent:8.0238
# Learning rate changed to 0.000250
# Epoch 14
# Epoch 15:total=3.1309, cls=0.1344, recon=1.0385 (0.9856, 1.0422),  smooth=0.0208, latent=12.9918
# Validation loss: 9.6746 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.3750 |val_class:0.7990 val_recon:0.9580 val_smooth: 0.0186 val_latent:13.9452
# Epoch 15
# Epoch 16:total=3.0843, cls=0.1311, recon=1.0312 (0.9636, 1.0358),  smooth=0.0202, latent=12.9778
# Validation loss: 10.1181 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.3750 |val_class:0.8437 val_recon:0.9213 val_smooth: 0.0219 val_latent:13.5577
# Epoch 16
# Epoch 17:total=2.9975, cls=0.1227, recon=1.0302 (0.9695, 1.0352),  smooth=0.0201, latent=12.9980
# Validation loss: 11.7350 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.2500 |val_class:1.0039 val_recon:0.9335 val_smooth: 0.0223 val_latent:12.7801
# Epoch 17
# Epoch 18:total=2.8344, cls=0.1068, recon=1.0294 (0.9636, 1.0337),  smooth=0.0198, latent=13.0886
# Validation loss: 10.9795 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.3125 |val_class:0.9243 val_recon:0.9398 val_smooth: 0.0258 val_latent:12.3666
# Epoch 18
# Epoch 19:total=2.8610, cls=0.1099, recon=1.0266 (0.9690, 1.0308),  smooth=0.0196, latent=13.1290
# Validation loss: 10.8672 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9195 val_recon:0.9103 val_smooth: 0.0223 val_latent:13.1046
# Epoch 19
# Epoch 20:total=2.7747, cls=0.1016, recon=1.0254 (0.9483, 1.0309),  smooth=0.0195, latent=13.1279
# Validation loss: 11.0408 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9356 val_recon:0.9170 val_smooth: 0.0230 val_latent:12.9008
# Learning rate changed to 0.000063
# Train accuracy: 0.98676 (0.95302)| Val accuracy: 0.85321 (0.37500) | Test accuracy: 0.86131 (0.36364)
#
# === Fold 7/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=46.3813, cls=1.1521, recon=25.0889 (25.4978, 25.0651),  smooth=0.9224, latent=22.0189
# Validation loss: 11.7771 | Val acc: 0.7018 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9617 val_recon:1.1025 val_smooth: 0.0513 val_latent:20.3035
# Epoch 1
# Epoch 2:total=10.1352, cls=0.7943, recon=1.2493 (1.1634, 1.2551),  smooth=0.0396, latent=21.0827
# Validation loss: 12.6510 | Val acc: 0.6193 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9895 val_recon:1.3367 val_smooth: 0.0879 val_latent:15.0301
# Epoch 2
# Epoch 3:total=8.5818, cls=0.6504, recon=1.1764 (1.0988, 1.1806),  smooth=0.0355, latent=20.4255
# Validation loss: 14.6603 | Val acc: 0.5734 |Val acc (NS/BH/CV): 0.2500 |val_class:1.2537 val_recon:1.0294 val_smooth: 0.0549 val_latent:18.8157
# Epoch 3
# Epoch 4:total=7.5023, cls=0.5470, recon=1.1549 (1.0853, 1.1595),  smooth=0.0330, latent=19.8581
# Validation loss: 15.9564 | Val acc: 0.5183 |Val acc (NS/BH/CV): 0.2500 |val_class:1.4066 val_recon:1.0589 val_smooth: 0.0280 val_latent:22.6624
# Epoch 4
# Epoch 5:total=6.3526, cls=0.4369, recon=1.1371 (1.0703, 1.1415),  smooth=0.0298, latent=19.6600
# Validation loss: 9.0468 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.3125 |val_class:0.7222 val_recon:0.9623 val_smooth: 0.0313 val_latent:19.2604
# Epoch 5
# Epoch 6:total=5.5681, cls=0.3610, recon=1.1224 (1.0718, 1.1267),  smooth=0.0285, latent=19.3544
# Validation loss: 9.5508 | Val acc: 0.7798 |Val acc (NS/BH/CV): 0.5000 |val_class:0.7662 val_recon:1.1606 val_smooth: 0.0173 val_latent:24.0552
# Epoch 6
# Epoch 7:total=5.2987, cls=0.3367, recon=1.1037 (1.0312, 1.1112),  smooth=0.0276, latent=18.7871
# Validation loss: 12.2952 | Val acc: 0.6651 |Val acc (NS/BH/CV): 0.5625 |val_class:0.9120 val_recon:2.5579 val_smooth: 0.0047 val_latent:35.6175
# Epoch 7
# Epoch 8:total=4.5780, cls=0.2679, recon=1.0859 (1.0040, 1.0915),  smooth=0.0260, latent=17.9903
# Validation loss: 9.5339 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.2500 |val_class:0.7631 val_recon:1.0103 val_smooth: 0.0342 val_latent:15.3488
# Epoch 8
# Epoch 9:total=3.9832, cls=0.2103, recon=1.0754 (0.9893, 1.0803),  smooth=0.0251, latent=17.5266
# Validation loss: 10.6779 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.1875 |val_class:0.8903 val_recon:1.0055 val_smooth: 0.0214 val_latent:17.7645
# Epoch 9
# Epoch 10:total=3.7761, cls=0.1923, recon=1.0585 (0.9687, 1.0646),  smooth=0.0240, latent=16.9950
# Validation loss: 13.5916 | Val acc: 0.7110 |Val acc (NS/BH/CV): 0.2500 |val_class:1.1829 val_recon:0.9000 val_smooth: 0.0308 val_latent:17.0962
# Epoch 10
# Epoch 11:total=3.8913, cls=0.2048, recon=1.0512 (0.9819, 1.0566),  smooth=0.0237, latent=16.4696
# Validation loss: 15.1245 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.1875 |val_class:1.2177 val_recon:1.7223 val_smooth: 0.0674 val_latent:11.1497
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=3.0597, cls=0.1237, recon=1.0398 (0.9528, 1.0445),  smooth=0.0227, latent=15.9818
# Validation loss: 10.5425 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.5625 |val_class:0.8849 val_recon:0.9362 val_smooth: 0.0201 val_latent:17.1546
# Epoch 12
# Epoch 13:total=2.9354, cls=0.1119, recon=1.0377 (0.9459, 1.0435),  smooth=0.0223, latent=15.9441
# Validation loss: 11.0136 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3125 |val_class:0.9323 val_recon:0.9037 val_smooth: 0.0231 val_latent:15.9806
# Epoch 13
# Epoch 14:total=2.8822, cls=0.1069, recon=1.0375 (0.9413, 1.0440),  smooth=0.0221, latent=15.9436
# Validation loss: 10.6046 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4375 |val_class:0.8922 val_recon:0.9144 val_smooth: 0.0213 val_latent:16.1559
# Epoch 14
# Epoch 15:total=2.8685, cls=0.1061, recon=1.0338 (0.9351, 1.0399),  smooth=0.0218, latent=16.0146
# Validation loss: 11.5179 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.4375 |val_class:0.9767 val_recon:0.9373 val_smooth: 0.0260 val_latent:15.2863
# Epoch 15
# Epoch 16:total=2.6816, cls=0.0879, recon=1.0322 (0.9381, 1.0384),  smooth=0.0216, latent=16.0871
# Validation loss: 11.5840 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9889 val_recon:0.9179 val_smooth: 0.0222 val_latent:16.0790
# Epoch 16
# Epoch 17:total=2.7210, cls=0.0924, recon=1.0286 (0.9355, 1.0359),  smooth=0.0214, latent=16.0220
# Validation loss: 10.9099 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9208 val_recon:0.8894 val_smooth: 0.0258 val_latent:15.6124
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=2.6249, cls=0.0830, recon=1.0287 (0.9342, 1.0340),  smooth=0.0212, latent=16.1065
# Validation loss: 11.0186 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.3750 |val_class:0.9333 val_recon:0.8962 val_smooth: 0.0235 val_latent:16.0849
# Epoch 18
# Epoch 19:total=2.6847, cls=0.0887, recon=1.0309 (0.9453, 1.0339),  smooth=0.0213, latent=16.0907
# Validation loss: 10.8282 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3125 |val_class:0.9144 val_recon:0.9005 val_smooth: 0.0230 val_latent:15.7256
# Epoch 19
# Epoch 20:total=2.5758, cls=0.0783, recon=1.0279 (0.9356, 1.0338),  smooth=0.0210, latent=16.1079
# Validation loss: 10.9249 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.3125 |val_class:0.9252 val_recon:0.8930 val_smooth: 0.0226 val_latent:16.0005
# Train accuracy: 0.99236 (0.95973)| Val accuracy: 0.83486 (0.31250) | Test accuracy: 0.86679 (0.30303)
#
# === Fold 8/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=25.0393, cls=0.9813, recon=10.4035 (9.9102, 10.4385),  smooth=0.4262, latent=32.5037
# Validation loss: 13.2465 | Val acc: 0.7064 |Val acc (NS/BH/CV): 0.1176 |val_class:0.9668 val_recon:1.3555 val_smooth: 0.1672 val_latent:22.1923
# Epoch 1
# Epoch 2:total=9.5534, cls=0.7084, recon=1.3758 (1.1050, 1.3909),  smooth=0.0537, latent=26.8723
# Validation loss: 11.9022 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.1765 |val_class:0.9215 val_recon:1.1447 val_smooth: 0.0993 val_latent:19.6848
# Epoch 2
# Epoch 3:total=7.9478, cls=0.5831, recon=1.1979 (1.1067, 1.2092),  smooth=0.0365, latent=24.6406
# Validation loss: 8.7000 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.3529 |val_class:0.6813 val_recon:0.9265 val_smooth: 0.0407 val_latent:22.6555
# Epoch 3
# Epoch 4:total=6.8613, cls=0.4855, recon=1.1468 (1.1040, 1.1479),  smooth=0.0304, latent=23.9503
# Validation loss: 13.3139 | Val acc: 0.7661 |Val acc (NS/BH/CV): 0.1176 |val_class:1.0338 val_recon:1.6580 val_smooth: 0.0769 val_latent:15.7864
# Epoch 4
# Epoch 5:total=5.8790, cls=0.3931, recon=1.1228 (1.0907, 1.1265),  smooth=0.0269, latent=23.2074
# Validation loss: 10.0061 | Val acc: 0.7661 |Val acc (NS/BH/CV): 0.3529 |val_class:0.8247 val_recon:0.9593 val_smooth: 0.0240 val_latent:25.6907
# Epoch 5
# Epoch 6:total=5.6751, cls=0.3754, recon=1.1042 (1.0700, 1.1058),  smooth=0.0259, latent=22.6650
# Validation loss: 12.8057 | Val acc: 0.7523 |Val acc (NS/BH/CV): 0.1176 |val_class:1.0729 val_recon:1.3972 val_smooth: 0.0112 val_latent:31.0696
# Epoch 6
# Epoch 7:total=4.6496, cls=0.2756, recon=1.0907 (1.0281, 1.0956),  smooth=0.0243, latent=21.5217
# Validation loss: 16.7946 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.1176 |val_class:1.0393 val_recon:4.4571 val_smooth: 0.1395 val_latent:10.8411
# Epoch 7
# Epoch 8:total=4.1722, cls=0.2303, recon=1.0751 (1.0323, 1.0782),  smooth=0.0234, latent=21.0085
# Validation loss: 17.6718 | Val acc: 0.6330 |Val acc (NS/BH/CV): 0.1176 |val_class:1.5068 val_recon:1.4652 val_smooth: 0.0584 val_latent:15.1309
# Epoch 8
# Epoch 9:total=4.2910, cls=0.2421, recon=1.0780 (1.0272, 1.0795),  smooth=0.0231, latent=20.4468
# Validation loss: 11.5929 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.1176 |val_class:0.9853 val_recon:0.8712 val_smooth: 0.0310 val_latent:17.3166
# Learning rate changed to 0.000250
# Epoch 9
# Epoch 10:total=3.5161, cls=0.1672, recon=1.0638 (0.9918, 1.0693),  smooth=0.0220, latent=19.3843
# Validation loss: 10.4491 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.2353 |val_class:0.8707 val_recon:0.9115 val_smooth: 0.0272 val_latent:17.3711
# Epoch 10
# Epoch 11:total=3.2518, cls=0.1421, recon=1.0539 (0.9580, 1.0596),  smooth=0.0217, latent=19.3504
# Validation loss: 10.1570 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3529 |val_class:0.8522 val_recon:0.8552 val_smooth: 0.0220 val_latent:19.6292
# Epoch 11
# Epoch 12:total=3.1664, cls=0.1341, recon=1.0515 (0.9814, 1.0564),  smooth=0.0214, latent=19.3834
# Validation loss: 10.9066 | Val acc: 0.8807 |Val acc (NS/BH/CV): 0.2941 |val_class:0.9208 val_recon:0.8867 val_smooth: 0.0253 val_latent:18.2046
# Epoch 12
# Epoch 13:total=3.0465, cls=0.1227, recon=1.0482 (0.9662, 1.0538),  smooth=0.0212, latent=19.4121
# Validation loss: 11.5800 | Val acc: 0.8761 |Val acc (NS/BH/CV): 0.2353 |val_class:0.9586 val_recon:1.0970 val_smooth: 0.0342 val_latent:15.8203
# Epoch 13
# Epoch 14:total=2.9582, cls=0.1144, recon=1.0471 (0.9600, 1.0535),  smooth=0.0208, latent=19.3786
# Validation loss: 11.4495 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.1765 |val_class:0.9800 val_recon:0.9108 val_smooth: 0.0178 val_latent:21.4452
# Epoch 14
# Epoch 15:total=2.9470, cls=0.1128, recon=1.0509 (0.9727, 1.0490),  smooth=0.0210, latent=19.2265
# Validation loss: 10.3946 | Val acc: 0.8761 |Val acc (NS/BH/CV): 0.3529 |val_class:0.8666 val_recon:0.8922 val_smooth: 0.0280 val_latent:17.0469
# Learning rate changed to 0.000063
# Epoch 15
# Epoch 16:total=2.8940, cls=0.1087, recon=1.0436 (0.9824, 1.0473),  smooth=0.0205, latent=19.2074
# Validation loss: 10.5364 | Val acc: 0.8945 |Val acc (NS/BH/CV): 0.2941 |val_class:0.8844 val_recon:0.8827 val_smooth: 0.0253 val_latent:17.2825
# Epoch 16
# Epoch 17:total=2.8261, cls=0.1020, recon=1.0436 (0.9611, 1.0501),  smooth=0.0204, latent=19.2324
# Validation loss: 10.6297 | Val acc: 0.8899 |Val acc (NS/BH/CV): 0.2941 |val_class:0.8932 val_recon:0.8869 val_smooth: 0.0254 val_latent:17.4054
# Epoch 17
# Epoch 18:total=2.7059, cls=0.0904, recon=1.0400 (0.9466, 1.0460),  smooth=0.0204, latent=19.2326
# Validation loss: 10.7761 | Val acc: 0.8853 |Val acc (NS/BH/CV): 0.2941 |val_class:0.9149 val_recon:0.8610 val_smooth: 0.0209 val_latent:18.7648
# Epoch 18
# Epoch 19:total=2.7172, cls=0.0917, recon=1.0405 (0.9494, 1.0472),  smooth=0.0202, latent=19.2388
# Validation loss: 10.6315 | Val acc: 0.8853 |Val acc (NS/BH/CV): 0.2941 |val_class:0.9010 val_recon:0.8570 val_smooth: 0.0207 val_latent:19.0816
# Epoch 19
# Epoch 20:total=2.7091, cls=0.0911, recon=1.0386 (0.9388, 1.0448),  smooth=0.0202, latent=19.1986
# Validation loss: 11.0558 | Val acc: 0.8899 |Val acc (NS/BH/CV): 0.2941 |val_class:0.9392 val_recon:0.8616 val_smooth: 0.0246 val_latent:18.2217
# Train accuracy: 0.98982 (0.96622)| Val accuracy: 0.88991 (0.29412) | Test accuracy: 0.87409 (0.27273)
#
# === Fold 9/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=116.8722, cls=1.1716, recon=87.8831 (88.5260, 87.8479),  smooth=1.6740, latent=14.6946
# Validation loss: 13.9686 | Val acc: 0.7752 |Val acc (NS/BH/CV): 0.0588 |val_class:1.0724 val_recon:1.6933 val_smooth: 0.1014 val_latent:17.4672
# Epoch 1
# Epoch 2:total=10.8702, cls=0.8669, recon=1.3216 (1.1523, 1.3340),  smooth=0.0339, latent=21.3698
# Validation loss: 11.4521 | Val acc: 0.7936 |Val acc (NS/BH/CV): 0.1765 |val_class:0.9227 val_recon:1.3483 val_smooth: 0.0338 val_latent:19.8784
# Epoch 2
# Epoch 3:total=9.4350, cls=0.7441, recon=1.1988 (1.1566, 1.2003),  smooth=0.0256, latent=20.2814
# Validation loss: 10.6584 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.1765 |val_class:0.8622 val_recon:1.2815 val_smooth: 0.0213 val_latent:21.9400
# Epoch 3
# Epoch 4:total=8.7457, cls=0.6808, recon=1.1549 (1.1420, 1.1562),  smooth=0.0243, latent=19.8354
# Validation loss: 11.1413 | Val acc: 0.7523 |Val acc (NS/BH/CV): 0.1765 |val_class:0.9131 val_recon:1.2343 val_smooth: 0.0234 val_latent:21.1118
# Epoch 4
# Epoch 5:total=8.2108, cls=0.6304, recon=1.1332 (1.1429, 1.1316),  smooth=0.0234, latent=19.3254
# Validation loss: 15.0237 | Val acc: 0.6881 |Val acc (NS/BH/CV): 0.0588 |val_class:1.0694 val_recon:2.8637 val_smooth: 0.0934 val_latent:11.4598
# Epoch 5
# Epoch 6:total=7.1430, cls=0.5253, recon=1.1264 (1.1307, 1.1251),  smooth=0.0224, latent=19.0414
# Validation loss: 12.0713 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.1176 |val_class:0.9356 val_recon:1.7211 val_smooth: 0.0459 val_latent:14.0807
# Epoch 6
# Epoch 7:total=6.4980, cls=0.4610, recon=1.1247 (1.1264, 1.1244),  smooth=0.0223, latent=18.7757
# Validation loss: 12.3136 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.0588 |val_class:0.9895 val_recon:1.4868 val_smooth: 0.0394 val_latent:15.1256
# Epoch 7
# Epoch 8:total=5.6519, cls=0.3779, recon=1.1154 (1.0987, 1.1172),  smooth=0.0216, latent=18.4074
# Validation loss: 18.5756 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.0000 |val_class:1.6147 val_recon:1.4663 val_smooth: 0.0423 val_latent:14.6800
# Epoch 8
# Epoch 9:total=5.2513, cls=0.3385, recon=1.1095 (1.0902, 1.1109),  smooth=0.0214, latent=17.8828
# Validation loss: 17.3647 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.0588 |val_class:1.1669 val_recon:4.2722 val_smooth: 0.0889 val_latent:9.2578
# Learning rate changed to 0.000250
# Epoch 9
# Epoch 10:total=4.3453, cls=0.2500, recon=1.0968 (1.0567, 1.1010),  smooth=0.0205, latent=17.5194
# Validation loss: 12.5756 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0524 val_recon:1.2243 val_smooth: 0.0286 val_latent:14.9754
# Epoch 10
# Epoch 11:total=4.2447, cls=0.2402, recon=1.0956 (1.0650, 1.0980),  smooth=0.0203, latent=17.5875
# Validation loss: 14.7287 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.2353 |val_class:1.2496 val_recon:1.3506 val_smooth: 0.0341 val_latent:14.8022
# Epoch 11
# Epoch 12:total=4.0816, cls=0.2245, recon=1.0888 (1.0430, 1.0923),  smooth=0.0204, latent=17.6040
# Validation loss: 14.2041 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.1765 |val_class:1.2223 val_recon:1.1720 val_smooth: 0.0266 val_latent:16.1719
# Epoch 12
# Epoch 13:total=4.0868, cls=0.2255, recon=1.0870 (1.0426, 1.0904),  smooth=0.0201, latent=17.5741
# Validation loss: 13.5467 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.2941 |val_class:1.1670 val_recon:1.1760 val_smooth: 0.0154 val_latent:20.3914
# Epoch 13
# Epoch 14:total=3.8198, cls=0.1996, recon=1.0795 (1.0261, 1.0834),  smooth=0.0200, latent=17.4969
# Validation loss: 14.1756 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2188 val_recon:1.1671 val_smooth: 0.0278 val_latent:15.6675
# Epoch 14
# Epoch 15:total=3.6185, cls=0.1801, recon=1.0756 (1.0184, 1.0784),  smooth=0.0198, latent=17.4887
# Validation loss: 14.2484 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2391 val_recon:1.0850 val_smooth: 0.0229 val_latent:17.0022
# Learning rate changed to 0.000063
# Epoch 15
# Epoch 16:total=3.4940, cls=0.1679, recon=1.0730 (1.0352, 1.0757),  smooth=0.0197, latent=17.3597
# Validation loss: 14.1409 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2298 val_recon:1.0737 val_smooth: 0.0225 val_latent:16.8649
# Epoch 16
# Epoch 17:total=3.4492, cls=0.1638, recon=1.0704 (1.0107, 1.0742),  smooth=0.0197, latent=17.3774
# Validation loss: 14.2294 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2385 val_recon:1.0724 val_smooth: 0.0228 val_latent:16.8615
# Epoch 17
# Epoch 18:total=3.4845, cls=0.1672, recon=1.0724 (1.0071, 1.0749),  smooth=0.0196, latent=17.3604
# Validation loss: 14.2418 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2420 val_recon:1.0656 val_smooth: 0.0212 val_latent:17.4005
# Epoch 18
# Epoch 19:total=3.4154, cls=0.1607, recon=1.0691 (0.9976, 1.0749),  smooth=0.0195, latent=17.3625
# Validation loss: 14.0798 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.2941 |val_class:1.2277 val_recon:1.0568 val_smooth: 0.0201 val_latent:17.7459
# Epoch 19
# Epoch 20:total=3.3679, cls=0.1562, recon=1.0661 (0.9971, 1.0710),  smooth=0.0196, latent=17.3506
# Validation loss: 15.1087 | Val acc: 0.8349 |Val acc (NS/BH/CV): 0.2941 |val_class:1.3290 val_recon:1.0592 val_smooth: 0.0215 val_latent:17.5193
# Train accuracy: 0.96436 (0.87162)| Val accuracy: 0.83486 (0.29412) | Test accuracy: 0.84489 (0.27273)
#
# === Fold 10/10 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=59.3688, cls=1.0596, recon=34.9127 (35.1112, 34.9031),  smooth=1.3303, latent=30.8303
# Validation loss: 12.3601 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.1176 |val_class:0.8471 val_recon:1.6433 val_smooth: 0.1700 val_latent:18.2599
# Epoch 1
# Epoch 2:total=9.7088, cls=0.7397, recon=1.3390 (1.2019, 1.3478),  smooth=0.0417, latent=28.4903
# Validation loss: 13.5513 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.0000 |val_class:0.9360 val_recon:2.1638 val_smooth: 0.1484 val_latent:16.8952
# Epoch 2
# Epoch 3:total=8.5171, cls=0.6391, recon=1.2170 (1.1985, 1.2191),  smooth=0.0354, latent=27.4907
# Validation loss: 19.1166 | Val acc: 0.7294 |Val acc (NS/BH/CV): 0.0588 |val_class:1.0442 val_recon:5.3364 val_smooth: 0.2798 val_latent:12.2254
# Epoch 3
# Epoch 4:total=7.5149, cls=0.5435, recon=1.1957 (1.1481, 1.1990),  smooth=0.0327, latent=27.5267
# Validation loss: 15.1491 | Val acc: 0.7064 |Val acc (NS/BH/CV): 0.0000 |val_class:1.2390 val_recon:1.3828 val_smooth: 0.0825 val_latent:22.3764
# Epoch 4
# Epoch 5:total=6.8830, cls=0.4820, recon=1.1847 (1.1765, 1.1877),  smooth=0.0320, latent=27.2315
# Validation loss: 9.6295 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.2353 |val_class:0.7330 val_recon:1.1817 val_smooth: 0.0565 val_latent:21.7176
# Epoch 5
# Epoch 6:total=6.1817, cls=0.4161, recon=1.1646 (1.1114, 1.1675),  smooth=0.0297, latent=26.7414
# Validation loss: 15.6703 | Val acc: 0.7018 |Val acc (NS/BH/CV): 0.1176 |val_class:1.0955 val_recon:2.9294 val_smooth: 0.1238 val_latent:14.9927
# Epoch 6
# Epoch 7:total=5.6312, cls=0.3631, recon=1.1499 (1.0985, 1.1527),  smooth=0.0289, latent=26.2361
# Validation loss: 16.3884 | Val acc: 0.6835 |Val acc (NS/BH/CV): 0.0588 |val_class:1.3588 val_recon:1.4910 val_smooth: 0.0755 val_latent:18.5227
# Epoch 7
# Epoch 8:total=5.1695, cls=0.3191, recon=1.1366 (1.1003, 1.1387),  smooth=0.0280, latent=25.2210
# Validation loss: 17.1495 | Val acc: 0.6422 |Val acc (NS/BH/CV): 0.2941 |val_class:1.4193 val_recon:1.6350 val_smooth: 0.0766 val_latent:17.0515
# Epoch 8
# Epoch 9:total=4.7623, cls=0.2802, recon=1.1273 (1.0710, 1.1301),  smooth=0.0270, latent=24.0837
# Validation loss: 10.6227 | Val acc: 0.7844 |Val acc (NS/BH/CV): 0.2353 |val_class:0.8684 val_recon:1.0116 val_smooth: 0.0366 val_latent:20.8956
# Epoch 9
# Epoch 10:total=4.4394, cls=0.2506, recon=1.1101 (1.0518, 1.1169),  smooth=0.0259, latent=23.0442
# Validation loss: 18.7317 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.0588 |val_class:1.0354 val_recon:6.1162 val_smooth: 0.1709 val_latent:10.6065
# Epoch 10
# Epoch 11:total=4.1695, cls=0.2247, recon=1.1000 (1.0625, 1.1016),  smooth=0.0257, latent=22.0273
# Validation loss: 11.9604 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.1176 |val_class:0.9474 val_recon:1.3922 val_smooth: 0.0533 val_latent:16.2988
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=3.2908, cls=0.1388, recon=1.0928 (1.0151, 1.0982),  smooth=0.0244, latent=21.2899
# Validation loss: 11.3108 | Val acc: 0.8257 |Val acc (NS/BH/CV): 0.2941 |val_class:0.9427 val_recon:0.9747 val_smooth: 0.0345 val_latent:19.1149
# Epoch 12
# Epoch 13:total=3.2063, cls=0.1314, recon=1.0834 (1.0057, 1.0891),  smooth=0.0243, latent=21.3645
# Validation loss: 10.3552 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.2941 |val_class:0.8486 val_recon:0.9913 val_smooth: 0.0313 val_latent:19.2961
# Epoch 13
# Epoch 14:total=3.1503, cls=0.1263, recon=1.0797 (1.0007, 1.0874),  smooth=0.0241, latent=21.3482
# Validation loss: 10.1198 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.3529 |val_class:0.8355 val_recon:0.9272 val_smooth: 0.0272 val_latent:20.6814
# Epoch 14
# Epoch 15:total=3.1075, cls=0.1225, recon=1.0771 (0.9989, 1.0817),  smooth=0.0238, latent=21.3487
# Validation loss: 10.7255 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.2941 |val_class:0.8983 val_recon:0.9485 val_smooth: 0.0226 val_latent:22.4367
# Epoch 15
# Epoch 16:total=3.0475, cls=0.1174, recon=1.0699 (0.9813, 1.0762),  smooth=0.0237, latent=21.3479
# Validation loss: 11.0283 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.2353 |val_class:0.9256 val_recon:0.9300 val_smooth: 0.0276 val_latent:20.6949
# Epoch 16
# Epoch 17:total=3.0154, cls=0.1146, recon=1.0688 (0.9829, 1.0750),  smooth=0.0234, latent=21.3127
# Validation loss: 12.1361 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.2941 |val_class:1.0195 val_recon:1.0399 val_smooth: 0.0337 val_latent:18.6630
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=2.8714, cls=0.1005, recon=1.0670 (0.9843, 1.0724),  smooth=0.0232, latent=21.3106
# Validation loss: 11.4654 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.2353 |val_class:0.9690 val_recon:0.9342 val_smooth: 0.0275 val_latent:20.3948
# Epoch 18
# Epoch 19:total=2.8497, cls=0.0984, recon=1.0661 (0.9856, 1.0718),  smooth=0.0233, latent=21.2774
# Validation loss: 11.7122 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.2353 |val_class:0.9978 val_recon:0.9259 val_smooth: 0.0241 val_latent:21.6435
# Epoch 19
# Epoch 20:total=2.8158, cls=0.0954, recon=1.0651 (0.9709, 1.0710),  smooth=0.0230, latent=21.2882
# Validation loss: 11.5219 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.2353 |val_class:0.9786 val_recon:0.9263 val_smooth: 0.0243 val_latent:21.5291
# Train accuracy: 0.98625 (0.94595)| Val accuracy: 0.85321 (0.23529) | Test accuracy: 0.86131 (0.27273)

# %%
all_results2, train_data, test_data = semisupervised_kfold_test(
    SemiSupervisedAE,
    np.column_stack([pn_normspec_labelled, pn_counts_labelled]),
    pn_spec_labels,
    np.column_stack([pn_normspec[unlabelled_args], pn_counts[unlabelled_args]]),
    epochs=20, lambda_cls=10, l2_lambda=1.0e-3, l1_lambda=1.0e-4, lr=1.0e-3,
    train_ids=pn_labelled_trainids.astype(int),
    test_ids=pn_labelled_testids.astype(int),
    weights=(class_weights).tolist(), k_folds=5)
# Out:
# === Fold 1/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=67.2169, cls=1.2674, recon=43.8455 (44.3017, 43.8059),  smooth=1.0152, latent=23.4469
# Validation loss: 16.1035 | Val acc: 0.5057 |Val acc (NS/BH/CV): 0.3939 |val_class:1.2495 val_recon:2.9276 val_smooth: 0.0120 val_latent:38.2879
# Epoch 1
# Epoch 2:total=12.3585, cls=0.9959, recon=1.4119 (1.2412, 1.4228),  smooth=0.0444, latent=21.6310
# Validation loss: 11.4372 | Val acc: 0.7780 |Val acc (NS/BH/CV): 0.4848 |val_class:0.9276 val_recon:1.2829 val_smooth: 0.0332 val_latent:22.5638
# Epoch 2
# Epoch 3:total=10.5798, cls=0.8405, recon=1.2558 (1.2301, 1.2596),  smooth=0.0375, latent=20.3407
# Validation loss: 12.1866 | Val acc: 0.5584 |Val acc (NS/BH/CV): 0.6667 |val_class:0.9396 val_recon:2.1349 val_smooth: 0.0099 val_latent:32.1346
# Epoch 3
# Epoch 4:total=8.6698, cls=0.6552, recon=1.2269 (1.1997, 1.2291),  smooth=0.0344, latent=20.8776
# Validation loss: 16.4164 | Val acc: 0.5355 |Val acc (NS/BH/CV): 0.3636 |val_class:1.4240 val_recon:1.4354 val_smooth: 0.0186 val_latent:26.9347
# Epoch 4
# Epoch 5:total=7.7206, cls=0.5642, recon=1.2011 (1.1590, 1.2030),  smooth=0.0327, latent=20.7270
# Validation loss: 12.2419 | Val acc: 0.7368 |Val acc (NS/BH/CV): 0.3636 |val_class:1.0359 val_recon:0.9720 val_smooth: 0.0360 val_latent:20.0942
# Epoch 5
# Epoch 6:total=6.5523, cls=0.4525, recon=1.1682 (1.1138, 1.1713),  smooth=0.0306, latent=20.4245
# Validation loss: 12.4265 | Val acc: 0.7323 |Val acc (NS/BH/CV): 0.5455 |val_class:1.0606 val_recon:0.9978 val_smooth: 0.0268 val_latent:21.2265
# Epoch 6
# Epoch 7:total=6.2485, cls=0.4241, recon=1.1552 (1.1097, 1.1585),  smooth=0.0297, latent=19.6530
# Validation loss: 14.0913 | Val acc: 0.5973 |Val acc (NS/BH/CV): 0.5455 |val_class:1.1959 val_recon:1.4380 val_smooth: 0.0131 val_latent:25.8517
# Epoch 7
# Epoch 8:total=5.3138, cls=0.3343, recon=1.1301 (1.0796, 1.1340),  smooth=0.0283, latent=18.9602
# Validation loss: 13.1909 | Val acc: 0.6316 |Val acc (NS/BH/CV): 0.5758 |val_class:1.0947 val_recon:1.5679 val_smooth: 0.0110 val_latent:25.9084
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=4.4320, cls=0.2479, recon=1.1275 (1.0837, 1.1318),  smooth=0.0267, latent=18.5579
# Validation loss: 11.8730 | Val acc: 0.8284 |Val acc (NS/BH/CV): 0.5758 |val_class:1.0117 val_recon:0.9457 val_smooth: 0.0251 val_latent:19.3686
# Epoch 9
# Epoch 10:total=4.1420, cls=0.2224, recon=1.1033 (1.0450, 1.1090),  smooth=0.0256, latent=18.7195
# Validation loss: 11.8111 | Val acc: 0.7986 |Val acc (NS/BH/CV): 0.4848 |val_class:0.9990 val_recon:1.0902 val_smooth: 0.0169 val_latent:22.2813
# Epoch 10
# Epoch 11:total=3.7648, cls=0.1873, recon=1.0915 (1.0378, 1.0954),  smooth=0.0241, latent=18.8780
# Validation loss: 12.0467 | Val acc: 0.8421 |Val acc (NS/BH/CV): 0.5758 |val_class:1.0326 val_recon:0.9214 val_smooth: 0.0239 val_latent:19.5324
# Epoch 11
# Epoch 12:total=3.7879, cls=0.1904, recon=1.0883 (1.0169, 1.0931),  smooth=0.0236, latent=18.9442
# Validation loss: 12.7441 | Val acc: 0.8101 |Val acc (NS/BH/CV): 0.4545 |val_class:1.0973 val_recon:0.9151 val_smooth: 0.0297 val_latent:18.0712
# Epoch 12
# Epoch 13:total=3.8256, cls=0.1947, recon=1.0848 (1.0214, 1.0887),  smooth=0.0234, latent=19.0633
# Validation loss: 12.6851 | Val acc: 0.8398 |Val acc (NS/BH/CV): 0.5455 |val_class:1.0974 val_recon:0.9084 val_smooth: 0.0242 val_latent:19.5422
# Epoch 13
# Epoch 14:total=3.5600, cls=0.1686, recon=1.0830 (1.0128, 1.0852),  smooth=0.0231, latent=19.0348
# Validation loss: 12.6542 | Val acc: 0.8330 |Val acc (NS/BH/CV): 0.5455 |val_class:1.0939 val_recon:0.8944 val_smooth: 0.0261 val_latent:18.7474
# Learning rate changed to 0.000063
# Epoch 14
# Epoch 15:total=3.3850, cls=0.1519, recon=1.0792 (1.0166, 1.0806),  smooth=0.0227, latent=19.1207
# Validation loss: 13.9375 | Val acc: 0.8650 |Val acc (NS/BH/CV): 0.5152 |val_class:1.2209 val_recon:0.9086 val_smooth: 0.0260 val_latent:19.0725
# Epoch 15
# Epoch 16:total=3.3792, cls=0.1516, recon=1.0757 (1.0078, 1.0814),  smooth=0.0228, latent=19.1412
# Validation loss: 13.5339 | Val acc: 0.8535 |Val acc (NS/BH/CV): 0.5455 |val_class:1.1821 val_recon:0.9004 val_smooth: 0.0252 val_latent:19.2056
# Epoch 16
# Epoch 17:total=3.3163, cls=0.1454, recon=1.0760 (1.0164, 1.0802),  smooth=0.0226, latent=19.1978
# Validation loss: 13.7837 | Val acc: 0.8673 |Val acc (NS/BH/CV): 0.5152 |val_class:1.2076 val_recon:0.9061 val_smooth: 0.0241 val_latent:19.3689
# Epoch 17
# Epoch 18:total=3.2974, cls=0.1438, recon=1.0741 (1.0051, 1.0773),  smooth=0.0225, latent=19.1968
# Validation loss: 13.6145 | Val acc: 0.8627 |Val acc (NS/BH/CV): 0.5152 |val_class:1.1903 val_recon:0.9064 val_smooth: 0.0244 val_latent:19.4920
# Epoch 18
# Epoch 19:total=3.2564, cls=0.1397, recon=1.0745 (1.0157, 1.0793),  smooth=0.0225, latent=19.1936
# Validation loss: 13.7421 | Val acc: 0.8558 |Val acc (NS/BH/CV): 0.4848 |val_class:1.2031 val_recon:0.9041 val_smooth: 0.0247 val_latent:19.1782
# Epoch 19
# Epoch 20:total=3.2316, cls=0.1376, recon=1.0710 (1.0007, 1.0759),  smooth=0.0224, latent=19.2509
# Validation loss: 13.9119 | Val acc: 0.8696 |Val acc (NS/BH/CV): 0.4848 |val_class:1.2207 val_recon:0.9042 val_smooth: 0.0241 val_latent:19.3167
# Learning rate changed to 0.000016
# Train accuracy: 0.97364 (0.99242)| Val accuracy: 0.86957 (0.48485) | Test accuracy: 0.85401 (0.33333)
#
# === Fold 2/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=39.7906, cls=1.2623, recon=17.6266 (17.5153, 17.6380),  smooth=0.8991, latent=24.8291
# Validation loss: 13.7211 | Val acc: 0.4920 |Val acc (NS/BH/CV): 0.5455 |val_class:1.1323 val_recon:1.3467 val_smooth: 0.0502 val_latent:23.7415
# Epoch 1
# Epoch 2:total=12.7577, cls=1.0269, recon=1.3997 (1.1509, 1.4160),  smooth=0.0542, latent=21.1982
# Validation loss: 13.2154 | Val acc: 0.7735 |Val acc (NS/BH/CV): 0.3636 |val_class:1.0536 val_recon:1.1360 val_smooth: 0.1002 val_latent:15.5360
# Epoch 2
# Epoch 3:total=10.2886, cls=0.8028, recon=1.2622 (1.0902, 1.2737),  smooth=0.0452, latent=19.5058
# Validation loss: 13.6126 | Val acc: 0.8146 |Val acc (NS/BH/CV): 0.2424 |val_class:1.1060 val_recon:1.2223 val_smooth: 0.0786 val_latent:15.7235
# Epoch 3
# Epoch 4:total=8.3081, cls=0.6135, recon=1.2177 (1.0813, 1.2255),  smooth=0.0406, latent=19.4946
# Validation loss: 13.5692 | Val acc: 0.5217 |Val acc (NS/BH/CV): 0.5758 |val_class:1.1398 val_recon:1.3774 val_smooth: 0.0238 val_latent:24.0649
# Epoch 4
# Epoch 5:total=7.4731, cls=0.5376, recon=1.1736 (1.0724, 1.1814),  smooth=0.0371, latent=19.3724
# Validation loss: 13.2809 | Val acc: 0.6430 |Val acc (NS/BH/CV): 0.5152 |val_class:1.1349 val_recon:1.1018 val_smooth: 0.0275 val_latent:20.4422
# Epoch 5
# Epoch 6:total=5.9622, cls=0.3910, recon=1.1587 (1.0663, 1.1629),  smooth=0.0338, latent=19.0133
# Validation loss: 15.5732 | Val acc: 0.6316 |Val acc (NS/BH/CV): 0.5152 |val_class:1.3145 val_recon:1.7426 val_smooth: 0.0121 val_latent:27.3956
# Epoch 6
# Epoch 7:total=5.5353, cls=0.3526, recon=1.1398 (1.0615, 1.1435),  smooth=0.0312, latent=18.9511
# Validation loss: 14.2947 | Val acc: 0.7643 |Val acc (NS/BH/CV): 0.4848 |val_class:1.2216 val_recon:1.0640 val_smooth: 0.0460 val_latent:15.7342
# Epoch 7
# Epoch 8:total=4.6749, cls=0.2702, recon=1.1168 (1.0639, 1.1204),  smooth=0.0297, latent=18.3637
# Validation loss: 18.2250 | Val acc: 0.8490 |Val acc (NS/BH/CV): 0.3030 |val_class:1.6273 val_recon:1.0140 val_smooth: 0.0380 val_latent:15.9163
# Learning rate changed to 0.000250
# Epoch 8
# Epoch 9:total=3.9225, cls=0.1989, recon=1.0936 (0.9917, 1.1010),  smooth=0.0280, latent=18.0798
# Validation loss: 19.5554 | Val acc: 0.8352 |Val acc (NS/BH/CV): 0.4242 |val_class:1.7758 val_recon:0.9395 val_smooth: 0.0297 val_latent:18.9803
# Epoch 9
# Epoch 10:total=3.7788, cls=0.1855, recon=1.0880 (1.0056, 1.0936),  smooth=0.0275, latent=18.1822
# Validation loss: 17.8426 | Val acc: 0.8398 |Val acc (NS/BH/CV): 0.3939 |val_class:1.6014 val_recon:0.9577 val_smooth: 0.0312 val_latent:17.3650
# Epoch 10
# Epoch 11:total=3.6627, cls=0.1745, recon=1.0844 (1.0034, 1.0886),  smooth=0.0273, latent=18.2833
# Validation loss: 16.6519 | Val acc: 0.7918 |Val acc (NS/BH/CV): 0.4545 |val_class:1.4839 val_recon:0.9400 val_smooth: 0.0314 val_latent:16.9041
# Epoch 11
# Epoch 12:total=3.4931, cls=0.1586, recon=1.0786 (0.9774, 1.0852),  smooth=0.0268, latent=18.4252
# Validation loss: 18.1078 | Val acc: 0.8284 |Val acc (NS/BH/CV): 0.4545 |val_class:1.6337 val_recon:0.9488 val_smooth: 0.0261 val_latent:18.7735
# Epoch 12
# Epoch 13:total=3.4807, cls=0.1582, recon=1.0732 (0.9798, 1.0794),  smooth=0.0264, latent=18.4112
# Validation loss: 17.8537 | Val acc: 0.8032 |Val acc (NS/BH/CV): 0.4848 |val_class:1.6081 val_recon:0.9915 val_smooth: 0.0218 val_latent:20.2504
# Epoch 13
# Epoch 14:total=3.2898, cls=0.1400, recon=1.0683 (0.9687, 1.0772),  smooth=0.0261, latent=18.4293
# Validation loss: 18.8926 | Val acc: 0.8307 |Val acc (NS/BH/CV): 0.4545 |val_class:1.7131 val_recon:0.9169 val_smooth: 0.0284 val_latent:18.0110
# Learning rate changed to 0.000063
# Epoch 14
# Epoch 15:total=3.2469, cls=0.1364, recon=1.0633 (0.9639, 1.0698),  smooth=0.0259, latent=18.6234
# Validation loss: 19.6809 | Val acc: 0.8444 |Val acc (NS/BH/CV): 0.4242 |val_class:1.7903 val_recon:0.9183 val_smooth: 0.0299 val_latent:17.7797
# Epoch 15
# Epoch 16:total=3.1133, cls=0.1233, recon=1.0628 (0.9567, 1.0706),  smooth=0.0257, latent=18.4935
# Validation loss: 19.9584 | Val acc: 0.8535 |Val acc (NS/BH/CV): 0.4545 |val_class:1.8204 val_recon:0.9164 val_smooth: 0.0278 val_latent:18.1546
# Epoch 16
# Epoch 17:total=3.1008, cls=0.1222, recon=1.0627 (0.9684, 1.0681),  smooth=0.0256, latent=18.5113
# Validation loss: 19.1852 | Val acc: 0.8352 |Val acc (NS/BH/CV): 0.4545 |val_class:1.7431 val_recon:0.9155 val_smooth: 0.0278 val_latent:18.1555
# Epoch 17
# Epoch 18:total=3.1369, cls=0.1260, recon=1.0612 (0.9683, 1.0658),  smooth=0.0255, latent=18.5578
# Validation loss: 19.7406 | Val acc: 0.8467 |Val acc (NS/BH/CV): 0.3939 |val_class:1.7958 val_recon:0.9207 val_smooth: 0.0302 val_latent:17.6058
# Epoch 18
# Epoch 19:total=2.9893, cls=0.1118, recon=1.0588 (0.9436, 1.0660),  smooth=0.0252, latent=18.5787
# Validation loss: 20.0483 | Val acc: 0.8490 |Val acc (NS/BH/CV): 0.4242 |val_class:1.8298 val_recon:0.9171 val_smooth: 0.0273 val_latent:18.4038
# Epoch 19
# Epoch 20:total=3.0179, cls=0.1147, recon=1.0583 (0.9719, 1.0643),  smooth=0.0252, latent=18.5943
# Validation loss: 20.4269 | Val acc: 0.8421 |Val acc (NS/BH/CV): 0.3939 |val_class:1.8687 val_recon:0.9279 val_smooth: 0.0251 val_latent:19.2236
# Learning rate changed to 0.000016
# Train accuracy: 0.97708 (0.98485)| Val accuracy: 0.84211 (0.39394) | Test accuracy: 0.84672 (0.36364)
#
# === Fold 3/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=58.4823, cls=1.2269, recon=34.5769 (34.6460, 34.5643),  smooth=1.1097, latent=14.6391
# Validation loss: 21.4911 | Val acc: 0.7959 |Val acc (NS/BH/CV): 0.3333 |val_class:1.1652 val_recon:5.2158 val_smooth: 0.4093 val_latent:5.7794
# Epoch 1
# Epoch 2:total=12.6051, cls=1.0261, recon=1.3993 (1.2511, 1.4124),  smooth=0.0406, latent=13.6446
# Validation loss: 23.9632 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.1818 |val_class:1.1814 val_recon:8.5028 val_smooth: 0.3116 val_latent:5.1935
# Epoch 2
# Epoch 3:total=10.5185, cls=0.8414, recon=1.2412 (1.3117, 1.2371),  smooth=0.0324, latent=13.1670
# Validation loss: 12.5786 | Val acc: 0.6583 |Val acc (NS/BH/CV): 0.4848 |val_class:1.0691 val_recon:1.0396 val_smooth: 0.0308 val_latent:13.1140
# Epoch 3
# Epoch 4:total=9.5510, cls=0.7507, recon=1.1800 (1.1641, 1.1818),  smooth=0.0322, latent=13.0815
# Validation loss: 13.3254 | Val acc: 0.5826 |Val acc (NS/BH/CV): 0.5152 |val_class:1.1481 val_recon:1.0157 val_smooth: 0.0285 val_latent:14.2902
# Epoch 4
# Epoch 5:total=8.3973, cls=0.6390, recon=1.1478 (1.1307, 1.1494),  smooth=0.0316, latent=12.7302
# Validation loss: 12.4184 | Val acc: 0.6812 |Val acc (NS/BH/CV): 0.4848 |val_class:1.0535 val_recon:1.1072 val_smooth: 0.0229 val_latent:14.6929
# Epoch 5
# Epoch 6:total=7.4093, cls=0.5429, recon=1.1228 (1.1501, 1.1213),  smooth=0.0312, latent=11.9880
# Validation loss: 13.2151 | Val acc: 0.7385 |Val acc (NS/BH/CV): 0.4545 |val_class:1.1308 val_recon:1.1961 val_smooth: 0.0161 val_latent:14.0735
# Epoch 6
# Epoch 7:total=6.4145, cls=0.4477, recon=1.1024 (1.0720, 1.1043),  smooth=0.0287, latent=11.7438
# Validation loss: 15.8752 | Val acc: 0.6606 |Val acc (NS/BH/CV): 0.3939 |val_class:1.3453 val_recon:1.2797 val_smooth: 0.0594 val_latent:9.1973
# Epoch 7
# Epoch 8:total=5.6517, cls=0.3741, recon=1.0878 (1.0361, 1.0927),  smooth=0.0272, latent=11.7117
# Validation loss: 14.7021 | Val acc: 0.6835 |Val acc (NS/BH/CV): 0.6061 |val_class:1.2839 val_recon:1.1547 val_smooth: 0.0154 val_latent:13.8727
# Epoch 8
# Epoch 9:total=5.1806, cls=0.3286, recon=1.0809 (1.0463, 1.0832),  smooth=0.0260, latent=11.8234
# Validation loss: 14.6047 | Val acc: 0.7867 |Val acc (NS/BH/CV): 0.4848 |val_class:1.2797 val_recon:0.9150 val_smooth: 0.0338 val_latent:11.6093
# Epoch 9
# Epoch 10:total=4.3841, cls=0.2512, recon=1.0675 (1.0245, 1.0714),  smooth=0.0249, latent=11.6062
# Validation loss: 20.5352 | Val acc: 0.8440 |Val acc (NS/BH/CV): 0.2121 |val_class:1.8254 val_recon:1.2562 val_smooth: 0.0471 val_latent:9.6572
# Epoch 10
# Epoch 11:total=4.1908, cls=0.2331, recon=1.0601 (1.0305, 1.0627),  smooth=0.0243, latent=11.8435
# Validation loss: 17.2896 | Val acc: 0.7890 |Val acc (NS/BH/CV): 0.4545 |val_class:1.5593 val_recon:0.9020 val_smooth: 0.0237 val_latent:11.2906
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=3.6619, cls=0.1817, recon=1.0543 (1.0187, 1.0580),  smooth=0.0232, latent=11.7779
# Validation loss: 15.5871 | Val acc: 0.8142 |Val acc (NS/BH/CV): 0.5152 |val_class:1.3920 val_recon:0.8856 val_smooth: 0.0224 val_latent:11.8419
# Epoch 12
# Epoch 13:total=3.2735, cls=0.1435, recon=1.0494 (0.9935, 1.0516),  smooth=0.0231, latent=11.8320
# Validation loss: 16.7562 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.4545 |val_class:1.5080 val_recon:0.9215 val_smooth: 0.0196 val_latent:12.7355
# Epoch 13
# Epoch 14:total=3.2261, cls=0.1389, recon=1.0510 (0.9931, 1.0561),  smooth=0.0228, latent=11.9238
# Validation loss: 16.6192 | Val acc: 0.8417 |Val acc (NS/BH/CV): 0.4848 |val_class:1.4950 val_recon:0.8770 val_smooth: 0.0235 val_latent:12.0450
# Epoch 14
# Epoch 15:total=3.1161, cls=0.1281, recon=1.0502 (1.0050, 1.0533),  smooth=0.0226, latent=12.0824
# Validation loss: 17.1246 | Val acc: 0.8372 |Val acc (NS/BH/CV): 0.4545 |val_class:1.5376 val_recon:0.9080 val_smooth: 0.0283 val_latent:11.3232
# Epoch 15
# Epoch 16:total=3.1005, cls=0.1271, recon=1.0463 (0.9953, 1.0493),  smooth=0.0225, latent=12.1592
# Validation loss: 17.1028 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.4848 |val_class:1.5351 val_recon:0.8980 val_smooth: 0.0297 val_latent:11.2947
# Epoch 16
# Epoch 17:total=3.0326, cls=0.1208, recon=1.0444 (0.9831, 1.0484),  smooth=0.0222, latent=12.2193
# Validation loss: 17.9541 | Val acc: 0.8394 |Val acc (NS/BH/CV): 0.4545 |val_class:1.6247 val_recon:0.8834 val_smooth: 0.0266 val_latent:11.8050
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=2.8714, cls=0.1050, recon=1.0433 (0.9990, 1.0454),  smooth=0.0220, latent=12.2745
# Validation loss: 16.9376 | Val acc: 0.8165 |Val acc (NS/BH/CV): 0.4848 |val_class:1.5280 val_recon:0.8745 val_smooth: 0.0225 val_latent:12.3448
# Epoch 18
# Epoch 19:total=2.9177, cls=0.1097, recon=1.0432 (0.9883, 1.0483),  smooth=0.0220, latent=12.2574
# Validation loss: 17.4269 | Val acc: 0.8234 |Val acc (NS/BH/CV): 0.4242 |val_class:1.5736 val_recon:0.8769 val_smooth: 0.0257 val_latent:11.7784
# Epoch 19
# Epoch 20:total=2.7980, cls=0.0979, recon=1.0413 (1.0050, 1.0425),  smooth=0.0220, latent=12.3027
# Validation loss: 16.7549 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.4545 |val_class:1.5077 val_recon:0.8685 val_smooth: 0.0252 val_latent:11.6917
# Train accuracy: 0.96105 (1.00000)| Val accuracy: 0.81193 (0.45455) | Test accuracy: 0.81022 (0.36364)
#
# === Fold 4/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=70.5249, cls=1.3820, recon=45.7147 (46.5160, 45.6671),  smooth=1.0434, latent=28.7572
# Validation loss: 14.2335 | Val acc: 0.3349 |Val acc (NS/BH/CV): 0.6061 |val_class:1.2023 val_recon:1.1529 val_smooth: 0.0498 val_latent:30.9156
# Epoch 1
# Epoch 2:total=11.8655, cls=0.9633, recon=1.2982 (1.2408, 1.3033),  smooth=0.0377, latent=28.5642
# Validation loss: 13.6780 | Val acc: 0.4128 |Val acc (NS/BH/CV): 0.5758 |val_class:1.1695 val_recon:0.9894 val_smooth: 0.0437 val_latent:27.4404
# Epoch 2
# Epoch 3:total=10.3755, cls=0.8236, recon=1.2225 (1.2546, 1.2214),  smooth=0.0358, latent=27.6009
# Validation loss: 11.9147 | Val acc: 0.6583 |Val acc (NS/BH/CV): 0.6364 |val_class:0.9582 val_recon:1.5831 val_smooth: 0.0179 val_latent:38.2755
# Epoch 3
# Epoch 4:total=8.9414, cls=0.6838, recon=1.2036 (1.2081, 1.2016),  smooth=0.0339, latent=26.3259
# Validation loss: 12.2954 | Val acc: 0.6032 |Val acc (NS/BH/CV): 0.5758 |val_class:1.0089 val_recon:1.4906 val_smooth: 0.0143 val_latent:36.9530
# Epoch 4
# Epoch 5:total=7.4969, cls=0.5443, recon=1.1897 (1.2402, 1.1831),  smooth=0.0300, latent=25.6020
# Validation loss: 13.3851 | Val acc: 0.7271 |Val acc (NS/BH/CV): 0.3636 |val_class:1.0238 val_recon:1.8037 val_smooth: 0.0786 val_latent:17.1608
# Epoch 5
# Epoch 6:total=6.8560, cls=0.4841, recon=1.1668 (1.2131, 1.1660),  smooth=0.0281, latent=24.6987
# Validation loss: 11.1597 | Val acc: 0.6858 |Val acc (NS/BH/CV): 0.5758 |val_class:0.9349 val_recon:0.9925 val_smooth: 0.0247 val_latent:25.9372
# Epoch 6
# Epoch 7:total=5.7191, cls=0.3737, recon=1.1433 (1.1879, 1.1402),  smooth=0.0268, latent=23.4147
# Validation loss: 17.3005 | Val acc: 0.7179 |Val acc (NS/BH/CV): 0.4848 |val_class:1.5478 val_recon:1.0272 val_smooth: 0.0220 val_latent:25.4390
# Epoch 7
# Epoch 8:total=5.3322, cls=0.3375, recon=1.1285 (1.1407, 1.1288),  smooth=0.0255, latent=21.9546
# Validation loss: 13.5255 | Val acc: 0.6032 |Val acc (NS/BH/CV): 0.5152 |val_class:1.1552 val_recon:1.2561 val_smooth: 0.0139 val_latent:25.8372
# Epoch 8
# Epoch 9:total=4.4617, cls=0.2520, recon=1.1186 (1.1046, 1.1202),  smooth=0.0247, latent=21.4736
# Validation loss: 15.1354 | Val acc: 0.8326 |Val acc (NS/BH/CV): 0.3333 |val_class:1.3180 val_recon:1.0399 val_smooth: 0.0340 val_latent:19.6109
# Epoch 9
# Epoch 10:total=4.2953, cls=0.2366, recon=1.1061 (1.0928, 1.1067),  smooth=0.0244, latent=21.4840
# Validation loss: 17.3965 | Val acc: 0.8142 |Val acc (NS/BH/CV): 0.2727 |val_class:1.5011 val_recon:1.3261 val_smooth: 0.0485 val_latent:16.3231
# Epoch 10
# Epoch 11:total=3.7823, cls=0.1880, recon=1.0888 (1.0481, 1.0915),  smooth=0.0233, latent=21.0708
# Validation loss: 16.3222 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.4242 |val_class:1.4570 val_recon:0.9959 val_smooth: 0.0173 val_latent:23.7629
# Epoch 11
# Epoch 12:total=3.6094, cls=0.1723, recon=1.0770 (1.0245, 1.0821),  smooth=0.0228, latent=21.0549
# Validation loss: 15.3843 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4545 |val_class:1.3573 val_recon:1.0751 val_smooth: 0.0151 val_latent:23.6698
# Learning rate changed to 0.000250
# Epoch 12
# Epoch 13:total=3.1562, cls=0.1279, recon=1.0717 (1.0152, 1.0754),  smooth=0.0223, latent=20.9963
# Validation loss: 15.5037 | Val acc: 0.8303 |Val acc (NS/BH/CV): 0.4848 |val_class:1.3787 val_recon:0.9474 val_smooth: 0.0186 val_latent:21.8656
# Epoch 13
# Epoch 14:total=3.0145, cls=0.1142, recon=1.0692 (1.0470, 1.0713),  smooth=0.0220, latent=21.0026
# Validation loss: 17.4387 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.3939 |val_class:1.5721 val_recon:0.9440 val_smooth: 0.0190 val_latent:22.1174
# Epoch 14
# Epoch 15:total=2.9244, cls=0.1061, recon=1.0634 (1.0036, 1.0683),  smooth=0.0217, latent=21.1539
# Validation loss: 17.0629 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.4242 |val_class:1.5352 val_recon:0.9104 val_smooth: 0.0218 val_latent:20.9480
# Epoch 15
# Epoch 16:total=2.9173, cls=0.1058, recon=1.0607 (0.9983, 1.0641),  smooth=0.0216, latent=21.1416
# Validation loss: 15.4773 | Val acc: 0.8234 |Val acc (NS/BH/CV): 0.4848 |val_class:1.3783 val_recon:0.9062 val_smooth: 0.0206 val_latent:20.8868
# Epoch 16
# Epoch 17:total=2.7547, cls=0.0902, recon=1.0559 (0.9953, 1.0604),  smooth=0.0215, latent=21.2710
# Validation loss: 17.4095 | Val acc: 0.8486 |Val acc (NS/BH/CV): 0.4545 |val_class:1.5672 val_recon:0.9066 val_smooth: 0.0249 val_latent:19.9058
# Epoch 17
# Epoch 18:total=2.7451, cls=0.0893, recon=1.0578 (0.9703, 1.0638),  smooth=0.0212, latent=21.4429
# Validation loss: 17.2211 | Val acc: 0.8578 |Val acc (NS/BH/CV): 0.4848 |val_class:1.5467 val_recon:0.9095 val_smooth: 0.0264 val_latent:19.6786
# Learning rate changed to 0.000063
# Epoch 18
# Epoch 19:total=2.6686, cls=0.0822, recon=1.0534 (0.9709, 1.0599),  smooth=0.0210, latent=21.5500
# Validation loss: 17.4389 | Val acc: 0.8624 |Val acc (NS/BH/CV): 0.4545 |val_class:1.5736 val_recon:0.8963 val_smooth: 0.0225 val_latent:20.6238
# Epoch 19
# Epoch 20:total=2.6783, cls=0.0832, recon=1.0559 (0.9941, 1.0620),  smooth=0.0208, latent=21.5639
# Validation loss: 17.3094 | Val acc: 0.8532 |Val acc (NS/BH/CV): 0.4545 |val_class:1.5618 val_recon:0.8936 val_smooth: 0.0216 val_latent:20.8041
# Train accuracy: 0.98167 (1.00000)| Val accuracy: 0.85321 (0.45455) | Test accuracy: 0.86496 (0.36364)
#
# === Fold 5/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=39.6784, cls=1.2985, recon=17.6661 (17.8181, 17.6557),  smooth=0.8471, latent=30.3282
# Validation loss: 25.3072 | Val acc: 0.0894 |Val acc (NS/BH/CV): 0.5152 |val_class:2.1473 val_recon:3.1624 val_smooth: 0.0092 val_latent:53.6556
# Epoch 1
# Epoch 2:total=11.4294, cls=0.9139, recon=1.3053 (1.1548, 1.3147),  smooth=0.0433, latent=25.0805
# Validation loss: 13.8027 | Val acc: 0.4931 |Val acc (NS/BH/CV): 0.3939 |val_class:1.1251 val_recon:1.8312 val_smooth: 0.0158 val_latent:34.7586
# Epoch 2
# Epoch 3:total=9.7911, cls=0.7612, recon=1.2285 (1.1029, 1.2366),  smooth=0.0398, latent=24.1015
# Validation loss: 14.1981 | Val acc: 0.5161 |Val acc (NS/BH/CV): 0.4242 |val_class:1.1382 val_recon:2.1303 val_smooth: 0.0117 val_latent:38.4144
# Epoch 3
# Epoch 4:total=8.3275, cls=0.6212, recon=1.2002 (1.0945, 1.2066),  smooth=0.0359, latent=24.0843
# Validation loss: 14.4878 | Val acc: 0.4771 |Val acc (NS/BH/CV): 0.5455 |val_class:1.1639 val_recon:2.1815 val_smooth: 0.0094 val_latent:39.1774
# Epoch 4
# Epoch 5:total=7.3497, cls=0.5258, recon=1.1866 (1.1061, 1.1927),  smooth=0.0345, latent=23.6284
# Validation loss: 13.5777 | Val acc: 0.6124 |Val acc (NS/BH/CV): 0.5455 |val_class:1.1317 val_recon:1.5308 val_smooth: 0.0162 val_latent:29.6313
# Epoch 5
# Epoch 6:total=6.4817, cls=0.4456, recon=1.1481 (1.0834, 1.1530),  smooth=0.0316, latent=22.2265
# Validation loss: 17.6765 | Val acc: 0.5849 |Val acc (NS/BH/CV): 0.4242 |val_class:1.4079 val_recon:2.9645 val_smooth: 0.0049 val_latent:42.8512
# Epoch 6
# Epoch 7:total=5.2998, cls=0.3319, recon=1.1210 (1.0337, 1.1268),  smooth=0.0295, latent=21.2990
# Validation loss: 16.9709 | Val acc: 0.6743 |Val acc (NS/BH/CV): 0.3333 |val_class:1.4457 val_recon:1.8436 val_smooth: 0.0093 val_latent:31.4763
# Epoch 7
# Epoch 8:total=4.9002, cls=0.2939, recon=1.1156 (1.0333, 1.1219),  smooth=0.0278, latent=20.7833
# Validation loss: 22.8681 | Val acc: 0.7844 |Val acc (NS/BH/CV): 0.3030 |val_class:1.9878 val_recon:2.3394 val_smooth: 0.0067 val_latent:35.3579
# Epoch 8
# Epoch 9:total=4.2734, cls=0.2333, recon=1.1001 (1.0108, 1.1056),  smooth=0.0270, latent=19.7990
# Validation loss: 22.6626 | Val acc: 0.7408 |Val acc (NS/BH/CV): 0.4545 |val_class:1.8009 val_recon:4.0376 val_smooth: 0.0020 val_latent:44.6358
# Epoch 9
# Epoch 10:total=4.1291, cls=0.2205, recon=1.0893 (0.9774, 1.0985),  smooth=0.0263, latent=19.6824
# Validation loss: 24.8769 | Val acc: 0.8555 |Val acc (NS/BH/CV): 0.1818 |val_class:2.2508 val_recon:1.3408 val_smooth: 0.0458 val_latent:16.0952
# Epoch 10
# Epoch 11:total=3.9413, cls=0.2038, recon=1.0728 (0.9489, 1.0821),  smooth=0.0256, latent=19.1967
# Validation loss: 25.2691 | Val acc: 0.8417 |Val acc (NS/BH/CV): 0.1818 |val_class:2.2906 val_recon:1.3543 val_smooth: 0.0436 val_latent:15.1692
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=3.0811, cls=0.1200, recon=1.0627 (0.9665, 1.0697),  smooth=0.0243, latent=17.9832
# Validation loss: 19.9444 | Val acc: 0.8234 |Val acc (NS/BH/CV): 0.3636 |val_class:1.8160 val_recon:0.9523 val_smooth: 0.0257 val_latent:18.1975
# Epoch 12
# Epoch 13:total=2.9689, cls=0.1098, recon=1.0548 (0.9386, 1.0621),  smooth=0.0240, latent=18.3320
# Validation loss: 20.1275 | Val acc: 0.8119 |Val acc (NS/BH/CV): 0.3333 |val_class:1.8353 val_recon:0.9674 val_smooth: 0.0230 val_latent:19.3749
# Epoch 13
# Epoch 14:total=2.8589, cls=0.0992, recon=1.0541 (0.9360, 1.0616),  smooth=0.0237, latent=18.5661
# Validation loss: 19.5679 | Val acc: 0.7867 |Val acc (NS/BH/CV): 0.3939 |val_class:1.7671 val_recon:1.1640 val_smooth: 0.0154 val_latent:22.5940
# Epoch 14
# Epoch 15:total=2.8110, cls=0.0951, recon=1.0494 (0.9380, 1.0558),  smooth=0.0236, latent=18.6705
# Validation loss: 21.1933 | Val acc: 0.8234 |Val acc (NS/BH/CV): 0.3333 |val_class:1.9433 val_recon:0.9322 val_smooth: 0.0253 val_latent:18.7020
# Epoch 15
# Epoch 16:total=2.7507, cls=0.0896, recon=1.0482 (0.9330, 1.0548),  smooth=0.0232, latent=18.6835
# Validation loss: 20.4895 | Val acc: 0.8028 |Val acc (NS/BH/CV): 0.3939 |val_class:1.8709 val_recon:1.0111 val_smooth: 0.0191 val_latent:20.9568
# Epoch 16
# Epoch 17:total=2.6866, cls=0.0835, recon=1.0463 (0.9369, 1.0537),  smooth=0.0230, latent=18.8041
# Validation loss: 22.6077 | Val acc: 0.8211 |Val acc (NS/BH/CV): 0.3030 |val_class:2.0838 val_recon:0.9255 val_smooth: 0.0270 val_latent:18.2699
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=2.6523, cls=0.0804, recon=1.0482 (0.9332, 1.0558),  smooth=0.0225, latent=18.8793
# Validation loss: 22.4186 | Val acc: 0.8142 |Val acc (NS/BH/CV): 0.3030 |val_class:2.0628 val_recon:0.9386 val_smooth: 0.0278 val_latent:18.0890
# Epoch 18
# Epoch 19:total=2.6405, cls=0.0795, recon=1.0438 (0.9304, 1.0507),  smooth=0.0226, latent=18.8100
# Validation loss: 23.6153 | Val acc: 0.8188 |Val acc (NS/BH/CV): 0.2727 |val_class:2.1836 val_recon:0.9353 val_smooth: 0.0269 val_latent:18.5205
# Epoch 19
# Epoch 20:total=2.6098, cls=0.0766, recon=1.0439 (0.9280, 1.0524),  smooth=0.0225, latent=18.8626
# Validation loss: 22.1512 | Val acc: 0.8073 |Val acc (NS/BH/CV): 0.3030 |val_class:2.0408 val_recon:0.9245 val_smooth: 0.0244 val_latent:18.9529
# Train accuracy: 0.98396 (1.00000)| Val accuracy: 0.80734 (0.30303) | Test accuracy: 0.83759 (0.39394)

# %%
all_results3, train_data, test_data = semisupervised_kfold_test(
    SemiSupervisedAE,
    np.column_stack([pn_normspec_labelled, pn_counts_labelled]),
    pn_spec_labels,
    np.column_stack([pn_normspec[unlabelled_args], pn_counts[unlabelled_args]]),
    epochs=20, lambda_cls=10, l2_lambda=1.0e-3, l1_lambda=1.0e-4, lr=1.0e-3,
    train_ids=pn_labelled_trainids.astype(int),
    test_ids=pn_labelled_testids.astype(int),
    weights=(class_weights**2).tolist(), k_folds=5)
# Out:
# === Fold 1/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=51.5629, cls=1.1525, recon=29.8455 (30.3760, 29.8110),  smooth=0.9644, latent=25.1139
# Validation loss: 12.7627 | Val acc: 0.2815 |Val acc (NS/BH/CV): 0.6061 |val_class:0.9848 val_recon:1.5778 val_smooth: 0.0794 val_latent:19.0208
# Epoch 1
# Epoch 2:total=10.9652, cls=0.8805, recon=1.2402 (1.1699, 1.2438),  smooth=0.0369, latent=26.3568
# Validation loss: 12.8389 | Val acc: 0.3295 |Val acc (NS/BH/CV): 0.6364 |val_class:0.9079 val_recon:2.1744 val_smooth: 0.1044 val_latent:15.9964
# Epoch 2
# Epoch 3:total=10.4843, cls=0.8328, recon=1.2424 (1.1930, 1.2456),  smooth=0.0364, latent=23.7712
# Validation loss: 12.3401 | Val acc: 0.1510 |Val acc (NS/BH/CV): 0.6970 |val_class:0.8493 val_recon:2.4113 val_smooth: 0.0896 val_latent:12.1933
# Epoch 3
# Epoch 4:total=8.1839, cls=0.6163, recon=1.1802 (1.1719, 1.1815),  smooth=0.0290, latent=22.2102
# Validation loss: 15.5834 | Val acc: 0.5606 |Val acc (NS/BH/CV): 0.5758 |val_class:1.0825 val_recon:3.0656 val_smooth: 0.1149 val_latent:13.3774
# Epoch 4
# Epoch 5:total=7.5358, cls=0.5530, recon=1.1742 (1.1435, 1.1756),  smooth=0.0279, latent=20.9371
# Validation loss: 11.5170 | Val acc: 0.3936 |Val acc (NS/BH/CV): 0.6667 |val_class:0.9054 val_recon:1.3201 val_smooth: 0.0594 val_latent:16.2140
# Epoch 5
# Epoch 6:total=6.5102, cls=0.4539, recon=1.1488 (1.1178, 1.1496),  smooth=0.0268, latent=20.0889
# Validation loss: 14.1945 | Val acc: 0.5698 |Val acc (NS/BH/CV): 0.5152 |val_class:1.2407 val_recon:0.9845 val_smooth: 0.0247 val_latent:21.1119
# Epoch 6
# Epoch 7:total=6.9467, cls=0.4976, recon=1.1544 (1.1291, 1.1531),  smooth=0.0261, latent=18.8863
# Validation loss: 11.3084 | Val acc: 0.5538 |Val acc (NS/BH/CV): 0.6061 |val_class:0.9494 val_recon:1.0334 val_smooth: 0.0224 val_latent:18.0800
# Epoch 7
# Epoch 8:total=5.5599, cls=0.3634, recon=1.1196 (1.0882, 1.1219),  smooth=0.0248, latent=17.8860
# Validation loss: 26.0591 | Val acc: 0.7551 |Val acc (NS/BH/CV): 0.2727 |val_class:2.4118 val_recon:1.0369 val_smooth: 0.0346 val_latent:17.5459
# Epoch 8
# Epoch 9:total=5.3405, cls=0.3432, recon=1.1095 (1.0807, 1.1018),  smooth=0.0241, latent=17.2361
# Validation loss: 22.0200 | Val acc: 0.8055 |Val acc (NS/BH/CV): 0.3636 |val_class:1.9258 val_recon:1.6815 val_smooth: 0.0525 val_latent:13.2484
# Epoch 9
# Epoch 10:total=4.6439, cls=0.2765, recon=1.0868 (1.0301, 1.0904),  smooth=0.0233, latent=16.7119
# Validation loss: 22.6015 | Val acc: 0.4943 |Val acc (NS/BH/CV): 0.4242 |val_class:2.0610 val_recon:1.2039 val_smooth: 0.0228 val_latent:15.5357
# Epoch 10
# Epoch 11:total=4.1735, cls=0.2300, recon=1.0873 (1.0370, 1.0918),  smooth=0.0226, latent=15.8545
# Validation loss: 28.7576 | Val acc: 0.8352 |Val acc (NS/BH/CV): 0.3333 |val_class:2.5603 val_recon:1.9880 val_smooth: 0.0609 val_latent:11.9429
# Epoch 11
# Epoch 12:total=3.6430, cls=0.1796, recon=1.0674 (1.0145, 1.0720),  smooth=0.0218, latent=16.0322
# Validation loss: 19.0379 | Val acc: 0.6682 |Val acc (NS/BH/CV): 0.4848 |val_class:1.7359 val_recon:0.9214 val_smooth: 0.0196 val_latent:16.0868
# Epoch 12
# Epoch 13:total=3.1835, cls=0.1358, recon=1.0522 (0.9800, 1.0571),  smooth=0.0212, latent=16.3013
# Validation loss: 24.0489 | Val acc: 0.6682 |Val acc (NS/BH/CV): 0.5758 |val_class:2.2318 val_recon:1.0212 val_smooth: 0.0147 val_latent:18.1295
# Learning rate changed to 0.000250
# Epoch 13
# Epoch 14:total=2.8891, cls=0.1081, recon=1.0456 (0.9817, 1.0497),  smooth=0.0202, latent=16.3556
# Validation loss: 21.8710 | Val acc: 0.7231 |Val acc (NS/BH/CV): 0.4848 |val_class:2.0088 val_recon:0.9583 val_smooth: 0.0267 val_latent:14.1330
# Epoch 14
# Epoch 15:total=2.6553, cls=0.0851, recon=1.0434 (0.9738, 1.0486),  smooth=0.0201, latent=16.0233
# Validation loss: 23.0831 | Val acc: 0.6957 |Val acc (NS/BH/CV): 0.4545 |val_class:2.1431 val_recon:0.8861 val_smooth: 0.0206 val_latent:16.3546
# Epoch 15
# Epoch 16:total=2.8245, cls=0.1024, recon=1.0419 (0.9859, 1.0468),  smooth=0.0199, latent=16.4696
# Validation loss: 23.3497 | Val acc: 0.7277 |Val acc (NS/BH/CV): 0.4848 |val_class:2.1687 val_recon:0.8884 val_smooth: 0.0215 val_latent:16.1808
# Epoch 16
# Epoch 17:total=2.7624, cls=0.0969, recon=1.0363 (0.9512, 1.0428),  smooth=0.0198, latent=16.5994
# Validation loss: 25.5123 | Val acc: 0.7780 |Val acc (NS/BH/CV): 0.4545 |val_class:2.3855 val_recon:0.8929 val_smooth: 0.0206 val_latent:16.4156
# Epoch 17
# Epoch 18:total=2.7067, cls=0.0916, recon=1.0373 (0.9633, 1.0424),  smooth=0.0195, latent=16.5613
# Validation loss: 25.1313 | Val acc: 0.7643 |Val acc (NS/BH/CV): 0.3939 |val_class:2.3478 val_recon:0.8940 val_smooth: 0.0202 val_latent:16.0971
# Epoch 18
# Epoch 19:total=2.6134, cls=0.0824, recon=1.0374 (0.9699, 1.0423),  smooth=0.0194, latent=16.6501
# Validation loss: 28.8691 | Val acc: 0.7826 |Val acc (NS/BH/CV): 0.4848 |val_class:2.7199 val_recon:0.8832 val_smooth: 0.0230 val_latent:16.1317
# Learning rate changed to 0.000063
# Epoch 19
# Epoch 20:total=2.6564, cls=0.0873, recon=1.0343 (0.9507, 1.0420),  smooth=0.0191, latent=16.8983
# Validation loss: 25.2343 | Val acc: 0.7529 |Val acc (NS/BH/CV): 0.4242 |val_class:2.3589 val_recon:0.8780 val_smooth: 0.0211 val_latent:16.2848
# Train accuracy: 0.86304 (1.00000)| Val accuracy: 0.75286 (0.42424) | Test accuracy: 0.75182 (0.54545)
#
# === Fold 2/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=74.5571, cls=1.1563, recon=50.6270 (50.8986, 50.6114),  smooth=1.1833, latent=12.8033
# Validation loss: 12.2514 | Val acc: 0.0389 |Val acc (NS/BH/CV): 0.5152 |val_class:0.9488 val_recon:1.3273 val_smooth: 0.0904 val_latent:10.6515
# Epoch 1
# Epoch 2:total=11.6223, cls=0.9388, recon=1.2959 (1.2901, 1.2958),  smooth=0.0403, latent=13.2822
# Validation loss: 12.0279 | Val acc: 0.2654 |Val acc (NS/BH/CV): 0.6364 |val_class:0.9671 val_recon:1.1997 val_smooth: 0.0626 val_latent:9.6998
# Epoch 2
# Epoch 3:total=10.0551, cls=0.8016, recon=1.1886 (1.2286, 1.1869),  smooth=0.0316, latent=12.5492
# Validation loss: 12.3589 | Val acc: 0.4600 |Val acc (NS/BH/CV): 0.6667 |val_class:1.0313 val_recon:1.0829 val_smooth: 0.0429 val_latent:10.9054
# Epoch 3
# Epoch 4:total=10.1598, cls=0.8160, recon=1.1601 (1.2172, 1.1563),  smooth=0.0305, latent=11.7811
# Validation loss: 15.7377 | Val acc: 0.1190 |Val acc (NS/BH/CV): 0.5152 |val_class:1.3611 val_recon:1.0871 val_smooth: 0.0505 val_latent:10.1778
# Epoch 4
# Epoch 5:total=9.6625, cls=0.7681, recon=1.1398 (1.2297, 1.1353),  smooth=0.0306, latent=10.9190
# Validation loss: 11.7696 | Val acc: 0.3707 |Val acc (NS/BH/CV): 0.6061 |val_class:0.9933 val_recon:1.0023 val_smooth: 0.0298 val_latent:9.9136
# Epoch 5
# Epoch 6:total=7.9178, cls=0.5989, recon=1.1131 (1.1307, 1.1135),  smooth=0.0278, latent=10.1986
# Validation loss: 12.5006 | Val acc: 0.3341 |Val acc (NS/BH/CV): 0.6061 |val_class:1.0110 val_recon:1.3073 val_smooth: 0.0547 val_latent:7.5152
# Epoch 6
# Epoch 7:total=7.2281, cls=0.5317, recon=1.0975 (1.1291, 1.0963),  smooth=0.0275, latent=9.8825
# Validation loss: 12.4419 | Val acc: 0.3478 |Val acc (NS/BH/CV): 0.6667 |val_class:1.0094 val_recon:1.7082 val_smooth: 0.0095 val_latent:13.9049
# Epoch 7
# Epoch 8:total=6.6655, cls=0.4768, recon=1.0901 (1.0643, 1.0890),  smooth=0.0266, latent=9.6445
# Validation loss: 14.7202 | Val acc: 0.3204 |Val acc (NS/BH/CV): 0.5455 |val_class:1.2853 val_recon:1.1455 val_smooth: 0.0178 val_latent:10.7200
# Epoch 8
# Epoch 9:total=6.3140, cls=0.4430, recon=1.0805 (1.0538, 1.0823),  smooth=0.0260, latent=9.3404
# Validation loss: 19.8235 | Val acc: 0.8009 |Val acc (NS/BH/CV): 0.4848 |val_class:1.6727 val_recon:1.8716 val_smooth: 0.0683 val_latent:6.5521
# Epoch 9
# Epoch 10:total=5.3100, cls=0.3437, recon=1.0740 (1.0510, 1.0728),  smooth=0.0253, latent=9.3029
# Validation loss: 14.7039 | Val acc: 0.3936 |Val acc (NS/BH/CV): 0.6061 |val_class:1.2533 val_recon:1.5161 val_smooth: 0.0104 val_latent:12.7038
# Epoch 10
# Epoch 11:total=4.9377, cls=0.3097, recon=1.0580 (1.0241, 1.0612),  smooth=0.0234, latent=9.3672
# Validation loss: 31.8352 | Val acc: 0.6430 |Val acc (NS/BH/CV): 0.1515 |val_class:2.9773 val_recon:1.3059 val_smooth: 0.0205 val_latent:11.8246
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=4.3703, cls=0.2539, recon=1.0522 (1.0339, 1.0545),  smooth=0.0230, latent=9.4516
# Validation loss: 17.3360 | Val acc: 0.6888 |Val acc (NS/BH/CV): 0.5152 |val_class:1.5590 val_recon:0.9317 val_smooth: 0.0266 val_latent:9.2931
# Epoch 12
# Epoch 13:total=3.9196, cls=0.2096, recon=1.0486 (1.0074, 1.0521),  smooth=0.0226, latent=9.4859
# Validation loss: 18.8344 | Val acc: 0.7208 |Val acc (NS/BH/CV): 0.5152 |val_class:1.7112 val_recon:0.9382 val_smooth: 0.0235 val_latent:9.7139
# Epoch 13
# Epoch 14:total=3.7686, cls=0.1939, recon=1.0553 (1.0150, 1.0516),  smooth=0.0225, latent=9.6027
# Validation loss: 15.5027 | Val acc: 0.5858 |Val acc (NS/BH/CV): 0.6061 |val_class:1.3789 val_recon:0.9141 val_smooth: 0.0252 val_latent:9.1185
# Epoch 14
# Epoch 15:total=3.4772, cls=0.1664, recon=1.0437 (0.9805, 1.0474),  smooth=0.0221, latent=9.6355
# Validation loss: 20.1856 | Val acc: 0.7346 |Val acc (NS/BH/CV): 0.5152 |val_class:1.8437 val_recon:0.9247 val_smooth: 0.0275 val_latent:9.4070
# Epoch 15
# Epoch 16:total=3.5886, cls=0.1780, recon=1.0408 (0.9871, 1.0451),  smooth=0.0219, latent=9.6616
# Validation loss: 17.2711 | Val acc: 0.6064 |Val acc (NS/BH/CV): 0.5152 |val_class:1.5580 val_recon:0.9149 val_smooth: 0.0228 val_latent:9.7087
# Epoch 16
# Epoch 17:total=3.2611, cls=0.1456, recon=1.0397 (0.9758, 1.0442),  smooth=0.0217, latent=9.7266
# Validation loss: 18.0725 | Val acc: 0.6865 |Val acc (NS/BH/CV): 0.5758 |val_class:1.6358 val_recon:0.9123 val_smooth: 0.0254 val_latent:9.4311
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=3.5051, cls=0.1704, recon=1.0376 (0.9775, 1.0421),  smooth=0.0216, latent=9.8136
# Validation loss: 20.3508 | Val acc: 0.7208 |Val acc (NS/BH/CV): 0.5152 |val_class:1.8627 val_recon:0.9182 val_smooth: 0.0257 val_latent:9.8033
# Epoch 18
# Epoch 19:total=3.2680, cls=0.1466, recon=1.0399 (0.9840, 1.0443),  smooth=0.0213, latent=9.9576
# Validation loss: 20.1779 | Val acc: 0.7231 |Val acc (NS/BH/CV): 0.5152 |val_class:1.8460 val_recon:0.9145 val_smooth: 0.0255 val_latent:9.8451
# Epoch 19
# Epoch 20:total=3.1408, cls=0.1340, recon=1.0393 (0.9884, 1.0446),  smooth=0.0214, latent=9.9189
# Validation loss: 19.0137 | Val acc: 0.6979 |Val acc (NS/BH/CV): 0.5455 |val_class:1.7320 val_recon:0.9088 val_smooth: 0.0237 val_latent:9.9191
# Train accuracy: 0.77822 (0.99242)| Val accuracy: 0.69794 (0.54545) | Test accuracy: 0.65328 (0.51515)
#
# === Fold 3/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=107.9970, cls=1.2206, recon=78.9761 (80.3696, 78.8926),  smooth=1.6268, latent=23.4533
# Validation loss: 13.3475 | Val acc: 0.0482 |Val acc (NS/BH/CV): 0.6364 |val_class:1.0789 val_recon:1.7684 val_smooth: 0.0226 val_latent:38.3825
# Epoch 1
# Epoch 2:total=11.5865, cls=0.9285, recon=1.3674 (1.3195, 1.3697),  smooth=0.0379, latent=29.2093
# Validation loss: 12.7442 | Val acc: 0.0688 |Val acc (NS/BH/CV): 0.6667 |val_class:1.0471 val_recon:1.5384 val_smooth: 0.0172 val_latent:36.6232
# Epoch 2
# Epoch 3:total=11.5551, cls=0.9367, recon=1.2546 (1.4155, 1.2386),  smooth=0.0381, latent=25.8370
# Validation loss: 14.0810 | Val acc: 0.0596 |Val acc (NS/BH/CV): 0.6667 |val_class:1.1761 val_recon:1.6295 val_smooth: 0.0130 val_latent:33.2721
# Epoch 3
# Epoch 4:total=10.0602, cls=0.7973, recon=1.2120 (1.3380, 1.2047),  smooth=0.0323, latent=24.1779
# Validation loss: 12.5197 | Val acc: 0.2615 |Val acc (NS/BH/CV): 0.6667 |val_class:1.0158 val_recon:1.2244 val_smooth: 0.0590 val_latent:18.3766
# Epoch 4
# Epoch 5:total=8.7285, cls=0.6626, recon=1.2290 (1.3461, 1.2213),  smooth=0.0321, latent=23.0943
# Validation loss: 12.3666 | Val acc: 0.3624 |Val acc (NS/BH/CV): 0.6061 |val_class:1.0157 val_recon:1.5142 val_smooth: 0.0136 val_latent:29.6065
# Epoch 5
# Epoch 6:total=6.6911, cls=0.4676, recon=1.1774 (1.2332, 1.1716),  smooth=0.0283, latent=22.8527
# Validation loss: 12.5612 | Val acc: 0.2133 |Val acc (NS/BH/CV): 0.6667 |val_class:1.0676 val_recon:1.1262 val_smooth: 0.0202 val_latent:25.9522
# Epoch 6
# Epoch 7:total=7.6267, cls=0.5590, recon=1.2004 (1.3133, 1.1935),  smooth=0.0282, latent=22.0665
# Validation loss: 14.4809 | Val acc: 0.3647 |Val acc (NS/BH/CV): 0.5455 |val_class:1.2593 val_recon:1.1087 val_smooth: 0.0223 val_latent:22.0050
# Epoch 7
# Epoch 8:total=5.9866, cls=0.4008, recon=1.1537 (1.2162, 1.1503),  smooth=0.0269, latent=20.6118
# Validation loss: 15.2192 | Val acc: 0.3188 |Val acc (NS/BH/CV): 0.6364 |val_class:1.2610 val_recon:1.9660 val_smooth: 0.0076 val_latent:31.3072
# Epoch 8
# Epoch 9:total=5.7823, cls=0.3812, recon=1.1506 (1.2096, 1.1477),  smooth=0.0263, latent=20.0873
# Validation loss: 21.6151 | Val acc: 0.6353 |Val acc (NS/BH/CV): 0.4848 |val_class:1.9733 val_recon:1.0919 val_smooth: 0.0231 val_latent:21.2727
# Epoch 9
# Epoch 10:total=5.1051, cls=0.3147, recon=1.1411 (1.1973, 1.1365),  smooth=0.0259, latent=18.8800
# Validation loss: 16.2177 | Val acc: 0.4243 |Val acc (NS/BH/CV): 0.5152 |val_class:1.4460 val_recon:0.9559 val_smooth: 0.0243 val_latent:19.0289
# Epoch 10
# Epoch 11:total=4.6188, cls=0.2696, recon=1.1173 (1.1605, 1.1150),  smooth=0.0246, latent=18.4836
# Validation loss: 23.0774 | Val acc: 0.6261 |Val acc (NS/BH/CV): 0.5152 |val_class:2.1314 val_recon:0.9969 val_smooth: 0.0206 val_latent:19.1621
# Learning rate changed to 0.000250
# Epoch 11
# Epoch 12:total=4.1234, cls=0.2220, recon=1.1081 (1.1046, 1.1075),  smooth=0.0235, latent=18.6638
# Validation loss: 18.6876 | Val acc: 0.5940 |Val acc (NS/BH/CV): 0.5455 |val_class:1.6946 val_recon:0.9467 val_smooth: 0.0234 val_latent:18.7131
# Epoch 12
# Epoch 13:total=3.6436, cls=0.1750, recon=1.0987 (1.0997, 1.0995),  smooth=0.0234, latent=18.6984
# Validation loss: 19.7530 | Val acc: 0.6055 |Val acc (NS/BH/CV): 0.5152 |val_class:1.8001 val_recon:0.9329 val_smooth: 0.0260 val_latent:18.0326
# Epoch 13
# Epoch 14:total=3.5173, cls=0.1631, recon=1.0919 (1.1045, 1.0915),  smooth=0.0234, latent=18.7808
# Validation loss: 21.7438 | Val acc: 0.6995 |Val acc (NS/BH/CV): 0.5152 |val_class:2.0001 val_recon:0.9532 val_smooth: 0.0229 val_latent:18.9170
# Epoch 14
# Epoch 15:total=3.6743, cls=0.1789, recon=1.0923 (1.0951, 1.0919),  smooth=0.0232, latent=18.9132
# Validation loss: 23.1625 | Val acc: 0.7179 |Val acc (NS/BH/CV): 0.5152 |val_class:2.1282 val_recon:1.0047 val_smooth: 0.0317 val_latent:16.7463
# Epoch 15
# Epoch 16:total=3.6117, cls=0.1736, recon=1.0866 (1.0712, 1.0851),  smooth=0.0229, latent=18.9685
# Validation loss: 21.0414 | Val acc: 0.5986 |Val acc (NS/BH/CV): 0.5152 |val_class:1.9303 val_recon:0.9989 val_smooth: 0.0177 val_latent:20.7230
# Epoch 16
# Epoch 17:total=3.3919, cls=0.1522, recon=1.0828 (1.0723, 1.0821),  smooth=0.0226, latent=19.1067
# Validation loss: 20.8830 | Val acc: 0.5894 |Val acc (NS/BH/CV): 0.5455 |val_class:1.9148 val_recon:0.9202 val_smooth: 0.0255 val_latent:18.2357
# Learning rate changed to 0.000063
# Epoch 17
# Epoch 18:total=3.4442, cls=0.1580, recon=1.0767 (1.0514, 1.0787),  smooth=0.0226, latent=19.0148
# Validation loss: 22.9210 | Val acc: 0.7087 |Val acc (NS/BH/CV): 0.5152 |val_class:2.1190 val_recon:0.9254 val_smooth: 0.0245 val_latent:18.4784
# Epoch 18
# Epoch 19:total=3.3732, cls=0.1508, recon=1.0807 (1.0949, 1.0790),  smooth=0.0224, latent=19.0209
# Validation loss: 23.2974 | Val acc: 0.7385 |Val acc (NS/BH/CV): 0.5152 |val_class:2.1515 val_recon:0.9489 val_smooth: 0.0274 val_latent:17.5744
# Epoch 19
# Epoch 20:total=3.0754, cls=0.1212, recon=1.0809 (1.0596, 1.0831),  smooth=0.0222, latent=18.9867
# Validation loss: 21.3478 | Val acc: 0.6674 |Val acc (NS/BH/CV): 0.5455 |val_class:1.9623 val_recon:0.9226 val_smooth: 0.0242 val_latent:18.2905
# Train accuracy: 0.75372 (1.00000)| Val accuracy: 0.66743 (0.54545) | Test accuracy: 0.63321 (0.54545)
#
# === Fold 4/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=43.1075, cls=1.1054, recon=22.0632 (22.5022, 22.0361),  smooth=0.9440, latent=24.2796
# Validation loss: 11.5448 | Val acc: 0.0413 |Val acc (NS/BH/CV): 0.5455 |val_class:0.9309 val_recon:1.4019 val_smooth: 0.0278 val_latent:29.1279
# Epoch 1
# Epoch 2:total=11.2357, cls=0.9021, recon=1.2712 (1.1620, 1.2764),  smooth=0.0395, latent=21.7643
# Validation loss: 13.6465 | Val acc: 0.5596 |Val acc (NS/BH/CV): 0.5758 |val_class:1.1331 val_recon:1.6129 val_smooth: 0.0147 val_latent:28.4673
# Epoch 2
# Epoch 3:total=9.6118, cls=0.7464, recon=1.2271 (1.1884, 1.2300),  smooth=0.0373, latent=19.9469
# Validation loss: 11.3390 | Val acc: 0.2867 |Val acc (NS/BH/CV): 0.5455 |val_class:0.9468 val_recon:1.0103 val_smooth: 0.0311 val_latent:20.2515
# Epoch 3
# Epoch 4:total=8.6380, cls=0.6554, recon=1.1895 (1.1606, 1.1886),  smooth=0.0345, latent=18.9710
# Validation loss: 11.9291 | Val acc: 0.2271 |Val acc (NS/BH/CV): 0.6364 |val_class:0.9790 val_recon:1.3871 val_smooth: 0.0195 val_latent:25.3194
# Epoch 4
# Epoch 5:total=7.5154, cls=0.5453, recon=1.1886 (1.1743, 1.1891),  smooth=0.0323, latent=17.3284
# Validation loss: 14.3346 | Val acc: 0.3028 |Val acc (NS/BH/CV): 0.4848 |val_class:1.2175 val_recon:1.4676 val_smooth: 0.0133 val_latent:22.8814
# Epoch 5
# Epoch 6:total=6.5432, cls=0.4529, recon=1.1641 (1.1452, 1.1653),  smooth=0.0297, latent=16.0707
# Validation loss: 11.6963 | Val acc: 0.2729 |Val acc (NS/BH/CV): 0.6061 |val_class:0.9331 val_recon:1.7028 val_smooth: 0.0100 val_latent:23.7969
# Epoch 6
# Epoch 7:total=5.3804, cls=0.3420, recon=1.1298 (1.0810, 1.1333),  smooth=0.0275, latent=15.6178
# Validation loss: 14.9492 | Val acc: 0.6560 |Val acc (NS/BH/CV): 0.6061 |val_class:1.3011 val_recon:1.0414 val_smooth: 0.0342 val_latent:13.8964
# Epoch 7
# Epoch 8:total=4.3816, cls=0.2440, recon=1.1219 (1.0918, 1.1254),  smooth=0.0262, latent=15.7146
# Validation loss: 12.7222 | Val acc: 0.4954 |Val acc (NS/BH/CV): 0.6364 |val_class:1.0964 val_recon:0.9913 val_smooth: 0.0207 val_latent:16.6663
# Epoch 8
# Epoch 9:total=4.2876, cls=0.2358, recon=1.1158 (1.0721, 1.1190),  smooth=0.0255, latent=15.6915
# Validation loss: 17.1142 | Val acc: 0.1651 |Val acc (NS/BH/CV): 0.6061 |val_class:1.2187 val_recon:4.3298 val_smooth: 0.0014 val_latent:38.6681
# Learning rate changed to 0.000250
# Epoch 9
# Epoch 10:total=3.8495, cls=0.1935, recon=1.1072 (1.0816, 1.1102),  smooth=0.0248, latent=15.3006
# Validation loss: 15.0937 | Val acc: 0.6261 |Val acc (NS/BH/CV): 0.5758 |val_class:1.3295 val_recon:0.9506 val_smooth: 0.0290 val_latent:13.7364
# Epoch 10
# Epoch 11:total=3.5714, cls=0.1669, recon=1.0991 (1.0734, 1.1014),  smooth=0.0244, latent=15.5454
# Validation loss: 14.1409 | Val acc: 0.5550 |Val acc (NS/BH/CV): 0.6061 |val_class:1.2410 val_recon:0.9485 val_smooth: 0.0223 val_latent:15.3230
# Epoch 11
# Epoch 12:total=3.6459, cls=0.1750, recon=1.0946 (1.0607, 1.0974),  smooth=0.0241, latent=15.9166
# Validation loss: 18.1570 | Val acc: 0.6835 |Val acc (NS/BH/CV): 0.4848 |val_class:1.6382 val_recon:0.9393 val_smooth: 0.0277 val_latent:14.8788
# Epoch 12
# Epoch 13:total=3.2170, cls=0.1328, recon=1.0909 (1.0523, 1.0932),  smooth=0.0238, latent=16.0004
# Validation loss: 16.6189 | Val acc: 0.6560 |Val acc (NS/BH/CV): 0.5758 |val_class:1.4703 val_recon:1.0227 val_smooth: 0.0336 val_latent:13.4534
# Epoch 13
# Epoch 14:total=3.4370, cls=0.1558, recon=1.0842 (1.0293, 1.0898),  smooth=0.0234, latent=16.1681
# Validation loss: 20.2194 | Val acc: 0.7202 |Val acc (NS/BH/CV): 0.5152 |val_class:1.8313 val_recon:1.0173 val_smooth: 0.0331 val_latent:13.8392
# Epoch 14
# Epoch 15:total=3.1691, cls=0.1298, recon=1.0797 (1.0221, 1.0840),  smooth=0.0231, latent=16.2134
# Validation loss: 15.6537 | Val acc: 0.6078 |Val acc (NS/BH/CV): 0.6364 |val_class:1.3945 val_recon:0.9465 val_smooth: 0.0202 val_latent:16.3309
# Learning rate changed to 0.000063
# Epoch 15
# Epoch 16:total=3.0218, cls=0.1157, recon=1.0755 (1.0371, 1.0777),  smooth=0.0229, latent=16.1708
# Validation loss: 17.6060 | Val acc: 0.6743 |Val acc (NS/BH/CV): 0.5455 |val_class:1.5897 val_recon:0.9347 val_smooth: 0.0214 val_latent:16.0937
# Epoch 16
# Epoch 17:total=3.0732, cls=0.1209, recon=1.0761 (1.0319, 1.0781),  smooth=0.0228, latent=16.1913
# Validation loss: 17.9795 | Val acc: 0.6927 |Val acc (NS/BH/CV): 0.5455 |val_class:1.6255 val_recon:0.9193 val_smooth: 0.0246 val_latent:15.2104
# Epoch 17
# Epoch 18:total=3.0150, cls=0.1152, recon=1.0758 (1.0251, 1.0799),  smooth=0.0227, latent=16.2498
# Validation loss: 18.3409 | Val acc: 0.6995 |Val acc (NS/BH/CV): 0.5152 |val_class:1.6629 val_recon:0.9182 val_smooth: 0.0235 val_latent:15.4975
# Epoch 18
# Epoch 19:total=2.9204, cls=0.1062, recon=1.0725 (1.0313, 1.0751),  smooth=0.0226, latent=16.2481
# Validation loss: 16.8857 | Val acc: 0.6514 |Val acc (NS/BH/CV): 0.5455 |val_class:1.5189 val_recon:0.9245 val_smooth: 0.0213 val_latent:15.9748
# Epoch 19
# Epoch 20:total=3.0463, cls=0.1193, recon=1.0695 (0.9900, 1.0753),  smooth=0.0224, latent=16.3897
# Validation loss: 19.5601 | Val acc: 0.7225 |Val acc (NS/BH/CV): 0.5455 |val_class:1.7823 val_recon:0.9261 val_smooth: 0.0252 val_latent:15.4511
# Train accuracy: 0.84250 (1.00000)| Val accuracy: 0.72248 (0.54545) | Test accuracy: 0.72993 (0.48485)
#
# === Fold 5/5 ===
# 10 0.0001 10
# Epoch 0
# Epoch 1:total=59.1204, cls=1.2328, recon=36.3744 (36.5003, 36.3665),  smooth=0.9889, latent=8.0539
# Validation loss: 14.1823 | Val acc: 0.0459 |Val acc (NS/BH/CV): 0.6061 |val_class:1.1601 val_recon:1.3850 val_smooth: 0.0668 val_latent:6.5867
# Epoch 1
# Epoch 2:total=11.7876, cls=0.9712, recon=1.2469 (1.2414, 1.2467),  smooth=0.0299, latent=8.5054
# Validation loss: 12.9874 | Val acc: 0.2936 |Val acc (NS/BH/CV): 0.6667 |val_class:1.0883 val_recon:1.1768 val_smooth: 0.0398 val_latent:7.7515
# Epoch 2
# Epoch 3:total=11.5684, cls=0.9566, recon=1.1758 (1.2734, 1.1678),  smooth=0.0296, latent=8.1960
# Validation loss: 14.2325 | Val acc: 0.2729 |Val acc (NS/BH/CV): 0.5152 |val_class:1.1762 val_recon:1.4172 val_smooth: 0.0524 val_latent:7.0485
# Epoch 3
# Epoch 4:total=9.7329, cls=0.7768, recon=1.1579 (1.2032, 1.1562),  smooth=0.0276, latent=7.7290
# Validation loss: 13.7338 | Val acc: 0.1514 |Val acc (NS/BH/CV): 0.7273 |val_class:1.1878 val_recon:1.0792 val_smooth: 0.0244 val_latent:8.7981
# Epoch 4
# Epoch 5:total=9.7686, cls=0.7818, recon=1.1486 (1.2389, 1.1434),  smooth=0.0270, latent=7.0989
# Validation loss: 14.2782 | Val acc: 0.1147 |Val acc (NS/BH/CV): 0.5455 |val_class:1.2406 val_recon:1.1085 val_smooth: 0.0230 val_latent:7.6936
# Epoch 5
# Epoch 6:total=8.5941, cls=0.6692, recon=1.1185 (1.1864, 1.1136),  smooth=0.0251, latent=6.7683
# Validation loss: 14.2081 | Val acc: 0.5596 |Val acc (NS/BH/CV): 0.6061 |val_class:1.2276 val_recon:1.0179 val_smooth: 0.0380 val_latent:6.3595
# Epoch 6
# Epoch 7:total=7.5327, cls=0.5644, recon=1.1178 (1.1298, 1.1192),  smooth=0.0237, latent=6.5576
# Validation loss: 12.5534 | Val acc: 0.4381 |Val acc (NS/BH/CV): 0.6667 |val_class:1.0809 val_recon:0.9276 val_smooth: 0.0281 val_latent:6.8475
# Epoch 7
# Epoch 8:total=6.8264, cls=0.4954, recon=1.1025 (1.1289, 1.0995),  smooth=0.0233, latent=6.5654
# Validation loss: 19.8743 | Val acc: 0.7110 |Val acc (NS/BH/CV): 0.4242 |val_class:1.6921 val_recon:1.8416 val_smooth: 0.0576 val_latent:5.5891
# Epoch 8
# Epoch 9:total=6.9947, cls=0.5117, recon=1.1032 (1.0969, 1.1048),  smooth=0.0236, latent=6.5056
# Validation loss: 20.7337 | Val acc: 0.5963 |Val acc (NS/BH/CV): 0.3636 |val_class:1.8561 val_recon:1.1755 val_smooth: 0.0457 val_latent:6.2970
# Epoch 9
# Epoch 10:total=5.2658, cls=0.3411, recon=1.0889 (1.0935, 1.0873),  smooth=0.0225, latent=6.3733
# Validation loss: 16.9298 | Val acc: 0.4725 |Val acc (NS/BH/CV): 0.6364 |val_class:1.5105 val_recon:0.9929 val_smooth: 0.0291 val_latent:5.7711
# Epoch 10
# Epoch 11:total=5.2860, cls=0.3439, recon=1.0827 (1.0584, 1.0844),  smooth=0.0222, latent=6.5324
# Validation loss: 30.6762 | Val acc: 0.7913 |Val acc (NS/BH/CV): 0.2121 |val_class:2.7349 val_recon:2.0816 val_smooth: 0.0703 val_latent:6.0925
# Epoch 11
# Epoch 12:total=4.5284, cls=0.2705, recon=1.0713 (1.0946, 1.0691),  smooth=0.0209, latent=6.6066
# Validation loss: 21.5642 | Val acc: 0.5275 |Val acc (NS/BH/CV): 0.4848 |val_class:1.9748 val_recon:0.9892 val_smooth: 0.0283 val_latent:5.8764
# Epoch 12
# Epoch 13:total=4.3063, cls=0.2506, recon=1.0530 (1.0401, 1.0527),  smooth=0.0202, latent=6.5987
# Validation loss: 99.0959 | Val acc: 0.7454 |Val acc (NS/BH/CV): 0.0000 |val_class:9.6073 val_recon:1.8752 val_smooth: 0.0592 val_latent:17.1401
# Learning rate changed to 0.000250
# Epoch 13
# Epoch 14:total=3.6640, cls=0.1877, recon=1.0481 (1.0428, 1.0492),  smooth=0.0193, latent=6.5683
# Validation loss: 29.0983 | Val acc: 0.7179 |Val acc (NS/BH/CV): 0.4242 |val_class:2.7390 val_recon:0.9130 val_smooth: 0.0249 val_latent:7.3345
# Epoch 14
# Epoch 15:total=3.3588, cls=0.1576, recon=1.0437 (1.0283, 1.0448),  smooth=0.0193, latent=6.9012
# Validation loss: 27.1359 | Val acc: 0.7202 |Val acc (NS/BH/CV): 0.5152 |val_class:2.5459 val_recon:0.9354 val_smooth: 0.0195 val_latent:7.9136
# Epoch 15
# Epoch 16:total=3.2659, cls=0.1484, recon=1.0452 (1.0374, 1.0457),  smooth=0.0192, latent=7.1035
# Validation loss: 23.6888 | Val acc: 0.6376 |Val acc (NS/BH/CV): 0.5455 |val_class:2.2015 val_recon:0.9240 val_smooth: 0.0204 val_latent:7.4471
# Epoch 16
# Epoch 17:total=3.0942, cls=0.1318, recon=1.0395 (1.0160, 1.0429),  smooth=0.0192, latent=7.0857
# Validation loss: 26.9781 | Val acc: 0.7087 |Val acc (NS/BH/CV): 0.5152 |val_class:2.5253 val_recon:0.9112 val_smooth: 0.0268 val_latent:7.3060
# Epoch 17
# Epoch 18:total=3.0072, cls=0.1232, recon=1.0397 (1.0244, 1.0409),  smooth=0.0190, latent=7.1337
# Validation loss: 29.5028 | Val acc: 0.7431 |Val acc (NS/BH/CV): 0.5152 |val_class:2.7753 val_recon:0.9335 val_smooth: 0.0271 val_latent:7.4435
# Epoch 18
# Epoch 19:total=2.9963, cls=0.1224, recon=1.0380 (1.0205, 1.0396),  smooth=0.0190, latent=7.2084
# Validation loss: 28.4267 | Val acc: 0.7202 |Val acc (NS/BH/CV): 0.4848 |val_class:2.6695 val_recon:0.9322 val_smooth: 0.0255 val_latent:7.2767
# Learning rate changed to 0.000063
# Epoch 19
# Epoch 20:total=2.8034, cls=0.1035, recon=1.0366 (1.0103, 1.0393),  smooth=0.0188, latent=7.2153
# Validation loss: 28.5442 | Val acc: 0.7225 |Val acc (NS/BH/CV): 0.5152 |val_class:2.6856 val_recon:0.9063 val_smooth: 0.0237 val_latent:7.5547
# Train accuracy: 0.82761 (1.00000)| Val accuracy: 0.72248 (0.51515) | Test accuracy: 0.71168 (0.48485)

# %%
best_model = all_results[3]['model']

# %%
pn_spec_tensor = torch.tensor(pn_normspec, dtype=torch.float32).unsqueeze(1)
pn_spec_l_tensor = torch.tensor(pn_normspec_labelled, dtype=torch.float32).unsqueeze(1)
pn_labels_tensor = torch.tensor(pn_spec_labels, dtype=torch.long)

# %%
pn_latent = best_model.encoder(pn_spec_tensor)
pn_latent = pn_latent.view(len(pn_latent), -1)
pn_latent = best_model.fc_enc(pn_latent)

# %%
pn_labeled_latent = best_model.encoder(pn_spec_l_tensor)
pn_labeled_latent = pn_labeled_latent.view(len(pn_labeled_latent), -1)
pn_labeled_latent = best_model.fc_enc(pn_labeled_latent)

# %%
torch.save(pn_latent, 'Latent_pn_spectra_4class.pt')

# %%
def plot_confusion_matrix(model, dataloader, class_names=None, device='cpu', normalize=False, show_metrics=False):
    """
    Compute and plot confusion matrix for a trained PyTorch model.

    Args:
        model (torch.nn.Module): Trained model.
        dataloader (torch.utils.data.DataLoader): Test dataset loader.
        class_names (list of str): Names of the classes in order. Default None.
        device (str): 'cpu' or 'cuda'.
        normalize (bool): Whether to normalize the confusion matrix.
        show_metrics (bool): Whether to print precision, recall, F1 per class.
    """
    model.to(device)
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            _, logits, _ = model(x[:, :, :-1])
            #print(model(x))
            preds = torch.argmax(logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    # Compute confusion matrix
    cm = confusion_matrix(all_labels, all_preds, normalize='true' if normalize else None)

    if class_names is None:
        class_names = [str(i) for i in range(cm.shape[0])]

    # Plot
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap='Blues', values_format='.2f' if normalize else 'd')
    #plt.title("Confusion Matrix")
    plt.show()

    # Print classification metrics
    if show_metrics:
        print("\nClassification Report:\n")
        print(classification_report(all_labels, all_preds, target_names=class_names, digits=4))

# %%
mytest_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
plot_confusion_matrix(all_results[3]['model'], mytest_loader, class_names=['AGN', 'STAR', 'NS/BH', 'CV'])

# %%
# Out:
# [{'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.867579908675799,
#   'test_acc': 0.8722627737226277,
#   'val_acc_nscv': tensor(0.2353),
#   'test_acc_nscv': tensor(0.3333)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8310502283105022,
#   'test_acc': 0.8558394160583942,
#   'val_acc_nscv': tensor(0.4118),
#   'test_acc_nscv': tensor(0.4242)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8669724770642202,
#   'test_acc': 0.864963503649635,
#   'val_acc_nscv': tensor(0.3750),
#   'test_acc_nscv': tensor(0.3636)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8302752293577982,
#   'test_acc': 0.8667883211678832,
#   'val_acc_nscv': tensor(0.5000),
#   'test_acc_nscv': tensor(0.4242)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8532110091743119,
#   'test_acc': 0.8576642335766423,
#   'val_acc_nscv': tensor(0.4375),
#   'test_acc_nscv': tensor(0.3939)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8532110091743119,
#   'test_acc': 0.8613138686131386,
#   'val_acc_nscv': tensor(0.3750),
#   'test_acc_nscv': tensor(0.3636)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8348623853211009,
#   'test_acc': 0.8667883211678832,
#   'val_acc_nscv': tensor(0.3125),
#   'test_acc_nscv': tensor(0.3030)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8899082568807339,
#   'test_acc': 0.8740875912408759,
#   'val_acc_nscv': tensor(0.2941),
#   'test_acc_nscv': tensor(0.2727)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8348623853211009,
#   'test_acc': 0.8448905109489051,
#   'val_acc_nscv': tensor(0.2941),
#   'test_acc_nscv': tensor(0.2727)},
#  {'model': SemiSupervisedAE(
#     (encoder): Sequential(
#       (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,), padding=(3,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv1d(8, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.0, inplace=False)
#       (9): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc_enc): Linear(in_features=1520, out_features=32, bias=True)
#     (fc_dec): Linear(in_features=32, out_features=1520, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(8, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (3): Softplus(beta=1, threshold=20)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=32, out_features=4, bias=True)
#     )
#   ),
#   'val_acc': 0.8532110091743119,
#   'test_acc': 0.8613138686131386,
#   'val_acc_nscv': tensor(0.2353),
#   'test_acc_nscv': tensor(0.2727)}]

# %%
evaluate(all_results[3]['model'], mytest_loader, "cpu")
# Out:
# (0.8667883211678832, tensor(0.4242))
